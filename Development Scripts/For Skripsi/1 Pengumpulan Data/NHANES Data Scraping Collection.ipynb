# %%
import pandas as pd
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, parse_qs
import urllib.request
import time
import re

import warnings
warnings.filterwarnings('ignore')

base_path = "/content/drive/MyDrive/Temp Folder"
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
start_overall = time.time()

# %%
start = time.time()
loop_num = 0

# Get Dataset HTML
dataset_html = []
for name in dataset_names:
  time.sleep(0.5)
  url = base_url + "&Component=" + name
  headers = {
      "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/5##.## (KHTML, like Gecko) Chrome/1##.#.#.# Safari/5##.##"
  }
  response = requests.get(url, headers=headers)
  soup = BeautifulSoup(response.content, "html.parser")
  dataset_html.append({'name':name, 'soup':soup})
  loop_num += 1

end = time.time()
duration = end - start
print("Loop Num: ", loop_num)
print("Time Taken:", duration, "Second")
# Out:
# Loop Num:  5
# Time Taken: 10.709123611450195 Second

# %%
dataset_information = []
for dataset in dataset_html:
  data_title = []
  for td in dataset['soup'].findAll('td', class_="text-left"):
    data_title.append(td.text)

  data_doc = []
  data_xpt = []
  for an in dataset['soup'].findAll('a'):
    if("/Nchs/Nhanes/" in an['href'] and ".htm" in an['href'].lower()):
      data_doc.append(an['href'])
    if("/Nchs/Nhanes/" in an['href'] and ".xpt" in an['href'].lower()):
      data_xpt.append(an['href'])

  dataset_information.append({'name': dataset['name'], 'titles': data_title, 'docs': data_doc, 'xpts': data_xpt})

for dataset in dataset_information:
  print("Name:", dataset['name'])
  print("Num of Dataset Title: ", str(len(dataset['titles'])))
  print("Num of Dataset Docs: ", str(len(dataset['docs'])))
  print("Num of Dataset XPTs: ", str(len(dataset['xpts'])))
  print("-"*10)
  print()
# Out:
# Name: Demographics
# Num of Dataset Title:  1
# Num of Dataset Docs:  1
# Num of Dataset XPTs:  1
# ----------
#
# Name: Dietary
# Num of Dataset Title:  14
# Num of Dataset Docs:  14
# Num of Dataset XPTs:  14
# ----------
#
# Name: Examination
# Num of Dataset Title:  14
# Num of Dataset Docs:  14
# Num of Dataset XPTs:  14
# ----------
#
# Name: Laboratory
# Num of Dataset Title:  53
# Num of Dataset Docs:  53
# Num of Dataset XPTs:  53
# ----------
#
# Name: Questionnaire
# Num of Dataset Title:  44
# Num of Dataset Docs:  44
# Num of Dataset XPTs:  44
# ----------

# %%
start = time.time()
loop_num = 0

# Get Docs HTML
docs_html = []
for dataset in dataset_information:
  for title, doc in zip(dataset['titles'], dataset['docs']):
    docs_url = doc

    time.sleep(0.5)
    url = "https://wwwn.cdc.gov/" + docs_url
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    docs_html.append({'name':dataset['name'], 'doc_url': docs_url, 'titles':title, 'soup':soup})
    loop_num += 1

end = time.time()
duration = end - start
print("Loop Num: ", loop_num)
print("Time Taken:", duration, "Second")

len(docs_html)
# Out:
# Loop Num:  126
# Time Taken: 148.33208775520325 Second
# 126

# %%
# Get Variable List for Each dataset
datasets_variable = []
for doc in docs_html:
  variables = []
  for title in doc['soup'].findAll('h3', class_="vartitle"):
    var_name = title['id']
    var_desc = re.sub(title['id']+" - ", "", title.text)
    missing_value_row = title.find_next(lambda tag: tag.name == 'td' and 'Missing' in tag.text)
    missing_count = missing_value_row.find_next('td')
    total_count = missing_count.find_next('td')

    variables.append({'var_name':var_name, 'var_desc':var_desc, 'missing_count':missing_count.text, 'total_count': total_count.text})

  datasets_variable.append({'name': doc['name'], 'title':doc['titles'], 'doc_url': doc['doc_url'], 'variables':variables})

print(len(datasets_variable))

dataset_variable_df = pd.DataFrame({'name':[], 'title':[], 'doc_url':[], 'variable':[], 'desc':[], 'missing_count':[], 'total_count':[]})

for dataset in datasets_variable:
  for var in dataset['variables']:
    temp = pd.DataFrame([{
        'name': dataset['name'],
        'title': dataset['title'],
        'doc_url': dataset['doc_url'],
        'variable': var['var_name'],
        'desc': var['var_desc'],
        'missing_count': var['missing_count'],
        'total_count': var['total_count']
      }])
    dataset_variable_df = pd.concat([dataset_variable_df, temp], axis=0)

dataset_variable_df = dataset_variable_df.reset_index(drop=True)
dataset_variable_df.to_excel(base_path + '/Dataset/Variable List.xlsx', index=False)

# %%
start = time.time()
loop_num = 0

xpt_paths = []

print("Downloading Data...")

for dataset in dataset_information:
  dir_path = base_path + "/Dataset/Raw XPT/" + dataset['name']
  if(not os.path.exists(dir_path)):
    os.mkdir(dir_path)

  for title, xpt in zip(dataset['titles'], dataset['xpts']):
    file_path = dir_path+"/"+(title.replace("/", " ").strip())+".XPT"

    time.sleep(0.5)
    url = "https://wwwn.cdc.gov" + xpt
    urllib.request.urlretrieve(url, file_path)

    xpt_paths.append({'name': dataset['name'], 'titles':title, 'file_path':file_path})
    print("URL: ", url)
    print("File Path: ", file_path)
    print()
    loop_num += 1

for xpt in xpt_paths:
  dir_path = base_path + "/Dataset/Raw CSV/" + xpt['name']
  if(not os.path.exists(dir_path)):
    os.mkdir(dir_path)

  file_path = dir_path+"/"+(xpt['titles'].replace("/", " ").strip())+".csv"

  data_df = pd.read_sas(xpt['file_path'])

  data_df.to_csv(file_path, index=False)

  csv_paths.append({'name': xpt['name'], 'titles':xpt['titles'], 'file_path':file_path})
  print("URL: ", url)
  print("File Path: ", file_path)
  print()
  loop_num += 1


end = time.time()
duration = end - start
print("Loop Num: ", loop_num)
print("Time Taken:", duration, "Second")
# Out:
# Downloading Data...
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DEMO_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Demographics/Demographic Variables and Sample Weights.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DR1IFF_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Interview - Individual Foods, First Day.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DR2IFF_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Interview - Individual Foods, Second Day.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DR1TOT_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Interview - Total Nutrient Intakes, First Day.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DR2TOT_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Interview - Total Nutrient Intakes, Second Day.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DRXFCD_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Interview Technical Support File - Food Codes.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/DSBI.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Supplement Database - Blend Information.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/DSII.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Supplement Database - Ingredient Information.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/DSPI.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Supplement Database - Product Information.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DS1IDS_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Supplement Use 24-Hour - Individual Dietary Supplements, First Day.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DS2IDS_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Supplement Use 24-Hour - Individual Dietary Supplements, Second Day.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DS1TOT_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Supplement Use 24-Hour - Total Dietary Supplements, First Day.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DS2TOT_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Supplement Use 24-Hour - Total Dietary Supplements, Second Day.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DSQIDS_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Supplement Use 30-Day - Individual Dietary Supplements.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DSQTOT_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Dietary/Dietary Supplement Use 30-Day - Total Dietary Supplements.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/AUX_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Examination/Audiometry.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/AUXAR_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Examination/Audiometry - Acoustic Reflex.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/AUXTYM_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Examination/Audiometry - Tympanometry.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/AUXWBR_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Examination/Audiometry - Wideband Reflectance.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/BPX_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Examination/Blood Pressure.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/BPXO_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Examination/Blood Pressure - Oscillometric Measurements.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018
XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/CBQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Consumer Behavior.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/CBQPFA_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Consumer Behavior Phone Follow-up Module - Adult.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/CBQPFC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Consumer Behavior Phone Follow-up Module - Child.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/HSQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Current Health Status.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DEQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Dermatology.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DIQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Diabetes.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DBQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Diet Behavior & Nutrition.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DLQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Disability.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DUQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Drug Use.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/ECQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Early Childhood.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/FSQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Food Security.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/HIQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Health Insurance.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/HEQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Hepatitis.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/HUQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Hospital Utilization & Access to Care.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/HOQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Housing Characteristics.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/IMQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Immunization.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/INQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Income.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/KIQ_U_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Kidney Conditions - Urology.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/MCQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Medical Conditions.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DPQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Mental Health - Depression Screener.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/OCQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Occupation.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/OHQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Oral Health.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/OSQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Osteoporosis.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/PUQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Pesticide Use.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/PAQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Physical Activity.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/PAQY_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Physical Activity - Youth.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/PFQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Physical Functioning.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/RXQ_RX_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Prescription Medications.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/1999-2000/RXQ_DRUG.xpt
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Prescription Medications - Drug Information.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/RXQASA_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Preventive Aspirin Use.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/RHQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Reproductive Health.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/SLQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Sleep Disorders.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/SMQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Smoking - Cigarette Use.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/SMQFAM_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Smoking - Household Smokers.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/SMQRTU_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Smoking - Recent Tobacco Use.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/SMQSHS_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Smoking - Secondhand Smoke Exposure.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/VTQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Volatile Toxicant.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQ_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Weight History.XPT
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw XPT/Questionnaire/Weight History - Youth.XPT
#
# Loop Num:  126
# Time Taken: 627.1285579204559 Second

# %%
start = time.time()
loop_num = 0

csv_paths = []
if(not os.path.exists(base_path + "/Dataset/Raw CSV/")):
  os.mkdir(base_path + "/Dataset/Raw CSV/")

print("Transforming Data Into CSV...")

for xpt in xpt_paths:
  dir_path = base_path + "/Dataset/Raw CSV/" + xpt['name']
  if(not os.path.exists(dir_path)):
    os.mkdir(dir_path)

  file_path = dir_path+"/"+(xpt['titles'].replace("/", " ").strip())+".csv"

  data_df = pd.read_sas(xpt['file_path'])

  data_df.to_csv(file_path, index=False)

  csv_paths.append({'name': xpt['name'], 'titles':xpt['titles'], 'file_path':file_path})
  print("URL: ", url)
  print("File Path: ", file_path)
  print()
  loop_num += 1


end = time.time()
duration = end - start
print("Loop Num: ", loop_num)
print("Time Taken:", duration, "Second")
# Out:
# Transforming Data Into CSV...
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Demographics/Demographic Variables and Sample Weights.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Interview - Individual Foods, First Day.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Interview - Individual Foods, Second Day.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Interview - Total Nutrient Intakes, First Day.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Interview - Total Nutrient Intakes, Second Day.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Interview Technical Support File - Food Codes.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Supplement Database - Blend Information.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Supplement Database - Ingredient Information.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Supplement Database - Product Information.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Supplement Use 24-Hour - Individual Dietary Supplements, First Day.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Supplement Use 24-Hour - Individual Dietary Supplements, Second Day.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Supplement Use 24-Hour - Total Dietary Supplements, First Day.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Supplement Use 24-Hour - Total Dietary Supplements, Second Day.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Supplement Use 30-Day - Individual Dietary Supplements.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Dietary/Dietary Supplement Use 30-Day - Total Dietary Supplements.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Audiometry.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Audiometry - Acoustic Reflex.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Audiometry - Tympanometry.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Audiometry - Wideband Reflectance.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Blood Pressure.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Blood Pressure - Oscillometric Measurements.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Body Measures.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Dual-Energy X-ray Absorptiometry - Android Gynoid Measurements.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Dual-Energy X-ray Absorptiometry - Femur.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Dual-Energy X-ray Absorptiometry - Spine.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Dual-Energy X-ray Absorptiometry - Whole Body.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/Liver Ultrasound Transient Elastography.csv
#
# URL:  https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Examination/
://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
# File Path:  /content/drive/MyDrive/Temp Folder/Dataset/Raw CSV/Questionnaire/Weight History - Youth.csv
#
# Loop Num:  126
# Time Taken: 72.85308194160461 Second

# %%
dataset_info_df = pd.DataFrame({'name':[], 'titles':[], 'doc':[], 'xpt':[]})

for dataset in dataset_information:
  temp = pd.DataFrame({'name': dataset['name'], 'titles':dataset['titles'], 'doc': dataset['docs'], 'xpt': dataset['xpts']})
  dataset_info_df = pd.concat([dataset_info_df, temp], axis=0)

dataset_info_df = dataset_info_df.reset_index(drop=True)
dataset_info_df

dataset_info_df = dataset_info_df.merge(pd.DataFrame(xpt_paths), how='left', on=['name', 'titles'])
dataset_info_df = dataset_info_df.rename(columns={'file_path':'xpt_path'})

dataset_info_df = dataset_info_df.merge(pd.DataFrame(csv_paths), how='left', on=['name', 'titles'])
dataset_info_df = dataset_info_df.rename(columns={'file_path':'csv_path'})

dataset_info_df.to_excel(base_path + '/Dataset/' + 'Dataset Info.xlsx', index=False)
dataset_info_df
# Out:
#               name                                             titles  \
# 0     Demographics           Demographic Variables and Sample Weights
# 1          Dietary    Dietary Interview - Individual Foods, First Day
# 2          Dietary   Dietary Interview - Individual Foods, Second Day
# 3          Dietary  Dietary Interview - Total Nutrient Intakes, Fi...
# 4          Dietary  Dietary Interview - Total Nutrient Intakes, Se...
# ..             ...                                                ...
# 121  Questionnaire                       Smoking - Recent Tobacco Use
# 122  Questionnaire                Smoking - Secondhand Smoke Exposure
# 123  Questionnaire                                  Volatile Toxicant
# 124  Questionnaire                                     Weight History
# 125  Questionnaire                             Weight History - Youth
#
#                                      doc                                  xpt  \
# 0      /Nchs/Nhanes/2017-2018/DEMO_J.htm    /Nchs/Nhanes/2017-2018/DEMO_J.XPT
# 1    /Nchs/Nhanes/2017-2018/DR1IFF_J.htm  /Nchs/Nhanes/2017-2018/DR1IFF_J.XPT
# 2    /Nchs/Nhanes/2017-2018/DR2IFF_J.htm  /Nchs/Nhanes/2017-2018/DR2IFF_J.XPT
# 3    /Nchs/Nhanes/2017-2018/DR1TOT_J.htm  /Nchs/Nhanes/2017-2018/DR1TOT_J.XPT
# 4    /Nchs/Nhanes/2017-2018/DR2TOT_J.htm  /Nchs/Nhanes/2017-2018/DR2TOT_J.XPT
# ..                                   ...                                  ...
# 121  /Nchs/Nhanes/2017-2018/SMQRTU_J.htm  /Nchs/Nhanes/2017-2018/SMQRTU_J.XPT
# 122  /Nchs/Nhanes/2017-2018/SMQSHS_J.htm  /Nchs/Nhanes/2017-2018/SMQSHS_J.XPT
# 123     /Nchs/Nhanes/2017-2018/VTQ_J.htm     /Nchs/Nhanes/2017-2018/VTQ_J.XPT
# 124     /Nchs/Nhanes/2017-2018/WHQ_J.htm     /Nchs/Nhanes/2017-2018/WHQ_J.XPT
# 125  /Nchs/Nhanes/2017-2018/WHQMEC_J.htm  /Nchs/Nhanes/2017-2018/WHQMEC_J.XPT
#
#                                               xpt_path  \
# 0    /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 1    /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 2    /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 3    /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 4    /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# ..                                                 ...
# 121  /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 122  /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 123  /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 124  /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 125  /content/drive/MyDrive/Temp Folder/Dataset/Raw...
#
#                                               csv_path
# 0    /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 1    /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 2    /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 3    /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 4    /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# ..                                                 ...
# 121  /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 122  /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 123  /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 124  /content/drive/MyDrive/Temp Folder/Dataset/Raw...
# 125  /content/drive/MyDrive/Temp Folder/Dataset/Raw...
#
# [126 rows x 6 columns]

# %%
end_overall = time.time()
duration = end_overall - start_overall
print("Time Taken:", duration, "Second")
# Out:
# Time Taken: 869.2555108070374 Second
