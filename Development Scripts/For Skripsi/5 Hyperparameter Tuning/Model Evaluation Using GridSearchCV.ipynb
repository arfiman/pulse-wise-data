# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import random

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import layers, models
import tensorflow_datasets as tfds
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, ClassifierMixin

import warnings
warnings.filterwarnings('ignore')

drive_path = '/content/drive/MyDrive/Kuliah/Tugas Akhir/Final Project Shared Folder'
data_path = "Dataset/Data Versioning/"
model_path = "Model/ML Model/"
data_version = "Trained_V2-3.csv"
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_raw = pd.read_csv(os.path.join(drive_path, data_path+data_version), index_col = 0)
try:
  df_raw = df_raw.set_index('SEQN', drop=True)
  df_raw = df_raw.drop(columns = "Unnamed: 0")
except:
  pass

df_raw.head()
# Out:
#          Dieta1_DRDINT  Dieta1_DR1TFIBE  Quest21_SLQ300  Quest19_PAD660  \
# SEQN
# 93705.0              1                0               2               2
# 93708.0              1                2               2               2
# 93709.0              0                2               2               1
# 93711.0              1                3               1               0
# 93713.0              1                1               2               1
#
#          Quest19_PAQ635  Dieta1_DR1TCHOL  Quest19_PAQ655  Dieta1_DR1TSFAT  \
# SEQN
# 93705.0             2.0                0               2                1
# 93708.0             2.0                0               2                1
# 93709.0             2.0                2               1                2
# 93711.0             1.0                3               3                3
# 93713.0             1.0                1               2                3
#
#          Dieta1_DR1TKCAL  Exami2_BMXBMI  ...  Quest1_ALQ111  Quest10_ECQ020  \
# SEQN                                     ...
# 93705.0                0              2  ...            1.0             9.0
# 93708.0                0              0  ...            2.0             9.0
# 93709.0                1              3  ...            9.0             9.0
# 93711.0                3              0  ...            1.0             9.0
# 93713.0                2              0  ...            1.0             9.0
#
#          Quest16_MCQ220  Quest4_CBD121  Quest16_MCQ366A  Labor2_URDFLOW1  \
# SEQN
# 93705.0             2.0   7.500000e+01              2.0            1.204
# 93708.0             2.0   5.397605e-79              2.0            0.500
# 93709.0             2.0   4.000000e+01              2.0            0.107
# 93711.0             2.0   8.570000e+02              2.0            0.605
# 93713.0             2.0   4.000000e+01              2.0            0.706
#
#          Demog1_DMDEDUC  Quest9_DLQ050  Quest20_PFQ061C  Quest16_MCQ160B
# SEQN
# 93705.0             2.0            2.0              1.0              2.0
# 93708.0             1.0            2.0              2.0              2.0
# 93709.0             4.0            1.0              9.0              2.0
# 93711.0             5.0            2.0              9.0              2.0
# 93713.0             3.0            2.0              1.0              2.0
#
# [5 rows x 86 columns]

# %%
def get_categorical(df):
    categorical = []
    for col in df.columns.tolist():
        try:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': model_var[model_var['model_var_name'] ==  col]['desc'].values[0],
                    'column': col,
                    'possible_values': df[col].unique().tolist()}
                            )
        except Exception as error:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': None,
                    'column': col,
                    'possible_values': df[col].unique().tolist()})
            # print(f'{col} error: {error}')
    return categorical

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTENC, SMOTE

def prep_data(df):
  X = df.copy().drop(columns=['Quest16_MCQ160B'])
  y = df['Quest16_MCQ160B']

  y = y.replace({2: 0})
  y = y.replace({9: 0})

  y = y.astype(int)

  categorical_summary = get_categorical(X)
  categorical_cols = [True if data_col in [col['column'] for col in categorical_summary] else False for data_col in X.columns.tolist()]

  X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42)

  # Instantiate the SMOTE oversampler
  smotenc = SMOTENC(
      categorical_features=categorical_cols,
      sampling_strategy='auto',
      random_state=37
    )

  # Apply SMOTE to generate synthetic samples
  X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

  scaler = StandardScaler()
  X_resampled.iloc[:, 28:] = scaler.fit_transform(X_resampled.iloc[:, 28:])
  X_val.iloc[:, 28:] = scaler.transform(X_val.iloc[:, 28:])

  X_resampled = np.array(X_resampled).reshape(X_resampled.shape[0], X_resampled.shape[1], 1)
  X_val = np.array(X_val).reshape(X_val.shape[0], X_val.shape[1], 1)

  print("Train: ", X_resampled.shape, " ", y_resampled.shape)
  print("Val: ", X_val.shape, " ", y_val.shape)
  print("Column Used: ", X.columns.tolist())

  return X_resampled, X_val, y_resampled, y_val

X_train, X_val, y_train, y_val = prep_data(df_raw)
input_shape = X_train.shape[1:]

print(y_train.value_counts())
print(y_val.value_counts())
# Out:
# Train:  (8050, 85, 1)   (8050,)
# Val:  (1393, 85, 1)   (1393,)
# Column Used:  ['Dieta1_DRDINT', 'Dieta1_DR1TFIBE', 'Quest21_SLQ300', 'Quest19_PAD660', 'Quest19_PAQ635', 'Dieta1_DR1TCHOL', 'Quest19_PAQ655', 'Dieta1_DR1TSFAT', 'Dieta1_DR1TKCAL', 'Exami2_BMXBMI', 'Dieta1_DR1TSUGR', 'Quest21_SLQ320', 'Quest21_SLQ330', 'Quest19_PAD615', 'Quest21_SLD012', 'Quest21_SLD013', 'Dieta1_DR1DAY', 'Quest6_DED120', 'Quest19_PAQ610', 'Quest6_DED125', 'Dieta1_DR1TPROT', 'Quest19_PAQ640', 'Dieta1_DR1TPFAT', 'Dieta1_DR1TMFAT', 'Dieta1_DR1TCALC', 'Dieta1_DR1TCARB', 'Dieta1_DR1TTFAT', 'Quest19_PAD645', 'Exami1_BPXPLS', 'Demog1_RIDRETH3', 'Demog1_DMDHHSZA', 'Demog1_DMDHHSZE', 'Quest14_INQ020', 'Quest18_OCQ210', 'Demog1_INDIN2', 'Quest12_HEQ030', 'Quest22_SMQ900', 'Exami2_BMXHT', 'Quest3_CDQ009', 'Quest3_CDQ010', 'Exami2_BMXWT', 'Quest3_CDQ008', 'Quest20_PFQ061H', 'Quest7_DIQ010', 'Quest20_PFQ061B', 'Labor1_LBDTCSI', 'Quest17_DPQ040', 'Demog1_RIAGENDR', 'Labor2_URDTIME1', 'Quest22_SMQ890', 'Demog1_DMDMARTL', 'Exami1_BPXPULS', 'Exami1_DiaPulse', 'Demog1_DMDFMSIZ', 'Quest16_MCQ300C', 'Demog1_RIDAGEYR', 'Demog1_DMDHHSZB', 'Labor1_LBXTC', 'Exami1_SysPulse', 'Quest16_MCQ010', 'Quest16_MCQ366B', 'Quest22_SMQ020', 'Quest14_IND235', 'Quest11_HIQ011', 'Quest20_PFQ020', 'Labor2_URXVOL1', 'Quest4_CBD111', 'Quest15_KIQ026', 'Quest17_DPQ020', 'Quest16_MCQ300A', 'Quest14_INQ012', 'Quest17_DPQ030', 'Quest15_KIQ022', 'Quest2_BPQ020', 'Demog1_DMDHHSIZ', 'Quest12_HEQ010', 'Quest1_ALQ111', 'Quest10_ECQ020', 'Quest16_MCQ220', 'Quest4_CBD121', 'Quest16_MCQ366A', 'Labor2_URDFLOW1', 'Demog1_DMDEDUC', 'Quest9_DLQ050', 'Quest20_PFQ061C']
# Quest16_MCQ160B
# 0    4025
# 1    4025
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1343
# 1      50
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTENC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

def prep_data_cross_validation(df, num_folds=5):
  X = df.copy().drop(columns=['Quest16_MCQ160B'])
  y = df['Quest16_MCQ160B']

  y = y.replace({2: 0})
  y = y.replace({9: 0})

  y = y.astype(int)

  categorical_summary = get_categorical(X)
  categorical_cols = [True if data_col in [col['column'] for col in categorical_summary] else False for data_col in X.columns.tolist()]

  kf = KFold(n_splits=num_folds, shuffle=True, random_state=37)

  for train_index, val_index in kf.split(X):
    X_train, X_val, y_train, y_val = X.iloc[train_index, :], X.iloc[val_index, :], y.iloc[train_index], y.iloc[val_index]\

    # Instantiate the SMOTE oversampler
    smotenc = SMOTENC(
        categorical_features=categorical_cols,
        sampling_strategy='auto',
        random_state=37
      )

    # Apply SMOTE to generate synthetic samples
    X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

    scaler = StandardScaler()
    X_resampled.iloc[:, 28:] = scaler.fit_transform(X_resampled.iloc[:, 28:])
    X_val.iloc[:, 28:] = scaler.transform(X_val.iloc[:, 28:])

    X_resampled = np.array(X_resampled).reshape(X_resampled.shape[0], X_resampled.shape[1], 1)
    X_val = np.array(X_val).reshape(X_val.shape[0], X_val.shape[1], 1)

    yield X_resampled, X_val, y_resampled, y_val

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data=()):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data
        self.logs = {}

    def on_epoch_end(self, epoch, logs={}):
        if not self.validation_data:
            raise RuntimeError("Requires validation_data.")
        if self.logs.get('roc_auc', None) == None:
          self.logs['roc_auc'] = []
        if self.logs.get('f1score', None) == None:
          self.logs['f1score'] = []

        X_val, y_val = self.validation_data
        y_proba = self.model.predict(X_val, verbose=0)
        y_pred = np.argmax(y_proba, axis=1)

        # Convert one-hot encoded labels to class labels
        # y_pred =  [1 if preds[1] >= 2.46069816967065e-06 else 0 for preds in y_pred]

        # Compute Metrics score
        f1score = f1_score(y_val, y_pred, average='weighted')
        roc_auc = roc_auc_score(y_val, y_pred, average='weighted')

        # Add Metrics score to logs
        self.logs['roc_auc'].append(roc_auc)
        self.logs['f1score'].append(f1score)

# %%
def build_model():
  model = models.Sequential()
  model.add(layers.Input(input_shape))
  model.add(layers.Conv1D(filters=16, kernel_size=3, activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(units=128, activation='relu'))
  model.add(layers.Dense(2, activation='softmax'))

  # Compile the model
  model.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
  )

  return model

# %%
tf.random.set_seed(37)
random.seed(37)

loss = []
accuracy = []
f1score = []
auc = []
train_loss = []
train_accuracy = []
train_f1score = []
train_auc = []

for X_train, X_val, y_train, y_val in prep_data_cross_validation(df_raw, num_folds=4):
  print(y_train.value_counts())
  print(y_val.value_counts())

  model = build_model()

  metrics_callback = MetricsCallback(validation_data=(X_val, y_val))
  train_metrics_callback = MetricsCallback(validation_data=(X_train, y_train))

  model.fit(X_train, y_train, epochs=20, validation_data=(X_val, y_val), callbacks=[metrics_callback, train_metrics_callback])
  _loss, _accuracy = model.evaluate(X_val, y_val, verbose=0)
  loss.append(_loss)
  accuracy.append(_accuracy)
  f1score.append(metrics_callback.logs.get('f1score'))
  auc.append(metrics_callback.logs.get('roc_auc'))

  _train_loss, _train_accuracy = model.evaluate(X_train, y_train, verbose=0)
  train_loss.append(_train_loss)
  train_accuracy.append(_train_accuracy)
  train_f1score.append(train_metrics_callback.logs.get('f1score'))
  train_auc.append(train_metrics_callback.logs.get('roc_auc'))


print()
model.summary()
# Out:
# Quest16_MCQ160B
# 0    4022
# 1    4022
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1346
# 1      47
# Name: count, dtype: int64
# Epoch 1/20
# 252/252 [==============================] - 3s 10ms/step - loss: 0.1738 - accuracy: 0.9398 - val_loss: 0.1430 - val_accuracy: 0.9454
# Epoch 2/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.1096 - accuracy: 0.9664 - val_loss: 0.1564 - val_accuracy: 0.9397
# Epoch 3/20
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0810 - accuracy: 0.9741 - val_loss: 0.1625 - val_accuracy: 0.9390
# Epoch 4/20
# 252/252 [==============================] - 4s 15ms/step - loss: 0.0605 - accuracy: 0.9802 - val_loss: 0.1528 - val_accuracy: 0.9433
# Epoch 5/20
# 252/252 [==============================] - 2s 10ms/step - loss: 0.0504 - accuracy: 0.9861 - val_loss: 0.1663 - val_accuracy: 0.9447
# Epoch 6/20
# 252/252 [==============================] - 2s 10ms/step - loss: 0.0324 - accuracy: 0.9896 - val_loss: 0.1653 - val_accuracy: 0.9476
# Epoch 7/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0278 - accuracy: 0.9908 - val_loss: 0.1975 - val_accuracy: 0.9347
# Epoch 8/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0197 - accuracy: 0.9945 - val_loss: 0.2053 - val_accuracy: 0.9440
# Epoch 9/20
# 252/252 [==============================] - 4s 16ms/step - loss: 0.0140 - accuracy: 0.9953 - val_loss: 0.2011 - val_accuracy: 0.9447
# Epoch 10/20
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.2436 - val_accuracy: 0.9426
# Epoch 11/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0068 - accuracy: 0.9988 - val_loss: 0.2370 - val_accuracy: 0.9548
# Epoch 12/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.2627 - val_accuracy: 0.9447
# Epoch 13/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.2635 - val_accuracy: 0.9490
# Epoch 14/20
# 252/252 [==============================] - 4s 15ms/step - loss: 7.7628e-04 - accuracy: 1.0000 - val_loss: 0.2852 - val_accuracy: 0.9505
# Epoch 15/20
# 252/252 [==============================] - 3s 13ms/step - loss: 4.3528e-04 - accuracy: 1.0000 - val_loss: 0.2967 - val_accuracy: 0.9476
# Epoch 16/20
# 252/252 [==============================] - 3s 10ms/step - loss: 3.1751e-04 - accuracy: 1.0000 - val_loss: 0.3028 - val_accuracy: 0.9483
# Epoch 17/20
# 252/252 [==============================] - 2s 10ms/step - loss: 2.5856e-04 - accuracy: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9469
# Epoch 18/20
# 252/252 [==============================] - 2s 10ms/step - loss: 2.0332e-04 - accuracy: 1.0000 - val_loss: 0.3236 - val_accuracy: 0.9440
# Epoch 19/20
# 252/252 [==============================] - 3s 13ms/step - loss: 1.7396e-04 - accuracy: 1.0000 - val_loss: 0.3273 - val_accuracy: 0.9476
# Epoch 20/20
# 252/252 [==============================] - 3s 14ms/step - loss: 1.4159e-04 - accuracy: 1.0000 - val_loss: 0.3330 - val_accuracy: 0.9483
# Quest16_MCQ160B
# 0    4040
# 1    4040
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1328
# 1      64
# Name: count, dtype: int64
# Epoch 1/20
# 253/253 [==============================] - 4s 12ms/step - loss: 0.1598 - accuracy: 0.9434 - val_loss: 0.2056 - val_accuracy: 0.9361
# Epoch 2/20
# 253/253 [==============================] - 4s 15ms/step - loss: 0.0957 - accuracy: 0.9697 - val_loss: 0.2263 - val_accuracy: 0.9274
# Epoch 3/20
# 253/253 [==============================] - 2s 9ms/step - loss: 0.0695 - accuracy: 0.9778 - val_loss: 0.2325 - val_accuracy: 0.9274
# Epoch 4/20
# 253/253 [==============================] - 3s 12ms/step - loss: 0.0502 - accuracy: 0.9838 - val_loss: 0.2243 - val_accuracy: 0.9476
# Epoch 5/20
# 253/253 [==============================] - 2s 10ms/step - loss: 0.0380 - accuracy: 0.9877 - val_loss: 0.2690 - val_accuracy: 0.9375
# Epoch 6/20
# 253/253 [==============================] - 3s 13ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.2862 - val_accuracy: 0.9519
# Epoch 7/20
# 253/253 [==============================] - 4s 14ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.3215 - val_accuracy: 0.9454
# Epoch 8/20
# 253/253 [==============================] - 2s 9ms/step - loss: 0.0102 - accuracy: 0.9976 - val_loss: 0.3718 - val_accuracy: 0.9440
# Epoch 9/20
# 253/253 [==============================] - 2s 9ms/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.3859 - val_accuracy: 0.9490
# Epoch 10/20
# 253/253 [==============================] - 2s 9ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.3925 - val_accuracy: 0.9411
# Epoch 11/20
# 253/253 [==============================] - 3s 12ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.4202 - val_accuracy: 0.9461
# Epoch 12/20
# 253/253 [==============================] - 4s 15ms/step - loss: 9.1433e-04 - accuracy: 1.0000 - val_loss: 0.4620 - val_accuracy: 0.9490
# Epoch 13/20
# 253/253 [==============================] - 2s 10ms/step - loss: 4.9891e-04 - accuracy: 1.0000 - val_loss: 0.4792 - val_accuracy: 0.9476
# Epoch 14/20
# 253/253 [==============================] - 2s 10ms/step - loss: 3.5682e-04 - accuracy: 1.0000 - val_loss: 0.4886 - val_accuracy: 0.9461
# Epoch 15/20
# 253/253 [==============================] - 2s 9ms/step - loss: 2.8047e-04 - accuracy: 1.0000 - val_loss: 0.4942 - val_accuracy: 0.9461
# Epoch 16/20
# 253/253 [==============================] - 3s 12ms/step - loss: 2.2271e-04 - accuracy: 1.0000 - val_loss: 0.5051 - val_accuracy: 0.9454
# Epoch 17/20
# 253/253 [==============================] - 4s 15ms/step - loss: 1.8266e-04 - accuracy: 1.0000 - val_loss: 0.5303 - val_accuracy: 0.9468
# Epoch 18/20
# 253/253 [==============================] - 3s 10ms/step - loss: 1.4887e-04 - accuracy: 1.0000 - val_loss: 0.5402 - val_accuracy: 0.9461
# Epoch 19/20
# 253/253 [==============================] - 2s 9ms/step - loss: 1.2462e-04 - accuracy: 1.0000 - val_loss: 0.5527 - val_accuracy: 0.9476
# Epoch 20/20
# 253/253 [==============================] - 2s 9ms/step - loss: 1.0298e-04 - accuracy: 1.0000 - val_loss: 0.5595 - val_accuracy: 0.9454
# Quest16_MCQ160B
# 0    4017
# 1    4017
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1351
# 1      41
# Name: count, dtype: int64
# Epoch 1/20
# 252/252 [==============================] - 4s 11ms/step - loss: 0.1669 - accuracy: 0.9432 - val_loss: 0.1519 - val_accuracy: 0.9411
# Epoch 2/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.1089 - accuracy: 0.9625 - val_loss: 0.1322 - val_accuracy: 0.9468
# Epoch 3/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0814 - accuracy: 0.9744 - val_loss: 0.1176 - val_accuracy: 0.9569
# Epoch 4/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0614 - accuracy: 0.9792 - val_loss: 0.1613 - val_accuracy: 0.9404
# Epoch 5/20
# 252/252 [==============================] - 3s 13ms/step - loss: 0.0475 - accuracy: 0.9836 - val_loss: 0.1438 - val_accuracy: 0.9511
# Epoch 6/20
# 252/252 [==============================] - 4s 14ms/step - loss: 0.0336 - accuracy: 0.9888 - val_loss: 0.1357 - val_accuracy: 0.9626
# Epoch 7/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0227 - accuracy: 0.9925 - val_loss: 0.1544 - val_accuracy: 0.9569
# Epoch 8/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.1665 - val_accuracy: 0.9562
# Epoch 9/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0096 - accuracy: 0.9976 - val_loss: 0.1912 - val_accuracy: 0.9511
# Epoch 10/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.1830 - val_accuracy: 0.9662
# Epoch 11/20
# 252/252 [==============================] - 5s 20ms/step - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.2019 - val_accuracy: 0.9533
# Epoch 12/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.2245 - val_accuracy: 0.9497
# Epoch 13/20
# 252/252 [==============================] - 2s 9ms/step - loss: 9.0005e-04 - accuracy: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.9533
# Epoch 14/20
# 252/252 [==============================] - 2s 8ms/step - loss: 5.6482e-04 - accuracy: 1.0000 - val_loss: 0.2336 - val_accuracy: 0.9569
# Epoch 15/20
# 252/252 [==============================] - 2s 9ms/step - loss: 3.7149e-04 - accuracy: 1.0000 - val_loss: 0.2433 - val_accuracy: 0.9598
# Epoch 16/20
# 252/252 [==============================] - 3s 13ms/step - loss: 2.9012e-04 - accuracy: 1.0000 - val_loss: 0.2493 - val_accuracy: 0.9576
# Epoch 17/20
# 252/252 [==============================] - 4s 14ms/step - loss: 2.3344e-04 - accuracy: 1.0000 - val_loss: 0.2512 - val_accuracy: 0.9583
# Epoch 18/20
# 252/252 [==============================] - 2s 9ms/step - loss: 1.8580e-04 - accuracy: 1.0000 - val_loss: 0.2561 - val_accuracy: 0.9583
# Epoch 19/20
# 252/252 [==============================] - 2s 9ms/step - loss: 1.5657e-04 - accuracy: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.9591
# Epoch 20/20
# 252/252 [==============================] - 2s 9ms/step - loss: 1.2982e-04 - accuracy: 1.0000 - val_loss: 0.2673 - val_accuracy: 0.9576
# Quest16_MCQ160B
# 0    4025
# 1    4025
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1343
# 1      49
# Name: count, dtype: int64
# Epoch 1/20
# 252/252 [==============================] - 3s 10ms/step - loss: 0.1568 - accuracy: 0.9476 - val_loss: 0.2894 - val_accuracy: 0.8879
# Epoch 2/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0999 - accuracy: 0.9696 - val_loss: 0.2025 - val_accuracy: 0.9332
# Epoch 3/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0764 - accuracy: 0.9755 - val_loss: 0.2297 - val_accuracy: 0.9310
# Epoch 4/20
# 252/252 [==============================] - 3s 12ms/step - loss: 0.0558 - accuracy: 0.9821 - val_loss: 0.2486 - val_accuracy: 0.9303
# Epoch 5/20
# 252/252 [==============================] - 4s 15ms/step - loss: 0.0452 - accuracy: 0.9842 - val_loss: 0.2203 - val_accuracy: 0.9318
# Epoch 6/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0291 - accuracy: 0.9899 - val_loss: 0.2664 - val_accuracy: 0.9303
# Epoch 7/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0212 - accuracy: 0.9942 - val_loss: 0.2552 - val_accuracy: 0.9432
# Epoch 8/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0132 - accuracy: 0.9965 - val_loss: 0.2744 - val_accuracy: 0.9447
# Epoch 9/20
# 252/252 [==============================] - 2s 10ms/step - loss: 0.0072 - accuracy: 0.9985 - val_loss: 0.3014 - val_accuracy: 0.9310
# Epoch 10/20
# 252/252 [==============================] - 5s 20ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.3213 - val_accuracy: 0.9411
# Epoch 11/20
# 252/252 [==============================] - 3s 11ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.3486 - val_accuracy: 0.9303
# Epoch 12/20
# 252/252 [==============================] - 2s 9ms/step - loss: 9.8735e-04 - accuracy: 0.9999 - val_loss: 0.3577 - val_accuracy: 0.9397
# Epoch 13/20
# 252/252 [==============================] - 2s 10ms/step - loss: 6.4943e-04 - accuracy: 0.9999 - val_loss: 0.3717 - val_accuracy: 0.9404
# Epoch 14/20
# 252/252 [==============================] - 2s 9ms/step - loss: 5.0779e-04 - accuracy: 0.9999 - val_loss: 0.3840 - val_accuracy: 0.9404
# Epoch 15/20
# 252/252 [==============================] - 4s 17ms/step - loss: 4.3163e-04 - accuracy: 0.9999 - val_loss: 0.3864 - val_accuracy: 0.9382
# Epoch 16/20
# 252/252 [==============================] - 2s 9ms/step - loss: 3.5437e-04 - accuracy: 1.0000 - val_loss: 0.4048 - val_accuracy: 0.9389
# Epoch 17/20
# 252/252 [==============================] - 2s 10ms/step - loss: 2.9256e-04 - accuracy: 1.0000 - val_loss: 0.4150 - val_accuracy: 0.9389
# Epoch 18/20
# 252/252 [==============================] - 2s 10ms/step - loss: 2.4913e-04 - accuracy: 1.0000 - val_loss: 0.4228 - val_accuracy: 0.9397
# Epoch 19/20
# 252/252 [==============================] - 2s 9ms/step - loss: 2.1941e-04 - accuracy: 1.0000 - val_loss: 0.4319 - val_accuracy: 0.9404
# Epoch 20/20
# 252/252 [==============================] - 4s 15ms/step - loss: 1.9392e-04 - accuracy: 1.0000 - val_loss: 0.4426 - val_accuracy: 0.9389
#
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 83, 16)            64
#
#  flatten_8 (Flatten)         (None, 1328)              0
#
#  dense_16 (Dense)            (None, 128)               170112
#
#  dense_17 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 170434 (665.76 KB)
# Trainable params: 170434 (665.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Evaluate Model

print(loss)
print(accuracy)
print(f1score)
print(auc)

print("Training Loss: " + str(np.mean(train_loss)*100) + "%")
print("Training Accuracy: " + str(np.mean(train_accuracy)*100) + "%")
print("Training F1 Score: " + str(np.mean(np.array(train_f1score)[:, -1])*100) + "%")
print("Training AUC: " + str(np.mean(np.array(train_auc)[:, -1])*100) + "%")

print("Loss: " + str(np.mean(loss)*100) + "%")
print("Accuracy: " + str(np.mean(accuracy)*100) + "%")
print("F1 Score: " + str(np.mean(np.array(f1score)[:, -1])*100) + "%")
print("AUC: " + str(np.mean(np.array(auc)[:, -1])*100) + "%")
# Out:
# [0.3330318331718445, 0.5595042109489441, 0.2672816514968872, 0.4426443576812744]
# [0.9483129978179932, 0.9454023241996765, 0.9576149582862854, 0.9389367699623108]
# [[0.9479627859615045, 0.9455596279877266, 0.9451042237810726, 0.9451792133858918, 0.9444366962162087, 0.9478611965508691, 0.9408128858772862, 0.9445682008022055, 0.9455475727774141, 0.9442287493204775, 0.9506055526283529, 0.9455475727774141, 0.9476463975913769, 0.9485381303053302, 0.9467604695581312, 0.9472027368721523, 0.9463195410066884, 0.9445682008022055, 0.9467604695581312, 0.9472027368721523], [0.9388534172549535, 0.9314621961470951, 0.931041939385174, 0.940159704020232, 0.9335272659803925, 0.9383220038218102, 0.9380434075063808, 0.9341857426898353, 0.9373633539181467, 0.9352208222406756, 0.9378219127499774, 0.9381878946499524, 0.9372563405112672, 0.9355373361417129, 0.9355373361417129, 0.9358732877490701, 0.9359911482021919, 0.9355373361417129, 0.9364467085837541, 0.9350852062824458], [0.946647610418592, 0.9480359732644238, 0.953297261780732, 0.9470608484051468, 0.9532480295363329, 0.9588944536221883, 0.9552428510536771, 0.9541897591256053, 0.9532480295363329, 0.9589859343869453, 0.9541026827104723, 0.9518729715815192, 0.9546031350287035, 0.9552428510536771, 0.9564107776620164, 0.9550725201438227, 0.9567347560185545, 0.9567347560185545, 0.957193709346877, 0.9562779482384466], [0.914523466422873, 0.9379150392956388, 0.9394743187846636, 0.9357259691565963, 0.9360909164581921, 0.9361901200928063, 0.941774236262073, 0.9438413529431483, 0.9361526133484982, 0.9416590866265825, 0.9352447184051286, 0.9402361375199135, 0.9406636032189875, 0.9406636032189875, 0.9393837236095293, 0.9403619578495084, 0.9398095221310272, 0.9407934044558193, 0.941225768669121, 0.9398095221310272]]
# [[0.6329629161265846, 0.6607916284657456, 0.6604201574404855, 0.6010480225095635, 0.5709904840188422, 0.6032768486611235, 0.617124023900604, 0.5808858398406626, 0.5915241377130032, 0.5904097246372231, 0.5761910783724826, 0.5915241377130032, 0.5834861370174829, 0.5842290790680028, 0.5827431949669628, 0.5831146659922228, 0.5823717239417028, 0.5808858398406626, 0.5827431949669628, 0.5831146659922228], [0.6839231927710843, 0.6496611445783133, 0.6422251506024097, 0.5932793674698795, 0.5880082831325302, 0.5509224397590361, 0.5847138554216867, 0.5542168674698795, 0.5568524096385542, 0.5824548192771084, 0.5776543674698795, 0.5642884036144579, 0.5635353915662651, 0.5553463855421686, 0.5553463855421686, 0.5624058734939759, 0.5557228915662652, 0.5553463855421686, 0.5560993975903614, 0.5549698795180723], [0.6030763120362513, 0.5587369789315954, 0.5520933003556535, 0.6263562672636349, 0.6200826849127115, 0.5905291473344045, 0.5875683775342564, 0.5753732555830369, 0.6200826849127115, 0.556904551280894, 0.609367947861566, 0.6075174667364734, 0.621192973587767, 0.5875683775342564, 0.5772237367081294, 0.5761134480330738, 0.6001335957104944, 0.6001335957104944, 0.600503691935513, 0.599763499485476], [0.6862947710729862, 0.5917683529107846, 0.659473916148738, 0.580447368820946, 0.5713601896454784, 0.5902791496345374, 0.5576534411232847, 0.5780616043885909, 0.5808196696400079, 0.5762001002932818, 0.5706155880073548, 0.565623717841567, 0.5659960186606287, 0.5659960186606287, 0.5648791162034433, 0.5750831978360964, 0.5652514170225051, 0.5754554986551582, 0.57582779947422, 0.5652514170225051]]
# Training Loss: 0.011894910676346626%
# Training Accuracy: 100.0%
# Training F1 Score: 100.0%
# Training AUC: 100.0%
# Loss: 40.061551332473755%
# Accuracy: 94.75667625665665%
# F1 Score: 94.4593853381018%
# AUC: 57.57748655045691%

# %%
model = build_model()

model.summary()

X_train, X_val, y_train, y_val = prep_data(df_raw)


metrics_callback = MetricsCallback(validation_data=(X_val, y_val))
train_metrics_callback = MetricsCallback(validation_data=(X_train, y_train))

history = model.fit(X_train, y_train, epochs=20, validation_data=(X_val, y_val), callbacks=[metrics_callback, train_metrics_callback])
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_9 (Conv1D)           (None, 83, 16)            64
#
#  flatten_9 (Flatten)         (None, 1328)              0
#
#  dense_18 (Dense)            (None, 128)               170112
#
#  dense_19 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 170434 (665.76 KB)
# Trainable params: 170434 (665.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Train:  (8050, 85, 1)   (8050,)
# Val:  (1393, 85, 1)   (1393,)
# Column Used:  ['Dieta1_DRDINT', 'Dieta1_DR1TFIBE', 'Quest21_SLQ300', 'Quest19_PAD660', 'Quest19_PAQ635', 'Dieta1_DR1TCHOL', 'Quest19_PAQ655', 'Dieta1_DR1TSFAT', 'Dieta1_DR1TKCAL', 'Exami2_BMXBMI', 'Dieta1_DR1TSUGR', 'Quest21_SLQ320', 'Quest21_SLQ330', 'Quest19_PAD615', 'Quest21_SLD012', 'Quest21_SLD013', 'Dieta1_DR1DAY', 'Quest6_DED120', 'Quest19_PAQ610', 'Quest6_DED125', 'Dieta1_DR1TPROT', 'Quest19_PAQ640', 'Dieta1_DR1TPFAT', 'Dieta1_DR1TMFAT', 'Dieta1_DR1TCALC', 'Dieta1_DR1TCARB', 'Dieta1_DR1TTFAT', 'Quest19_PAD645', 'Exami1_BPXPLS', 'Demog1_RIDRETH3', 'Demog1_DMDHHSZA', 'Demog1_DMDHHSZE', 'Quest14_INQ020', 'Quest18_OCQ210', 'Demog1_INDIN2', 'Quest12_HEQ030', 'Quest22_SMQ900', 'Exami2_BMXHT', 'Quest3_CDQ009', 'Quest3_CDQ010', 'Exami2_BMXWT', 'Quest3_CDQ008', 'Quest20_PFQ061H', 'Quest7_DIQ010', 'Quest20_PFQ061B', 'Labor1_LBDTCSI', 'Quest17_DPQ040', 'Demog1_RIAGENDR', 'Labor2_URDTIME1', 'Quest22_SMQ890', 'Demog1_DMDMARTL', 'Exami1_BPXPULS', 'Exami1_DiaPulse', 'Demog1_DMDFMSIZ', 'Quest16_MCQ300C', 'Demog1_RIDAGEYR', 'Demog1_DMDHHSZB', 'Labor1_LBXTC', 'Exami1_SysPulse', 'Quest16_MCQ010', 'Quest16_MCQ366B', 'Quest22_SMQ020', 'Quest14_IND235', 'Quest11_HIQ011', 'Quest20_PFQ020', 'Labor2_URXVOL1', 'Quest4_CBD111', 'Quest15_KIQ026', 'Quest17_DPQ020', 'Quest16_MCQ300A', 'Quest14_INQ012', 'Quest17_DPQ030', 'Quest15_KIQ022', 'Quest2_BPQ020', 'Demog1_DMDHHSIZ', 'Quest12_HEQ010', 'Quest1_ALQ111', 'Quest10_ECQ020', 'Quest16_MCQ220', 'Quest4_CBD121', 'Quest16_MCQ366A', 'Labor2_URDFLOW1', 'Demog1_DMDEDUC', 'Quest9_DLQ050', 'Quest20_PFQ061C']
# Epoch 1/20
# 252/252 [==============================] - 3s 11ms/step - loss: 0.1681 - accuracy: 0.9395 - val_loss: 0.2022 - val_accuracy: 0.9218
# Epoch 2/20
# 252/252 [==============================] - 3s 12ms/step - loss: 0.1033 - accuracy: 0.9672 - val_loss: 0.1742 - val_accuracy: 0.9354
# Epoch 3/20
# 252/252 [==============================] - 4s 14ms/step - loss: 0.0758 - accuracy: 0.9764 - val_loss: 0.1847 - val_accuracy: 0.9497
# Epoch 4/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0608 - accuracy: 0.9794 - val_loss: 0.2146 - val_accuracy: 0.9196
# Epoch 5/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0414 - accuracy: 0.9860 - val_loss: 0.2046 - val_accuracy: 0.9404
# Epoch 6/20
# 252/252 [==============================] - 2s 10ms/step - loss: 0.0296 - accuracy: 0.9887 - val_loss: 0.1924 - val_accuracy: 0.9454
# Epoch 7/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0199 - accuracy: 0.9945 - val_loss: 0.2449 - val_accuracy: 0.9505
# Epoch 8/20
# 252/252 [==============================] - 4s 17ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.2455 - val_accuracy: 0.9426
# Epoch 9/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.2616 - val_accuracy: 0.9433
# Epoch 10/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0085 - accuracy: 0.9983 - val_loss: 0.2847 - val_accuracy: 0.9404
# Epoch 11/20
# 252/252 [==============================] - 2s 10ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.3040 - val_accuracy: 0.9440
# Epoch 12/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.3153 - val_accuracy: 0.9483
# Epoch 13/20
# 252/252 [==============================] - 4s 16ms/step - loss: 6.0836e-04 - accuracy: 1.0000 - val_loss: 0.3362 - val_accuracy: 0.9419
# Epoch 14/20
# 252/252 [==============================] - 3s 12ms/step - loss: 3.8765e-04 - accuracy: 1.0000 - val_loss: 0.3502 - val_accuracy: 0.9469
# Epoch 15/20
# 252/252 [==============================] - 2s 10ms/step - loss: 2.9388e-04 - accuracy: 1.0000 - val_loss: 0.3577 - val_accuracy: 0.9469
# Epoch 16/20
# 252/252 [==============================] - 2s 9ms/step - loss: 2.2904e-04 - accuracy: 1.0000 - val_loss: 0.3691 - val_accuracy: 0.9462
# Epoch 17/20
# 252/252 [==============================] - 2s 10ms/step - loss: 1.9451e-04 - accuracy: 1.0000 - val_loss: 0.3765 - val_accuracy: 0.9454
# Epoch 18/20
# 252/252 [==============================] - 4s 14ms/step - loss: 1.5896e-04 - accuracy: 1.0000 - val_loss: 0.3846 - val_accuracy: 0.9462
# Epoch 19/20
# 252/252 [==============================] - 3s 14ms/step - loss: 1.3076e-04 - accuracy: 1.0000 - val_loss: 0.3949 - val_accuracy: 0.9440
# Epoch 20/20
# 252/252 [==============================] - 2s 10ms/step - loss: 1.1155e-04 - accuracy: 1.0000 - val_loss: 0.4026 - val_accuracy: 0.9462

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_val, np.argmax(model.predict(X_val), axis=1))
# Out:
# 44/44 [==============================] - 0s 2ms/step
# array([[1310,   33],
#        [  42,    8]])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('CNN Model Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('CNN Model Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(train_metrics_callback.logs.get('f1score'), label='Training F1Score')
plt.plot(metrics_callback.logs.get('f1score'), label='Validation F1Score')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('CNN Model Training and Validation F1score')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(train_metrics_callback.logs.get('roc_auc'), label='Training ROC AUC')
plt.plot(metrics_callback.logs.get('roc_auc'), label='Validation ROC AUC')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('CNN Model Training and Validation ROC AUC')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Find Optimum Threshold

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, classification_report
import matplotlib.pyplot as plt

y_pred_prob = model.predict(X_val)[:, 1]

# Assuming y_val are the true labels and y_pred_prob are the predicted probabilities
# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Find the optimal threshold
youden_index = tpr - fpr
optimal_idx = np.argmax(youden_index)
optimal_threshold = thresholds[optimal_idx]

print(f'Optimal Threshold: {optimal_threshold}')

# Apply the optimal threshold
y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

# Evaluate performance at the optimal threshold
print(classification_report(y_val, y_pred_optimal))
print(f'ROC AUC Score: {roc_auc}')
# Out:
# 44/44 [==============================] - 0s 2ms/step
# Optimal Threshold: 1.1335868066453259e-06
#               precision    recall  f1-score   support
#
#            0       0.99      0.74      0.85      1343
#            1       0.11      0.86      0.20        50
#
#     accuracy                           0.75      1393
#    macro avg       0.55      0.80      0.52      1393
# weighted avg       0.96      0.75      0.83      1393
#
# ROC AUC Score: 0.8569173492181683

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data=()):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data
        self.logs = {}

    def on_epoch_end(self, epoch, logs={}):
        if not self.validation_data:
            raise RuntimeError("Requires validation_data.")
        if self.logs.get('roc_auc', None) == None:
          self.logs['roc_auc'] = []
        if self.logs.get('f1score', None) == None:
          self.logs['f1score'] = []

        X_val, y_val = self.validation_data
        y_proba = self.model.predict(X_val, verbose=0)
        # y_pred = np.argmax(y_proba, axis=1)

        # Convert one-hot encoded labels to class labels
        y_pred =  [1 if preds[1] >= optimal_threshold else 0 for preds in y_pred]

        # Compute Metrics score
        f1score = f1_score(y_val, y_pred, average='weighted')
        roc_auc = roc_auc_score(y_val, y_pred, average='weighted')

        # Add Metrics score to logs
        self.logs['roc_auc'].append(roc_auc)
        self.logs['f1score'].append(f1score)

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

# Evaluate Model

y_proba = model.predict(X_val)
y_pred =  [1 if preds[1] >= optimal_threshold else 0 for preds in y_proba]


accuracy = accuracy_score(y_val, y_pred)
f1score = f1_score(y_val, y_pred, average='weighted')
auc = roc_auc_score(y_val, y_pred, average='weighted')

print("Accuracy: " + str(np.mean(accuracy)*100) + "%")
print("F1 Score: " + str(np.mean(f1score)*100) + "%")
print("AUC: " + str(np.mean(auc)*100) + "%")
# Out:
# 44/44 [==============================] - 0s 2ms/step
# Accuracy: 74.87437185929649%
# F1 Score: 82.75959143757044%
# AUC: 80.23008190618017%

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_val,y_pred)
# Out:
# array([[1000,  343],
#        [   7,   43]])
