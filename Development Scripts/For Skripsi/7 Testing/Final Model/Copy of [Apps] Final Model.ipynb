# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (1.4.2)

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import random

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import layers, models
import tensorflow_datasets as tfds
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, ClassifierMixin

import warnings
warnings.filterwarnings('ignore')

drive_path = '/content/drive/MyDrive/Kuliah/Tugas Akhir/Final Project Shared Folder'
data_path = "Dataset/Data Versioning/"
model_path = "Model/ML Model/"
data_version = "Trained_App-4.csv"
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']
# Out:
# Mounted at /content/drive

# %%
import joblib

# %%
df_raw = pd.read_csv(os.path.join(drive_path, data_path+data_version), index_col = 0)
try:
  df_raw = df_raw.set_index('SEQN', drop=True)
  df_raw = df_raw.drop(columns = "Unnamed: 0")
except:
  pass

df_raw.head()
# Out:
#          Quest22_SMQ890  Quest22_SMQ900  Quest21_SLD123  Quest21_SLQ3032  \
# SEQN
# 93705.0             0.0             0.0               1                3
# 93708.0             0.0             0.0               1                2
# 93709.0             1.0             1.0               0                2
# 93711.0             0.0             0.0               1                2
# 93713.0             0.0             0.0               0                3
#
#          Dieta1_DR1TKCAL  Dieta1_DR1TPROT  Dieta1_DR1TCARB  Dieta1_DR1TSUGR  \
# SEQN
# 93705.0                0                0                0                1
# 93708.0                0                0                0                0
# 93709.0                1                2                1                2
# 93711.0                3                3                3                3
# 93713.0                2                1                1                2
#
#          Dieta1_DR1TFIBE  Dieta1_DR1TTFAT  ...  Dieta1_DR1TCALC  \
# SEQN                                       ...
# 93705.0                0                1  ...                0
# 93708.0                2                1  ...                0
# 93709.0                2                2  ...                2
# 93711.0                3                3  ...                3
# 93713.0                1                3  ...                1
#
#          Quest19_VigorousActivity  Demog1_RIDAGEYR  Exami2_BMXWT  \
# SEQN
# 93705.0                         0             66.0          79.5
# 93708.0                         0             66.0          53.5
# 93709.0                         1             75.0          88.8
# 93711.0                         1             56.0          62.1
# 93713.0                         0             67.0          74.9
#
#          Exami2_BMXHT  Exami2_BMXBMI  Quest3_CDQ008  Exami1_SysPulse  \
# SEQN
# 93705.0         158.3           31.7            0.0       157.722370
# 93708.0         150.2           23.7            0.0       139.094017
# 93709.0         151.1           38.9            0.0       118.666667
# 93711.0         170.6           21.3            0.0       101.333333
# 93713.0         178.6           23.5            0.0       104.666667
#
#          Exami1_DiaPulse  Quest16_MCQ160B
# SEQN
# 93705.0        69.961686              2.0
# 93708.0        75.777778              2.0
# 93709.0        66.666667              2.0
# 93711.0        66.666667              2.0
# 93713.0        72.000000              2.0
#
# [5 rows x 24 columns]

# %%
def get_categorical(df):
    categorical = []
    for col in df.columns.tolist():
        try:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': model_var[model_var['model_var_name'] ==  col]['desc'].values[0],
                    'column': col,
                    'possible_values': df[col].unique().tolist()}
                            )
        except Exception as error:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': None,
                    'column': col,
                    'possible_values': df[col].unique().tolist()})
            # print(f'{col} error: {error}')
    return categorical

# %%
from imblearn.over_sampling import SMOTENC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

def prep_data_cross_validation(df, num_folds=5):
  X = df.copy().drop(columns=['Quest16_MCQ160B'])
  y = df['Quest16_MCQ160B']

  y = y.replace({2: 0})
  y = y.replace({9: 0})

  y = y.astype(int)

  categorical_summary = get_categorical(X)
  categorical_cols = [True if data_col in [col['column'] for col in categorical_summary] else False for data_col in X.columns.tolist()]

  kf = KFold(n_splits=num_folds, shuffle=True, random_state=37)

  for train_index, val_index in kf.split(X):
    X_train, X_val, y_train, y_val = X.iloc[train_index, :], X.iloc[val_index, :], y.iloc[train_index], y.iloc[val_index]

    # Instantiate the SMOTE oversampler
    smotenc = SMOTENC(
        categorical_features=categorical_cols,
        sampling_strategy='auto',
        random_state=37
      )

    # Apply SMOTE to generate synthetic samples
    X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

    scaler = StandardScaler()
    X_resampled.iloc[:, 17:] = scaler.fit_transform(X_resampled.iloc[:, 17:])
    X_val.iloc[:, 17:] = scaler.transform(X_val.iloc[:, 17:])

    X_resampled = np.array(X_resampled).reshape(X_resampled.shape[0], X_resampled.shape[1], 1)
    X_val = np.array(X_val).reshape(X_val.shape[0], X_val.shape[1], 1)

    yield X_resampled, X_val, y_resampled, y_val

# %%
def get_categorical(df):
    categorical = []
    for col in df.columns.tolist():
        try:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': model_var[model_var['model_var_name'] ==  col]['desc'].values[0],
                    'column': col,
                    'possible_values': df[col].unique().tolist()}
                            )
        except Exception as error:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': None,
                    'column': col,
                    'possible_values': df[col].unique().tolist()})
            # print(f'{col} error: {error}')
    return categorical

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTENC, SMOTE

def prep_data_final(df):
  X = df.copy().drop(columns=['Quest16_MCQ160B'])
  y = df['Quest16_MCQ160B']

  y = y.replace({2: 0})
  y = y.replace({9: 0})

  y = y.astype(int)

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43, shuffle=True)

  categorical_summary = get_categorical(X)
  categorical_cols = [True if data_col in [col['column'] for col in categorical_summary] else False for data_col in X.columns.tolist()]

  # Instantiate the SMOTE oversampler
  smotenc = SMOTENC(
      categorical_features=categorical_cols,
      sampling_strategy='auto',
      random_state=37
    )

  # Apply SMOTE to generate synthetic samples
  X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

  scaler = StandardScaler()
  X_resampled.iloc[:, 16:] = scaler.fit_transform(X_resampled.iloc[:, 16:])
  X_test.iloc[:, 16:] = scaler.transform(X_test.iloc[:, 16:])
  joblib.dump(scaler, 'v2_standard_scaler.gz')

  X_resampled = np.array(X_resampled).reshape(X_resampled.shape[0], X_resampled.shape[1], 1)
  X_test = np.array(X_test).reshape(X_test.shape[0], X_test.shape[1], 1)

  return X_resampled, X_test, y_resampled, y_test

X_train, X_test, y_train, y_test = prep_data_final(df_raw)
input_shape = X_train.shape[1:]

print(y_train.value_counts())
# Out:
# Quest16_MCQ160B
# 0    4289
# 1    4289
# Name: count, dtype: int64

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data=()):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data
        self.logs = {}

    def on_epoch_end(self, epoch, logs={}):
        if not self.validation_data:
            raise RuntimeError("Requires validation_data.")
        if self.logs.get('roc_auc', None) == None:
          self.logs['roc_auc'] = []
        if self.logs.get('f1score', None) == None:
          self.logs['f1score'] = []

        X_val, y_val = self.validation_data
        y_pred = self.model.predict(X_val, verbose=0)

        # Convert one-hot encoded labels to class labels
        y_pred =  [1 if preds[1] >= 2.46069816967065e-06 else 0 for preds in y_pred]

        # Compute Metrics score
        f1score = f1_score(y_val, y_pred, average='weighted')
        roc_auc = roc_auc_score(y_val, y_pred, average='weighted')

        # Add Metrics score to logs
        self.logs['roc_auc'].append(roc_auc)
        self.logs['f1score'].append(f1score)

# %%
# def build_model():
#   model = models.Sequential()
#   model.add(layers.Input(input_shape))
#   model.add(layers.Conv1D(filters=16, kernel_size=3, activation='relu'))
#   model.add(layers.Conv1D(filters=16, kernel_size=3, activation='relu'))
#   model.add(layers.Conv1D(filters=16, kernel_size=2, activation='relu'))
#   model.add(layers.Flatten())
#   model.add(layers.Dense(units=4, activation='relu'))
#   model.add(layers.Dense(units=4, activation='relu'))
#   model.add(layers.Dense(units=128, activation='relu'))
#   model.add(layers.Dense(units=64, activation='relu'))
#   model.add(layers.Dense(2, activation='softmax'))

#   # Compile the model
#   model.compile(optimizer='adam',
#     loss='sparse_categorical_crossentropy',
#     metrics=['accuracy']
#   )

#   return model

# %%
def build_model():
  model = models.Sequential()
  model.add(layers.Input(input_shape))
  model.add(layers.Conv1D(filters=16, kernel_size=3, activation='relu'))
  model.add(layers.Conv1D(filters=16, kernel_size=2, activation='relu'))
  model.add(layers.MaxPool1D(2))
  model.add(layers.Conv1D(filters=16, kernel_size=2, activation='relu'))
  model.add(layers.Conv1D(filters=32, kernel_size=2, activation='relu'))
  model.add(layers.MaxPool1D(2))
  model.add(layers.Flatten())
  model.add(layers.Dense(units=32, activation='relu'))
  model.add(layers.Dense(units=8, activation='relu'))
  model.add(layers.Dense(units=128, activation='relu'))
  model.add(layers.Dense(units=32, activation='relu'))
  model.add(layers.Dense(2, activation='softmax'))

  # Compile the model
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0007),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
  )

  return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Early stopping callback to stop training when validation loss doesn't improve
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# %%
tf.random.set_seed(37)
random.seed(37)

loss = []
accuracy = []
f1score = []
auc = []

X_train, X_test, y_train, y_test = prep_data_final(df_raw)

model = build_model()
metrics_callback = MetricsCallback(validation_data=(X_test, y_test))

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=30)

_loss, _accuracy = model.evaluate(X_test, y_test, verbose=0)
loss.append(_loss)
accuracy.append(_accuracy)
f1score.append(metrics_callback.logs.get('f1score'))
auc.append(metrics_callback.logs.get('roc_auc'))

print()
model.summary()
# Out:
# Epoch 1/30
# 269/269 [==============================] - 5s 9ms/step - loss: 0.5121 - accuracy: 0.7467 - val_loss: 0.3424 - val_accuracy: 0.8259
# Epoch 2/30
# 269/269 [==============================] - 3s 11ms/step - loss: 0.3875 - accuracy: 0.8243 - val_loss: 0.4076 - val_accuracy: 0.7864
# Epoch 3/30
# 269/269 [==============================] - 3s 9ms/step - loss: 0.3370 - accuracy: 0.8518 - val_loss: 0.5563 - val_accuracy: 0.7271
# Epoch 4/30
# 269/269 [==============================] - 2s 7ms/step - loss: 0.3003 - accuracy: 0.8751 - val_loss: 0.3670 - val_accuracy: 0.8294
# Epoch 5/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.2777 - accuracy: 0.8854 - val_loss: 0.2848 - val_accuracy: 0.8707
# Epoch 6/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.2583 - accuracy: 0.8952 - val_loss: 0.2914 - val_accuracy: 0.8743
# Epoch 7/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.2414 - accuracy: 0.9052 - val_loss: 0.3914 - val_accuracy: 0.8241
# Epoch 8/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.2232 - accuracy: 0.9125 - val_loss: 0.3552 - val_accuracy: 0.8573
# Epoch 9/30
# 269/269 [==============================] - 2s 8ms/step - loss: 0.2163 - accuracy: 0.9176 - val_loss: 0.3119 - val_accuracy: 0.8734
# Epoch 10/30
# 269/269 [==============================] - 2s 8ms/step - loss: 0.2025 - accuracy: 0.9204 - val_loss: 0.2535 - val_accuracy: 0.8959
# Epoch 11/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.1957 - accuracy: 0.9253 - val_loss: 0.3028 - val_accuracy: 0.8824
# Epoch 12/30
# 269/269 [==============================] - 3s 11ms/step - loss: 0.1764 - accuracy: 0.9338 - val_loss: 0.3630 - val_accuracy: 0.8636
# Epoch 13/30
# 269/269 [==============================] - 2s 8ms/step - loss: 0.1695 - accuracy: 0.9374 - val_loss: 0.3739 - val_accuracy: 0.8609
# Epoch 14/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.1664 - accuracy: 0.9388 - val_loss: 0.4240 - val_accuracy: 0.8393
# Epoch 15/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.1539 - accuracy: 0.9440 - val_loss: 0.2915 - val_accuracy: 0.8950
# Epoch 16/30
# 269/269 [==============================] - 2s 7ms/step - loss: 0.1502 - accuracy: 0.9452 - val_loss: 0.2575 - val_accuracy: 0.9066
# Epoch 17/30
# 269/269 [==============================] - 2s 8ms/step - loss: 0.1484 - accuracy: 0.9465 - val_loss: 0.3466 - val_accuracy: 0.8779
# Epoch 18/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.1365 - accuracy: 0.9508 - val_loss: 0.2588 - val_accuracy: 0.9156
# Epoch 19/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.1351 - accuracy: 0.9527 - val_loss: 0.3150 - val_accuracy: 0.8860
# Epoch 20/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.1215 - accuracy: 0.9567 - val_loss: 0.3135 - val_accuracy: 0.8932
# Epoch 21/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.1227 - accuracy: 0.9570 - val_loss: 0.4318 - val_accuracy: 0.8519
# Epoch 22/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.1267 - accuracy: 0.9547 - val_loss: 0.3078 - val_accuracy: 0.8995
# Epoch 23/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.1110 - accuracy: 0.9621 - val_loss: 0.3363 - val_accuracy: 0.8851
# Epoch 24/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.1042 - accuracy: 0.9633 - val_loss: 0.3465 - val_accuracy: 0.8815
# Epoch 25/30
# 269/269 [==============================] - 2s 8ms/step - loss: 0.1059 - accuracy: 0.9632 - val_loss: 0.3598 - val_accuracy: 0.8842
# Epoch 26/30
# 269/269 [==============================] - 2s 8ms/step - loss: 0.1381 - accuracy: 0.9494 - val_loss: 0.3320 - val_accuracy: 0.8941
# Epoch 27/30
# 269/269 [==============================] - 1s 5ms/step - loss: 0.1001 - accuracy: 0.9668 - val_loss: 0.3971 - val_accuracy: 0.8743
# Epoch 28/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.0988 - accuracy: 0.9663 - val_loss: 0.3923 - val_accuracy: 0.8752
# Epoch 29/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.0893 - accuracy: 0.9713 - val_loss: 0.3574 - val_accuracy: 0.8968
# Epoch 30/30
# 269/269 [==============================] - 2s 6ms/step - loss: 0.0930 - accuracy: 0.9693 - val_loss: 0.3547 - val_accuracy: 0.8959
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 21, 16)            64
#
#  conv1d_5 (Conv1D)           (None, 20, 16)            528
#
#  max_pooling1d_2 (MaxPoolin  (None, 10, 16)            0
#  g1D)
#
#  conv1d_6 (Conv1D)           (None, 9, 16)             528
#
#  conv1d_7 (Conv1D)           (None, 8, 32)             1056
#
#  max_pooling1d_3 (MaxPoolin  (None, 4, 32)             0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 32)                4128
#
#  dense_6 (Dense)             (None, 8)                 264
#
#  dense_7 (Dense)             (None, 128)               1152
#
#  dense_8 (Dense)             (None, 32)                4128
#
#  dense_9 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 11914 (46.54 KB)
# Trainable params: 11914 (46.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_auc_score

# Evaluate Model

proba = model.predict(X_test)
preds = np.argmax(proba, axis=1)

print("Accuracy: " + str(accuracy_score(y_test, preds)*100) + "%")
print("F1 Score: " + str(f1_score(y_test, preds, average='weighted')*100) + "%")
print("AUC: " + str(roc_auc_score(y_test, preds, average='weighted')*100) + "%")

print(confusion_matrix(y_test, preds))
# Out:
# 35/35 [==============================] - 0s 2ms/step
# Accuracy: 89.5870736086176%
# F1 Score: 91.72077839858488%
# AUC: 51.775453462200446%
# [[994  85]
#  [ 31   4]]

# %%
# min(x*0.5/threshold, 1)

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, model.predict(X_test)[:, 1])

# Compute the optimal threshold by maximizing the Youden's J statistic
J = tpr - fpr
optimal_idx = np.argmax(J)
optimal_threshold = thresholds[optimal_idx]

# Alternatively, you can minimize the distance to the top-left corner (0,1)
distances = np.sqrt(fpr**2 + (1-tpr)**2)
optimal_idx = np.argmin(distances)
optimal_threshold = thresholds[optimal_idx]

print(f"Optimal threshold: {optimal_threshold}")
# Out:
# 35/35 [==============================] - 0s 2ms/step
# Optimal threshold: 0.008846051059663296

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_auc_score

# Evaluate Model

proba = model.predict(X_test)
preds = [1 if prob >= optimal_threshold else 0 for prob in proba[:, 1]]

print("Accuracy: " + str(accuracy_score(y_test, preds)*100) + "%")
print("F1 Score: " + str(f1_score(y_test, preds, average='weighted')*100) + "%")
print("AUC: " + str(roc_auc_score(y_test, preds, average='weighted')*100) + "%")

print(confusion_matrix(y_test, preds))
# Out:
# 35/35 [==============================] - 0s 2ms/step
# Accuracy: 64.63195691202873%
# F1 Score: 75.7614843000657%
# AUC: 74.83119290348206%
# [[690 389]
#  [  5  30]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.64      0.78      1079
#            1       0.07      0.86      0.13        35
#
#     accuracy                           0.65      1114
#    macro avg       0.53      0.75      0.46      1114
# weighted avg       0.96      0.65      0.76      1114

# %% [markdown]
# # Summarize Model

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('CNN Model Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Save Model

# %%
model.save('model_cnn_proper_apps_v3.h5', save_format='h5')

# %%
var_mapping_path = 'Dataset/Variable Mapping V3.xlsx'

var_mapping = pd.read_excel(os.path.join(drive_path, var_mapping_path))
var_mapping['group'] = var_mapping['group'].replace({'Dieta2': 'Dieta1'})
var_mapping['model_var_name'] = var_mapping['group'] + "_" + var_mapping['variable']

model_var = pd.DataFrame({'model_var_name': df_raw.columns.tolist()})

model_var = pd.merge(model_var, var_mapping, left_on=model_var['model_var_name'].str.lower(), right_on=var_mapping['model_var_name'].str.lower(), how='outer', indicator=True).query('_merge!="right_only"')

# To Check if all variable is tagged
# model_var[model_var['_merge'] == "left_only"]

model_var = model_var[['model_var_name_x', 'lifestyle', 'desc']].rename(columns={'model_var_name_x': 'model_var_name'}).drop_duplicates().reset_index(drop=True)

model_var
# Out:
#               model_var_name lifestyle  \
# 0             Quest22_SMQ890     False
# 1             Quest22_SMQ900     False
# 2             Quest21_SLD123      True
# 3            Quest21_SLQ3032      True
# 4            Dieta1_DR1TKCAL      True
# 5            Dieta1_DR1TPROT      True
# 6            Dieta1_DR1TCARB      True
# 7            Dieta1_DR1TSUGR      True
# 8            Dieta1_DR1TFIBE      True
# 9            Dieta1_DR1TTFAT      True
# 10           Dieta1_DR1TSFAT      True
# 11           Dieta1_DR1TMFAT      True
# 12           Dieta1_DR1TPFAT      True
# 13           Dieta1_DR1TCHOL      True
# 14           Dieta1_DR1TCALC      True
# 15  Quest19_VigorousActivity       NaN
# 16           Demog1_RIDAGEYR     False
# 17              Exami2_BMXWT     False
# 18              Exami2_BMXHT     False
# 19             Exami2_BMXBMI      True
# 20             Quest3_CDQ008     False
# 21           Exami1_SysPulse     False
# 22           Exami1_DiaPulse     False
# 23           Quest16_MCQ160B     False
#
#                                                  desc
# 0                    Ever Smoked A Cigar Even 1 Time?
# 1                           Ever Used An E-Cigarette?
# 2   Average value of sleep hours (Weekdays and wee...
# 3   Average value of sleep time (Weekdays and week...
# 4                                       Energy (Kcal)
# 5                                        Protein (Gm)
# 6                                   Carbohydrate (Gm)
# 7                                   Total Sugars (Gm)
# 8                                  Dietary Fiber (Gm)
# 9                                      Total Fat (Gm)
# 10                   Total Saturated Fatty Acids (Gm)
# 11             Total Monounsaturated Fatty Acids (Gm)
# 12             Total Polyunsaturated Fatty Acids (Gm)
# 13                                   Cholesterol (Mg)
# 14                                       Calcium (Mg)
# 15                                                NaN
# 16                          Age In Years At Screening
# 17                                        Weight (Kg)
# 18                               Standing Height (Cm)
# 19                          Body Mass Index (Kg/M**2)
# 20           Severe Pain In Chest More Than Half Hour
# 21                            Systolic Pulse Combined
# 22                           Diastolic Pulse Combined
# 23             Ever Told Had Congestive Heart Failure

# %%
model_var.loc[model_var['lifestyle'].isna(), 'lifestyle'] = True
model_var.loc[model_var['desc'].isna(), 'desc'] = 'Minutes of Vigorous Activity'

# %%
model_var[model_var['lifestyle'] == True].shape
# Out:
# (15, 3)

# %%
model_var.set_index('model_var_name').loc[[col for col in sorted(df_raw.columns.tolist()) if "Dieta" in col]]
# Out:
#                 lifestyle                                    desc
# model_var_name
# Dieta1_DR1TCALC      True                            Calcium (Mg)
# Dieta1_DR1TCARB      True                       Carbohydrate (Gm)
# Dieta1_DR1TCHOL      True                        Cholesterol (Mg)
# Dieta1_DR1TFIBE      True                      Dietary Fiber (Gm)
# Dieta1_DR1TKCAL      True                           Energy (Kcal)
# Dieta1_DR1TMFAT      True  Total Monounsaturated Fatty Acids (Gm)
# Dieta1_DR1TPFAT      True  Total Polyunsaturated Fatty Acids (Gm)
# Dieta1_DR1TPROT      True                            Protein (Gm)
# Dieta1_DR1TSFAT      True        Total Saturated Fatty Acids (Gm)
# Dieta1_DR1TSUGR      True                       Total Sugars (Gm)
# Dieta1_DR1TTFAT      True                          Total Fat (Gm)

# %%
df_raw['Quest3_CDQ008'].value_counts()
# Out:
# Quest3_CDQ008
# 0.0    5294
# 1.0     275
# Name: count, dtype: int64

# %%
import json

# generate lifestyle description
json_obj = {}
for col, desc in model_var[model_var['lifestyle']==True][['model_var_name', 'desc']].values:
    json_obj[col]=desc

with open('v1_lifestyle_description.json', 'w') as json_file:
    json.dump(json_obj, json_file)

# generate columns order
column_order = {'lifestyle': {}, 'characteristic': {}}
sampling = df_raw.sample(n=1, axis=0)

for index, key in enumerate(sampling.columns.tolist()):
    if index < model_var[model_var['lifestyle']==True].shape[0]:
        column_order['lifestyle'][key] = index
    else:
        column_order['characteristic'][key] = index

with open('v1_columns_order.json', 'w') as json_file:
    json.dump(column_order, json_file)

# %%
list(df_raw[df_raw['Quest3_CDQ008'] == 1].sample(1).values)
# Out:
# [array([  1. ,   0. ,   0. ,   1. ,   3. ,   2. ,   3. ,   3. ,   2. ,
#           3. ,   3. ,   3. ,   3. ,   3. ,   1. ,   3. ,  78. ,  62.3,
#         175.5,  20.2,   1. , 150. ,  78. ,   2. ])]

# %%
list(df_raw[df_raw['Quest3_CDQ008'] == 1].sample(1))
# Out:
# ['Quest22_SMQ890',
#  'Quest22_SMQ900',
#  'Quest21_SLD123',
#  'Quest21_SLQ3032',
#  'Dieta1_DR1TKCAL',
#  'Dieta1_DR1TPROT',
#  'Dieta1_DR1TCARB',
#  'Dieta1_DR1TSUGR',
#  'Dieta1_DR1TFIBE',
#  'Dieta1_DR1TTFAT',
#  'Dieta1_DR1TSFAT',
#  'Dieta1_DR1TMFAT',
#  'Dieta1_DR1TPFAT',
#  'Dieta1_DR1TCHOL',
#  'Dieta1_DR1TCALC',
#  'Quest19_VigorousActivity',
#  'Demog1_RIDAGEYR',
#  'Exami2_BMXWT',
#  'Exami2_BMXHT',
#  'Exami2_BMXBMI',
#  'Quest3_CDQ008',
#  'Exami1_SysPulse',
#  'Exami1_DiaPulse',
#  'Quest16_MCQ160B']

# %%
import matplotlib.pyplot as plt
plt.hist(model.predict(X)[:, 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d909100954f6> in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.hist(model.predict(X)[:, 1])
#
# NameError: name 'X' is not defined

# %%
model = tf.keras.models.load_model('/content/model_cnn_proper_apps_v3 (2).h5')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 21, 16)            64
#
#  conv1d_1 (Conv1D)           (None, 20, 16)            528
#
#  max_pooling1d (MaxPooling1  (None, 10, 16)            0
#  D)
#
#  conv1d_2 (Conv1D)           (None, 9, 16)             528
#
#  conv1d_3 (Conv1D)           (None, 8, 32)             1056
#
#  max_pooling1d_1 (MaxPoolin  (None, 4, 32)             0
#  g1D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 32)                4128
#
#  dense_1 (Dense)             (None, 8)                 264
#
#  dense_2 (Dense)             (None, 128)               1152
#
#  dense_3 (Dense)             (None, 32)                4128
#
#  dense_4 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 11914 (46.54 KB)
# Trainable params: 11914 (46.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_auc_score

# Evaluate Model

proba = model.predict(X_test)
preds = np.argmax(proba, axis=1)

print("Accuracy: " + str(accuracy_score(y_test, preds)*100) + "%")
print("F1 Score: " + str(f1_score(y_test, preds, average='weighted')*100) + "%")
print("AUC: " + str(roc_auc_score(y_test, preds, average='weighted')*100) + "%")

print(confusion_matrix(y_test, preds))
# Out:
# 35/35 [==============================] - 0s 5ms/step
# Accuracy: 88.77917414721723%
# F1 Score: 91.4467993720929%
# AUC: 58.269561763537666%
# [[980  99]
#  [ 26   9]]

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, model.predict(X_test)[:, 1])

# Compute the optimal threshold by maximizing the Youden's J statistic
J = tpr - fpr
optimal_idx = np.argmax(J)
optimal_threshold = thresholds[optimal_idx]

# Alternatively, you can minimize the distance to the top-left corner (0,1)
distances = np.sqrt(fpr**2 + (1-tpr)**2)
optimal_idx = np.argmin(distances)
optimal_threshold = thresholds[optimal_idx]

print(f"Optimal threshold: {optimal_threshold}")
# Out:
# 35/35 [==============================] - 0s 3ms/step
# Optimal threshold: 0.01220415998250246

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_auc_score

# Evaluate Model

proba = model.predict(X_test)
preds = [1 if prob >= optimal_threshold else 0 for prob in proba[:, 1]]

print("Accuracy: " + str(accuracy_score(y_test, preds)*100) + "%")
print("F1 Score: " + str(f1_score(y_test, preds, average='weighted')*100) + "%")
print("AUC: " + str(roc_auc_score(y_test, preds, average='weighted')*100) + "%")

print(confusion_matrix(y_test, preds))
# Out:
# 35/35 [==============================] - 0s 3ms/step
# Accuracy: 66.51705565529623%
# F1 Score: 77.1762946375949%
# AUC: 74.42208394015624%
# [[712 367]
#  [  6  29]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.66      0.79      1079
#            1       0.07      0.83      0.13        35
#
#     accuracy                           0.67      1114
#    macro avg       0.53      0.74      0.46      1114
# weighted avg       0.96      0.67      0.77      1114
