# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import random

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import layers, models
import tensorflow_datasets as tfds
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, ClassifierMixin

import warnings
warnings.filterwarnings('ignore')

drive_path = '/content/drive/MyDrive/Kuliah/Tugas Akhir/Final Project Shared Folder'
data_path = "Dataset/Data Versioning/"
model_path = "Model/ML Model/"
data_version = "Trained_App-3.csv"
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_raw = pd.read_csv(os.path.join(drive_path, data_path+data_version), index_col = 0)
try:
  df_raw = df_raw.set_index('SEQN', drop=True)
  df_raw = df_raw.drop(columns = "Unnamed: 0")
except:
  pass

df_raw.head()
# Out:
#          Quest22_SMQ890  Quest22_SMQ900  Quest21_SLQ300  Quest21_SLQ330  \
# SEQN
# 93705.0             2.0             2.0               3               1
# 93708.0             2.0             2.0               2               0
# 93709.0             1.0             1.0               2               0
# 93711.0             2.0             2.0               2               2
# 93713.0             2.0             2.0               3               0
#
#          Quest21_SLD012  Dieta1_DR1TKCAL  Dieta1_DR1TPROT  Dieta1_DR1TCARB  \
# SEQN
# 93705.0               1                0                0                0
# 93708.0               1                0                0                0
# 93709.0               0                1                2                1
# 93711.0               1                3                3                3
# 93713.0               0                2                1                1
#
#          Dieta1_DR1TSUGR  Dieta1_DR1TFIBE  ...  Dieta1_DR1TCALC  \
# SEQN                                       ...
# 93705.0                1                0  ...                0
# 93708.0                0                2  ...                0
# 93709.0                2                2  ...                2
# 93711.0                3                3  ...                3
# 93713.0                2                1  ...                1
#
#          Quest19_VigorousActivity  Demog1_RIDAGEYR  Exami2_BMXWT  \
# SEQN
# 93705.0                         0             66.0          79.5
# 93708.0                         0             66.0          53.5
# 93709.0                         1             75.0          88.8
# 93711.0                         1             56.0          62.1
# 93713.0                         0             67.0          74.9
#
#          Exami2_BMXHT  Exami2_BMXBMI  Quest3_CDQ008  Exami1_SysPulse  \
# SEQN
# 93705.0         158.3           31.7            9.0        69.961686
# 93708.0         150.2           23.7            9.0        75.777778
# 93709.0         151.1           38.9            9.0        66.666667
# 93711.0         170.6           21.3            9.0        66.666667
# 93713.0         178.6           23.5            9.0        72.000000
#
#          Exami1_DiaPulse  Quest16_MCQ160B
# SEQN
# 93705.0        69.961686              2.0
# 93708.0        75.777778              2.0
# 93709.0        66.666667              2.0
# 93711.0        66.666667              2.0
# 93713.0        72.000000              2.0
#
# [5 rows x 25 columns]

# %%
def get_categorical(df):
    categorical = []
    for col in df.columns.tolist():
        try:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': model_var[model_var['model_var_name'] ==  col]['desc'].values[0],
                    'column': col,
                    'possible_values': df[col].unique().tolist()}
                            )
        except Exception as error:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': None,
                    'column': col,
                    'possible_values': df[col].unique().tolist()})
            # print(f'{col} error: {error}')
    return categorical

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTENC, SMOTE

def prep_data(df):
  X = df.copy().drop(columns=['Quest16_MCQ160B'])
  y = df['Quest16_MCQ160B']

  y = y.replace({2: 0})
  y = y.replace({9: 0})

  y = y.astype(int)

  categorical_summary = get_categorical(X)
  categorical_cols = [True if data_col in [col['column'] for col in categorical_summary] else False for data_col in X.columns.tolist()]

  X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42)

  # Instantiate the SMOTE oversampler
  smotenc = SMOTENC(
      categorical_features=categorical_cols,
      sampling_strategy='auto',
      random_state=37
    )

  # Apply SMOTE to generate synthetic samples
  X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

  scaler = StandardScaler()
  X_resampled.iloc[:, 17:] = scaler.fit_transform(X_resampled.iloc[:, 17:])
  X_val.iloc[:, 17:] = scaler.transform(X_val.iloc[:, 17:])

  X_resampled = np.array(X_resampled).reshape(X_resampled.shape[0], X_resampled.shape[1], 1)
  X_val = np.array(X_val).reshape(X_val.shape[0], X_val.shape[1], 1)

  print("Train: ", X_resampled.shape, " ", y_resampled.shape)
  print("Val: ", X_val.shape, " ", y_val.shape)
  print("Column Used: ", X.columns.tolist())

  return X_resampled, X_val, y_resampled, y_val

X_train, X_val, y_train, y_val = prep_data(df_raw)
input_shape = X_train.shape[1:]

print(y_train.value_counts())
print(y_val.value_counts())
# Out:
# Train:  (8050, 24, 1)   (8050,)
# Val:  (1393, 24, 1)   (1393,)
# Column Used:  ['Quest22_SMQ890', 'Quest22_SMQ900', 'Quest21_SLQ300', 'Quest21_SLQ330', 'Quest21_SLD012', 'Dieta1_DR1TKCAL', 'Dieta1_DR1TPROT', 'Dieta1_DR1TCARB', 'Dieta1_DR1TSUGR', 'Dieta1_DR1TFIBE', 'Dieta1_DR1TTFAT', 'Dieta1_DR1TSFAT', 'Dieta1_DR1TMFAT', 'Dieta1_DR1TPFAT', 'Dieta1_DR1TCHOL', 'Dieta1_DR1TCALC', 'Quest19_VigorousActivity', 'Demog1_RIDAGEYR', 'Exami2_BMXWT', 'Exami2_BMXHT', 'Exami2_BMXBMI', 'Quest3_CDQ008', 'Exami1_SysPulse', 'Exami1_DiaPulse']
# Quest16_MCQ160B
# 0    4025
# 1    4025
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1343
# 1      50
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTENC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

def prep_data_cross_validation(df, num_folds=5):
  X = df.copy().drop(columns=['Quest16_MCQ160B'])
  y = df['Quest16_MCQ160B']

  y = y.replace({2: 0})
  y = y.replace({9: 0})

  y = y.astype(int)

  categorical_summary = get_categorical(X)
  categorical_cols = [True if data_col in [col['column'] for col in categorical_summary] else False for data_col in X.columns.tolist()]

  kf = KFold(n_splits=num_folds, shuffle=True, random_state=37)

  for train_index, val_index in kf.split(X):
    X_train, X_val, y_train, y_val = X.iloc[train_index, :], X.iloc[val_index, :], y.iloc[train_index], y.iloc[val_index]\

    # Instantiate the SMOTE oversampler
    smotenc = SMOTENC(
        categorical_features=categorical_cols,
        sampling_strategy='auto',
        random_state=37
      )

    # Apply SMOTE to generate synthetic samples
    X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

    scaler = StandardScaler()
    X_resampled.iloc[:, 17:] = scaler.fit_transform(X_resampled.iloc[:, 17:])
    X_val.iloc[:, 17:] = scaler.transform(X_val.iloc[:, 17:])

    X_resampled = np.array(X_resampled).reshape(X_resampled.shape[0], X_resampled.shape[1], 1)
    X_val = np.array(X_val).reshape(X_val.shape[0], X_val.shape[1], 1)

    yield X_resampled, X_val, y_resampled, y_val

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data=()):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data
        self.logs = {}

    def on_epoch_end(self, epoch, logs={}):
        if not self.validation_data:
            raise RuntimeError("Requires validation_data.")
        if self.logs.get('roc_auc', None) == None:
          self.logs['roc_auc'] = []
        if self.logs.get('f1score', None) == None:
          self.logs['f1score'] = []

        X_val, y_val = self.validation_data
        y_proba = self.model.predict(X_val, verbose=0)
        y_pred = np.argmax(y_proba, axis=1)

        # Convert one-hot encoded labels to class labels
        # y_pred =  [1 if preds[1] >= 2.46069816967065e-06 else 0 for preds in y_pred]

        # Compute Metrics score
        f1score = f1_score(y_val, y_pred, average='weighted')
        roc_auc = roc_auc_score(y_val, y_pred, average='weighted')

        # Add Metrics score to logs
        self.logs['roc_auc'].append(roc_auc)
        self.logs['f1score'].append(f1score)

# %%
def build_model():
  model = models.Sequential()
  model.add(layers.Input(input_shape))
  model.add(layers.Conv1D(filters=8, kernel_size=3))
  model.add(layers.Flatten())
  model.add(layers.Dense(units=4))
  model.add(layers.Dense(2, activation='softmax'))

  # Compile the model
  model.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
  )

  return model

# %%
tf.random.set_seed(37)
random.seed(37)

loss = []
accuracy = []
f1score = []
auc = []
train_loss = []
train_accuracy = []
train_f1score = []
train_auc = []

for X_train, X_val, y_train, y_val in prep_data_cross_validation(df_raw, num_folds=4):
  print(y_train.value_counts())
  print(y_val.value_counts())

  model = build_model()

  metrics_callback = MetricsCallback(validation_data=(X_val, y_val))
  train_metrics_callback = MetricsCallback(validation_data=(X_train, y_train))

  model.fit(X_train, y_train, epochs=20, validation_data=(X_val, y_val), callbacks=[metrics_callback, train_metrics_callback])
  _loss, _accuracy = model.evaluate(X_val, y_val, verbose=0)
  loss.append(_loss)
  accuracy.append(_accuracy)
  f1score.append(metrics_callback.logs.get('f1score'))
  auc.append(metrics_callback.logs.get('roc_auc'))

  _train_loss, _train_accuracy = model.evaluate(X_train, y_train, verbose=0)
  train_loss.append(_train_loss)
  train_accuracy.append(_train_accuracy)
  train_f1score.append(train_metrics_callback.logs.get('f1score'))
  train_auc.append(train_metrics_callback.logs.get('roc_auc'))


print()
model.summary()
# Out:
# Quest16_MCQ160B
# 0    4022
# 1    4022
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1346
# 1      47
# Name: count, dtype: int64
# Epoch 1/20
# 252/252 [==============================] - 3s 8ms/step - loss: 0.4888 - accuracy: 0.7557 - val_loss: 0.4577 - val_accuracy: 0.7566
# Epoch 2/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.4392 - accuracy: 0.7852 - val_loss: 0.4576 - val_accuracy: 0.7531
# Epoch 3/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.4362 - accuracy: 0.7863 - val_loss: 0.4455 - val_accuracy: 0.7631
# Epoch 4/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4313 - accuracy: 0.7846 - val_loss: 0.4755 - val_accuracy: 0.7538
# Epoch 5/20
# 252/252 [==============================] - 1s 6ms/step - loss: 0.4305 - accuracy: 0.7874 - val_loss: 0.4341 - val_accuracy: 0.7854
# Epoch 6/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.4303 - accuracy: 0.7900 - val_loss: 0.3807 - val_accuracy: 0.8162
# Epoch 7/20
# 252/252 [==============================] - 3s 11ms/step - loss: 0.4264 - accuracy: 0.7936 - val_loss: 0.4698 - val_accuracy: 0.7624
# Epoch 8/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.4281 - accuracy: 0.7888 - val_loss: 0.4712 - val_accuracy: 0.7581
# Epoch 9/20
# 252/252 [==============================] - 1s 6ms/step - loss: 0.4285 - accuracy: 0.7911 - val_loss: 0.4385 - val_accuracy: 0.7810
# Epoch 10/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4260 - accuracy: 0.7902 - val_loss: 0.5509 - val_accuracy: 0.7236
# Epoch 11/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4263 - accuracy: 0.7905 - val_loss: 0.4847 - val_accuracy: 0.7538
# Epoch 12/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.4279 - accuracy: 0.7921 - val_loss: 0.4411 - val_accuracy: 0.7753
# Epoch 13/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.4251 - accuracy: 0.7892 - val_loss: 0.4275 - val_accuracy: 0.7818
# Epoch 14/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.4262 - accuracy: 0.7904 - val_loss: 0.4252 - val_accuracy: 0.7882
# Epoch 15/20
# 252/252 [==============================] - 2s 9ms/step - loss: 0.4251 - accuracy: 0.7902 - val_loss: 0.5151 - val_accuracy: 0.7344
# Epoch 16/20
# 252/252 [==============================] - 3s 11ms/step - loss: 0.4254 - accuracy: 0.7913 - val_loss: 0.4336 - val_accuracy: 0.7832
# Epoch 17/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4254 - accuracy: 0.7893 - val_loss: 0.4359 - val_accuracy: 0.7767
# Epoch 18/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4256 - accuracy: 0.7903 - val_loss: 0.4251 - val_accuracy: 0.7904
# Epoch 19/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.4251 - accuracy: 0.7888 - val_loss: 0.4576 - val_accuracy: 0.7638
# Epoch 20/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4238 - accuracy: 0.7915 - val_loss: 0.4408 - val_accuracy: 0.7789
# Quest16_MCQ160B
# 0    4040
# 1    4040
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1328
# 1      64
# Name: count, dtype: int64
# Epoch 1/20
# 253/253 [==============================] - 3s 7ms/step - loss: 0.5098 - accuracy: 0.7610 - val_loss: 0.3914 - val_accuracy: 0.8247
# Epoch 2/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.4032 - accuracy: 0.8157 - val_loss: 0.3931 - val_accuracy: 0.8182
# Epoch 3/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3951 - accuracy: 0.8231 - val_loss: 0.4343 - val_accuracy: 0.7888
# Epoch 4/20
# 253/253 [==============================] - 2s 6ms/step - loss: 0.3928 - accuracy: 0.8261 - val_loss: 0.3886 - val_accuracy: 0.8132
# Epoch 5/20
# 253/253 [==============================] - 2s 7ms/step - loss: 0.3918 - accuracy: 0.8252 - val_loss: 0.3265 - val_accuracy: 0.8527
# Epoch 6/20
# 253/253 [==============================] - 3s 11ms/step - loss: 0.3922 - accuracy: 0.8244 - val_loss: 0.3974 - val_accuracy: 0.8125
# Epoch 7/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3922 - accuracy: 0.8240 - val_loss: 0.4068 - val_accuracy: 0.8060
# Epoch 8/20
# 253/253 [==============================] - 2s 6ms/step - loss: 0.3932 - accuracy: 0.8203 - val_loss: 0.3858 - val_accuracy: 0.8147
# Epoch 9/20
# 253/253 [==============================] - 2s 6ms/step - loss: 0.3899 - accuracy: 0.8252 - val_loss: 0.3195 - val_accuracy: 0.8614
# Epoch 10/20
# 253/253 [==============================] - 2s 6ms/step - loss: 0.3911 - accuracy: 0.8241 - val_loss: 0.4140 - val_accuracy: 0.7996
# Epoch 11/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3893 - accuracy: 0.8264 - val_loss: 0.4362 - val_accuracy: 0.7809
# Epoch 12/20
# 253/253 [==============================] - 2s 6ms/step - loss: 0.3893 - accuracy: 0.8264 - val_loss: 0.3787 - val_accuracy: 0.8261
# Epoch 13/20
# 253/253 [==============================] - 2s 9ms/step - loss: 0.3880 - accuracy: 0.8244 - val_loss: 0.4382 - val_accuracy: 0.7895
# Epoch 14/20
# 253/253 [==============================] - 3s 11ms/step - loss: 0.3895 - accuracy: 0.8257 - val_loss: 0.3808 - val_accuracy: 0.8226
# Epoch 15/20
# 253/253 [==============================] - 2s 7ms/step - loss: 0.3892 - accuracy: 0.8261 - val_loss: 0.3297 - val_accuracy: 0.8484
# Epoch 16/20
# 253/253 [==============================] - 2s 7ms/step - loss: 0.3885 - accuracy: 0.8244 - val_loss: 0.3743 - val_accuracy: 0.8226
# Epoch 17/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3882 - accuracy: 0.8267 - val_loss: 0.3677 - val_accuracy: 0.8297
# Epoch 18/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3873 - accuracy: 0.8262 - val_loss: 0.3476 - val_accuracy: 0.8369
# Epoch 19/20
# 253/253 [==============================] - 2s 6ms/step - loss: 0.3884 - accuracy: 0.8259 - val_loss: 0.3480 - val_accuracy: 0.8434
# Epoch 20/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.3882 - accuracy: 0.8274 - val_loss: 0.4064 - val_accuracy: 0.8039
# Quest16_MCQ160B
# 0    4017
# 1    4017
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1351
# 1      41
# Name: count, dtype: int64
# Epoch 1/20
# 252/252 [==============================] - 4s 10ms/step - loss: 0.5250 - accuracy: 0.7578 - val_loss: 0.3729 - val_accuracy: 0.8168
# Epoch 2/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4081 - accuracy: 0.8043 - val_loss: 0.4102 - val_accuracy: 0.7823
# Epoch 3/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3991 - accuracy: 0.8066 - val_loss: 0.5144 - val_accuracy: 0.7313
# Epoch 4/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3955 - accuracy: 0.8142 - val_loss: 0.5004 - val_accuracy: 0.7421
# Epoch 5/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.3940 - accuracy: 0.8164 - val_loss: 0.4486 - val_accuracy: 0.7672
# Epoch 6/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3921 - accuracy: 0.8157 - val_loss: 0.3847 - val_accuracy: 0.8139
# Epoch 7/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.3921 - accuracy: 0.8174 - val_loss: 0.4381 - val_accuracy: 0.7816
# Epoch 8/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.3932 - accuracy: 0.8179 - val_loss: 0.4340 - val_accuracy: 0.7845
# Epoch 9/20
# 252/252 [==============================] - 3s 11ms/step - loss: 0.3901 - accuracy: 0.8174 - val_loss: 0.4527 - val_accuracy: 0.7759
# Epoch 10/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.3933 - accuracy: 0.8184 - val_loss: 0.4389 - val_accuracy: 0.7802
# Epoch 11/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3913 - accuracy: 0.8190 - val_loss: 0.3892 - val_accuracy: 0.8161
# Epoch 12/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3912 - accuracy: 0.8184 - val_loss: 0.4480 - val_accuracy: 0.7730
# Epoch 13/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3902 - accuracy: 0.8190 - val_loss: 0.4598 - val_accuracy: 0.7658
# Epoch 14/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.3911 - accuracy: 0.8190 - val_loss: 0.4531 - val_accuracy: 0.7687
# Epoch 15/20
# 252/252 [==============================] - 3s 14ms/step - loss: 0.3906 - accuracy: 0.8158 - val_loss: 0.4255 - val_accuracy: 0.7902
# Epoch 16/20
# 252/252 [==============================] - 6s 24ms/step - loss: 0.3900 - accuracy: 0.8206 - val_loss: 0.4927 - val_accuracy: 0.7493
# Epoch 17/20
# 252/252 [==============================] - 3s 11ms/step - loss: 0.3900 - accuracy: 0.8213 - val_loss: 0.4268 - val_accuracy: 0.7881
# Epoch 18/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3901 - accuracy: 0.8167 - val_loss: 0.4768 - val_accuracy: 0.7550
# Epoch 19/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.3895 - accuracy: 0.8160 - val_loss: 0.3883 - val_accuracy: 0.8111
# Epoch 20/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.3903 - accuracy: 0.8185 - val_loss: 0.4109 - val_accuracy: 0.7953
# Quest16_MCQ160B
# 0    4025
# 1    4025
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1343
# 1      49
# Name: count, dtype: int64
# Epoch 1/20
# 252/252 [==============================] - 4s 13ms/step - loss: 0.4577 - accuracy: 0.7754 - val_loss: 0.5100 - val_accuracy: 0.7342
# Epoch 2/20
# 252/252 [==============================] - 1s 6ms/step - loss: 0.4066 - accuracy: 0.8120 - val_loss: 0.4265 - val_accuracy: 0.7902
# Epoch 3/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.4031 - accuracy: 0.8134 - val_loss: 0.4169 - val_accuracy: 0.7981
# Epoch 4/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4048 - accuracy: 0.8143 - val_loss: 0.5411 - val_accuracy: 0.7263
# Epoch 5/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4034 - accuracy: 0.8107 - val_loss: 0.4679 - val_accuracy: 0.7708
# Epoch 6/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4004 - accuracy: 0.8158 - val_loss: 0.4444 - val_accuracy: 0.7809
# Epoch 7/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.4005 - accuracy: 0.8142 - val_loss: 0.5181 - val_accuracy: 0.7421
# Epoch 8/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.4002 - accuracy: 0.8117 - val_loss: 0.4754 - val_accuracy: 0.7751
# Epoch 9/20
# 252/252 [==============================] - 2s 8ms/step - loss: 0.3994 - accuracy: 0.8154 - val_loss: 0.4334 - val_accuracy: 0.7931
# Epoch 10/20
# 252/252 [==============================] - 3s 11ms/step - loss: 0.3992 - accuracy: 0.8174 - val_loss: 0.4237 - val_accuracy: 0.7917
# Epoch 11/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3989 - accuracy: 0.8161 - val_loss: 0.4573 - val_accuracy: 0.7716
# Epoch 12/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3999 - accuracy: 0.8175 - val_loss: 0.4038 - val_accuracy: 0.8089
# Epoch 13/20
# 252/252 [==============================] - 1s 6ms/step - loss: 0.4012 - accuracy: 0.8149 - val_loss: 0.4701 - val_accuracy: 0.7716
# Epoch 14/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3984 - accuracy: 0.8124 - val_loss: 0.4414 - val_accuracy: 0.7809
# Epoch 15/20
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3979 - accuracy: 0.8153 - val_loss: 0.4727 - val_accuracy: 0.7708
# Epoch 16/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.3986 - accuracy: 0.8169 - val_loss: 0.4747 - val_accuracy: 0.7565
# Epoch 17/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.3989 - accuracy: 0.8154 - val_loss: 0.4567 - val_accuracy: 0.7744
# Epoch 18/20
# 252/252 [==============================] - 3s 11ms/step - loss: 0.3980 - accuracy: 0.8149 - val_loss: 0.4501 - val_accuracy: 0.7780
# Epoch 19/20
# 252/252 [==============================] - 2s 8ms/step - loss: 0.3982 - accuracy: 0.8179 - val_loss: 0.4932 - val_accuracy: 0.7536
# Epoch 20/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.3991 - accuracy: 0.8140 - val_loss: 0.5270 - val_accuracy: 0.7378
#
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 22, 8)             32
#
#  flatten_8 (Flatten)         (None, 176)               0
#
#  dense_16 (Dense)            (None, 4)                 708
#
#  dense_17 (Dense)            (None, 2)                 10
#
# =================================================================
# Total params: 750 (2.93 KB)
# Trainable params: 750 (2.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Evaluate Model

print(loss)
print(accuracy)
print(f1score)
print(auc)

print("Training Loss: " + str(np.mean(train_loss)*100) + "%")
print("Training Accuracy: " + str(np.mean(train_accuracy)*100) + "%")
print("Training F1 Score: " + str(np.mean(np.array(train_f1score)[:, -1])*100) + "%")
print("Training AUC: " + str(np.mean(np.array(train_auc)[:, -1])*100) + "%")

print("Loss: " + str(np.mean(loss)*100) + "%")
print("Accuracy: " + str(np.mean(accuracy)*100) + "%")
print("F1 Score: " + str(np.mean(np.array(f1score)[:, -1])*100) + "%")
print("AUC: " + str(np.mean(np.array(auc)[:, -1])*100) + "%")
# Out:
# [0.4408406913280487, 0.40642136335372925, 0.410899817943573, 0.5269829630851746]
# [0.7788944840431213, 0.8038793206214905, 0.795258641242981, 0.7377873659133911]
# [[0.8342852237202875, 0.8318898546889127, 0.8385240927424812, 0.832359885076028, 0.8530770942559093, 0.8726986805188032, 0.8381205511117366, 0.8352783538345685, 0.8503227480254466, 0.811765956367635, 0.8323456242292491, 0.8466776635171367, 0.8507908712487355, 0.85499135625717, 0.8192118179503737, 0.8517725102536782, 0.8476224713187613, 0.8563313235855665, 0.8389996787160875, 0.8489586225743058], [0.871016803507359, 0.8668448763083277, 0.8479310344827587, 0.8633493015694907, 0.8879622388653322, 0.8632430623469354, 0.858703668473311, 0.8644004607881869, 0.8930225071108258, 0.8547191272715973, 0.8425405055147999, 0.8718081037770785, 0.8484051885536673, 0.8693641141178841, 0.8848700325217814, 0.8692284032851406, 0.8736839237769117, 0.877781227738939, 0.8820470278092711, 0.8573064363880836], [0.8756976358834411, 0.8539098857476234, 0.8201250402196163, 0.8274377302082457, 0.8440808724720748, 0.8738244216904658, 0.8533704703465832, 0.8552184725799894, 0.8496599135651636, 0.8524818104632096, 0.8752483147687379, 0.8478271262646109, 0.8431184087219025, 0.8449937651782718, 0.858900261397276, 0.8322328858034801, 0.8575217875344201, 0.8360512753698717, 0.8721654362750396, 0.8621066421292854], [0.8181120444051478, 0.8550969723197932, 0.8602473596345758, 0.8126862350063949, 0.8426276804897378, 0.8491657622945055, 0.8234890230479539, 0.8454590365240637, 0.8570819453017137, 0.8561546544956025, 0.8431003102694562, 0.8669590397956657, 0.8431412860178741, 0.8491657622945055, 0.8426276804897378, 0.8331111559777954, 0.8449422764434182, 0.847340779291921, 0.8312373788744889, 0.8205612798581013]]
# [[0.7816698808131264, 0.7900793525339066, 0.7542126394992255, 0.7801839967120863, 0.7554614144352059, 0.7509010148272265, 0.7846416490152066, 0.8029464765578072, 0.7634994151307263, 0.7953826941924063, 0.7699171698650058, 0.7913281274698871, 0.7638708861559862, 0.7672141253833266, 0.7906879327242262, 0.7748806550535867, 0.7920710695204073, 0.7580617116120262, 0.7545841105244855, 0.7726518289020264], [0.7445406626506024, 0.7411521084337349, 0.748023343373494, 0.723644578313253, 0.7146084337349398, 0.7455760542168675, 0.7198795180722892, 0.7318335843373495, 0.7042545180722891, 0.731362951807229, 0.7290097891566265, 0.7378576807228917, 0.7483998493975904, 0.728539156626506, 0.6974774096385542, 0.7211031626506024, 0.7174322289156627, 0.6988893072289157, 0.7097138554216867, 0.71875], [0.7400751024534672, 0.745960535104981, 0.7551587803072701, 0.7370601722301457, 0.7263634886533914, 0.7267696918271922, 0.7219403874275605, 0.7234207723276346, 0.7189796176274125, 0.7330252207037244, 0.7397050062284487, 0.7293242584535394, 0.7137982704771533, 0.7152786553772275, 0.7263815421277825, 0.7052860573017278, 0.725271253452727, 0.7200718528280767, 0.7489393583795202, 0.7289722157029122], [0.7442673271840381, 0.7241478870029023, 0.7380749768261735, 0.7500037989879497, 0.7435911073290076, 0.7389715379822814, 0.748362636193718, 0.7458249122433784, 0.7453006519063321, 0.7445560502682085, 0.7439634081480694, 0.723995927484918, 0.7537951889616606, 0.7389715379822814, 0.7435911073290076, 0.7361450909477716, 0.7356208306107253, 0.7473141155196256, 0.7543194492987069, 0.746128831279347]]
# Training Loss: 39.88795056939125%
# Training Accuracy: 81.19575083255768%
# Training F1 Score: 81.16631779958358%
# Training AUC: 81.19575026565546%
# Loss: 44.62862089276314%
# Accuracy: 77.8954952955246%
# F1 Score: 84.72332452374441%
# AUC: 74.16257189710713%

# %%
model = build_model()

model.summary()

X_train, X_val, y_train, y_val = prep_data(df_raw)


metrics_callback = MetricsCallback(validation_data=(X_val, y_val))
train_metrics_callback = MetricsCallback(validation_data=(X_train, y_train))

history = model.fit(X_train, y_train, epochs=20, validation_data=(X_val, y_val), callbacks=[metrics_callback, train_metrics_callback])
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_9 (Conv1D)           (None, 22, 8)             32
#
#  flatten_9 (Flatten)         (None, 176)               0
#
#  dense_18 (Dense)            (None, 4)                 708
#
#  dense_19 (Dense)            (None, 2)                 10
#
# =================================================================
# Total params: 750 (2.93 KB)
# Trainable params: 750 (2.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Train:  (8050, 24, 1)   (8050,)
# Val:  (1393, 24, 1)   (1393,)
# Column Used:  ['Quest22_SMQ890', 'Quest22_SMQ900', 'Quest21_SLQ300', 'Quest21_SLQ330', 'Quest21_SLD012', 'Dieta1_DR1TKCAL', 'Dieta1_DR1TPROT', 'Dieta1_DR1TCARB', 'Dieta1_DR1TSUGR', 'Dieta1_DR1TFIBE', 'Dieta1_DR1TTFAT', 'Dieta1_DR1TSFAT', 'Dieta1_DR1TMFAT', 'Dieta1_DR1TPFAT', 'Dieta1_DR1TCHOL', 'Dieta1_DR1TCALC', 'Quest19_VigorousActivity', 'Demog1_RIDAGEYR', 'Exami2_BMXWT', 'Exami2_BMXHT', 'Exami2_BMXBMI', 'Quest3_CDQ008', 'Exami1_SysPulse', 'Exami1_DiaPulse']
# Epoch 1/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.5214 - accuracy: 0.7455 - val_loss: 0.3881 - val_accuracy: 0.8112
# Epoch 2/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3946 - accuracy: 0.8198 - val_loss: 0.3670 - val_accuracy: 0.8220
# Epoch 3/20
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3902 - accuracy: 0.8245 - val_loss: 0.4147 - val_accuracy: 0.8062
# Epoch 4/20
# 252/252 [==============================] - 2s 8ms/step - loss: 0.3889 - accuracy: 0.8252 - val_loss: 0.5958 - val_accuracy: 0.7193
# Epoch 5/20
# 252/252 [==============================] - 3s 10ms/step - loss: 0.3914 - accuracy: 0.8247 - val_loss: 0.4432 - val_accuracy: 0.7868
# Epoch 6/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3890 - accuracy: 0.8243 - val_loss: 0.4246 - val_accuracy: 0.7911
# Epoch 7/20
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3889 - accuracy: 0.8210 - val_loss: 0.4178 - val_accuracy: 0.7997
# Epoch 8/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3870 - accuracy: 0.8235 - val_loss: 0.4985 - val_accuracy: 0.7595
# Epoch 9/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3888 - accuracy: 0.8237 - val_loss: 0.4116 - val_accuracy: 0.7954
# Epoch 10/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.3876 - accuracy: 0.8237 - val_loss: 0.4418 - val_accuracy: 0.7897
# Epoch 11/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3875 - accuracy: 0.8247 - val_loss: 0.4016 - val_accuracy: 0.8090
# Epoch 12/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.3865 - accuracy: 0.8263 - val_loss: 0.4416 - val_accuracy: 0.7839
# Epoch 13/20
# 252/252 [==============================] - 2s 8ms/step - loss: 0.3875 - accuracy: 0.8245 - val_loss: 0.4342 - val_accuracy: 0.7861
# Epoch 14/20
# 252/252 [==============================] - 2s 8ms/step - loss: 0.3870 - accuracy: 0.8255 - val_loss: 0.3750 - val_accuracy: 0.8256
# Epoch 15/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.3879 - accuracy: 0.8248 - val_loss: 0.3843 - val_accuracy: 0.8134
# Epoch 16/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.3865 - accuracy: 0.8261 - val_loss: 0.4477 - val_accuracy: 0.7803
# Epoch 17/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3868 - accuracy: 0.8257 - val_loss: 0.4384 - val_accuracy: 0.7911
# Epoch 18/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3856 - accuracy: 0.8241 - val_loss: 0.4595 - val_accuracy: 0.7724
# Epoch 19/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3877 - accuracy: 0.8239 - val_loss: 0.4410 - val_accuracy: 0.7854
# Epoch 20/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3864 - accuracy: 0.8246 - val_loss: 0.4062 - val_accuracy: 0.8019

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_val, np.argmax(model.predict(X_val), axis=1))
# Out:
# 44/44 [==============================] - 0s 2ms/step
# array([[1081,  262],
#        [  14,   36]])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('CNN Model Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('CNN Model Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(train_metrics_callback.logs.get('f1score'), label='Training F1Score')
plt.plot(metrics_callback.logs.get('f1score'), label='Validation F1Score')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('CNN Model Training and Validation F1score')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(train_metrics_callback.logs.get('roc_auc'), label='Training ROC AUC')
plt.plot(metrics_callback.logs.get('roc_auc'), label='Validation ROC AUC')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('CNN Model Training and Validation ROC AUC')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Find Optimum Threshold

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, classification_report
import matplotlib.pyplot as plt

y_pred_prob = model.predict(X_val)[:, 1]

# Assuming y_val are the true labels and y_pred_prob are the predicted probabilities
# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Find the optimal threshold
youden_index = tpr - fpr
optimal_idx = np.argmax(youden_index)
optimal_threshold = thresholds[optimal_idx]

print(f'Optimal Threshold: {optimal_threshold}')

# Apply the optimal threshold
y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

# Evaluate performance at the optimal threshold
print(classification_report(y_val, y_pred_optimal))
print(f'ROC AUC Score: {roc_auc}')
# Out:
# 44/44 [==============================] - 0s 2ms/step
# Optimal Threshold: 0.29561781883239746
#               precision    recall  f1-score   support
#
#            0       0.99      0.69      0.82      1343
#            1       0.10      0.88      0.17        50
#
#     accuracy                           0.70      1393
#    macro avg       0.54      0.79      0.49      1393
# weighted avg       0.96      0.70      0.79      1393
#
# ROC AUC Score: 0.8550260610573343

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data=()):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data
        self.logs = {}

    def on_epoch_end(self, epoch, logs={}):
        if not self.validation_data:
            raise RuntimeError("Requires validation_data.")
        if self.logs.get('roc_auc', None) == None:
          self.logs['roc_auc'] = []
        if self.logs.get('f1score', None) == None:
          self.logs['f1score'] = []

        X_val, y_val = self.validation_data
        y_proba = self.model.predict(X_val, verbose=0)
        # y_pred = np.argmax(y_proba, axis=1)

        # Convert one-hot encoded labels to class labels
        y_pred =  [1 if preds[1] >= optimal_threshold else 0 for preds in y_pred]

        # Compute Metrics score
        f1score = f1_score(y_val, y_pred, average='weighted')
        roc_auc = roc_auc_score(y_val, y_pred, average='weighted')

        # Add Metrics score to logs
        self.logs['roc_auc'].append(roc_auc)
        self.logs['f1score'].append(f1score)

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

# Evaluate Model

y_proba = model.predict(X_val)
y_pred =  [1 if preds[1] >= optimal_threshold else 0 for preds in y_proba]


accuracy = accuracy_score(y_val, y_pred)
f1score = f1_score(y_val, y_pred, average='weighted')
auc = roc_auc_score(y_val, y_pred, average='weighted')

print("Accuracy: " + str(np.mean(accuracy)*100) + "%")
print("F1 Score: " + str(np.mean(f1score)*100) + "%")
print("AUC: " + str(np.mean(auc)*100) + "%")
# Out:
# 44/44 [==============================] - 0s 3ms/step
# Accuracy: 69.92103374012922%
# F1 Score: 79.30829171708021%
# AUC: 78.62397617274758%

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_val,y_pred)
# Out:
# array([[930, 413],
#        [  6,  44]])
