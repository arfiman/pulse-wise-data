# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import random

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import layers, models
import tensorflow_datasets as tfds
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, ClassifierMixin

import warnings
warnings.filterwarnings('ignore')

drive_path = '/content/drive/MyDrive/Kuliah/Tugas Akhir/Final Project Shared Folder'
data_path = "Dataset/Data Versioning/"
model_path = "Model/ML Model/"
data_version = "Trained_V2-3.csv"
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_raw = pd.read_csv(os.path.join(drive_path, data_path+data_version), index_col = 0)
try:
  df_raw = df_raw.set_index('SEQN', drop=True)
  df_raw = df_raw.drop(columns = "Unnamed: 0")
except:
  pass

df_raw.head()
# Out:
#          Dieta1_DRDINT  Dieta1_DR1TFIBE  Quest21_SLQ300  Quest19_PAD660  \
# SEQN
# 93705.0              1                0               2               2
# 93708.0              1                2               2               2
# 93709.0              0                2               2               1
# 93711.0              1                3               1               0
# 93713.0              1                1               2               1
#
#          Quest19_PAQ635  Dieta1_DR1TCHOL  Quest19_PAQ655  Dieta1_DR1TSFAT  \
# SEQN
# 93705.0             2.0                0               2                1
# 93708.0             2.0                0               2                1
# 93709.0             2.0                2               1                2
# 93711.0             1.0                3               3                3
# 93713.0             1.0                1               2                3
#
#          Dieta1_DR1TKCAL  Exami2_BMXBMI  ...  Quest1_ALQ111  Quest10_ECQ020  \
# SEQN                                     ...
# 93705.0                0              2  ...            1.0             9.0
# 93708.0                0              0  ...            2.0             9.0
# 93709.0                1              3  ...            9.0             9.0
# 93711.0                3              0  ...            1.0             9.0
# 93713.0                2              0  ...            1.0             9.0
#
#          Quest16_MCQ220  Quest4_CBD121  Quest16_MCQ366A  Labor2_URDFLOW1  \
# SEQN
# 93705.0             2.0   7.500000e+01              2.0            1.204
# 93708.0             2.0   5.397605e-79              2.0            0.500
# 93709.0             2.0   4.000000e+01              2.0            0.107
# 93711.0             2.0   8.570000e+02              2.0            0.605
# 93713.0             2.0   4.000000e+01              2.0            0.706
#
#          Demog1_DMDEDUC  Quest9_DLQ050  Quest20_PFQ061C  Quest16_MCQ160B
# SEQN
# 93705.0             2.0            2.0              1.0              2.0
# 93708.0             1.0            2.0              2.0              2.0
# 93709.0             4.0            1.0              9.0              2.0
# 93711.0             5.0            2.0              9.0              2.0
# 93713.0             3.0            2.0              1.0              2.0
#
# [5 rows x 86 columns]

# %%
def get_categorical(df):
    categorical = []
    for col in df.columns.tolist():
        try:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': model_var[model_var['model_var_name'] ==  col]['desc'].values[0],
                    'column': col,
                    'possible_values': df[col].unique().tolist()}
                            )
        except Exception as error:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': None,
                    'column': col,
                    'possible_values': df[col].unique().tolist()})
            # print(f'{col} error: {error}')
    return categorical

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTENC, SMOTE

def prep_data(df):
  X = df.copy().drop(columns=['Quest16_MCQ160B'])
  y = df['Quest16_MCQ160B']

  y = y.replace({2: 0})
  y = y.replace({9: 0})

  y = y.astype(int)

  categorical_summary = get_categorical(X)
  categorical_cols = [True if data_col in [col['column'] for col in categorical_summary] else False for data_col in X.columns.tolist()]

  X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42)

  # Instantiate the SMOTE oversampler
  smotenc = SMOTENC(
      categorical_features=categorical_cols,
      sampling_strategy='auto',
      random_state=37
    )

  # Apply SMOTE to generate synthetic samples
  X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

  scaler = StandardScaler()
  X_resampled.iloc[:, 28:] = scaler.fit_transform(X_resampled.iloc[:, 28:])
  X_val.iloc[:, 28:] = scaler.transform(X_val.iloc[:, 28:])

  X_resampled = np.array(X_resampled).reshape(X_resampled.shape[0], X_resampled.shape[1], 1)
  X_val = np.array(X_val).reshape(X_val.shape[0], X_val.shape[1], 1)

  print("Train: ", X_resampled.shape, " ", y_resampled.shape)
  print("Val: ", X_val.shape, " ", y_val.shape)
  print("Column Used: ", X.columns.tolist())

  return X_resampled, X_val, y_resampled, y_val

X_train, X_val, y_train, y_val = prep_data(df_raw)
input_shape = X_train.shape[1:]

print(y_train.value_counts())
print(y_val.value_counts())
# Out:
# Train:  (8050, 85, 1)   (8050,)
# Val:  (1393, 85, 1)   (1393,)
# Column Used:  ['Dieta1_DRDINT', 'Dieta1_DR1TFIBE', 'Quest21_SLQ300', 'Quest19_PAD660', 'Quest19_PAQ635', 'Dieta1_DR1TCHOL', 'Quest19_PAQ655', 'Dieta1_DR1TSFAT', 'Dieta1_DR1TKCAL', 'Exami2_BMXBMI', 'Dieta1_DR1TSUGR', 'Quest21_SLQ320', 'Quest21_SLQ330', 'Quest19_PAD615', 'Quest21_SLD012', 'Quest21_SLD013', 'Dieta1_DR1DAY', 'Quest6_DED120', 'Quest19_PAQ610', 'Quest6_DED125', 'Dieta1_DR1TPROT', 'Quest19_PAQ640', 'Dieta1_DR1TPFAT', 'Dieta1_DR1TMFAT', 'Dieta1_DR1TCALC', 'Dieta1_DR1TCARB', 'Dieta1_DR1TTFAT', 'Quest19_PAD645', 'Exami1_BPXPLS', 'Demog1_RIDRETH3', 'Demog1_DMDHHSZA', 'Demog1_DMDHHSZE', 'Quest14_INQ020', 'Quest18_OCQ210', 'Demog1_INDIN2', 'Quest12_HEQ030', 'Quest22_SMQ900', 'Exami2_BMXHT', 'Quest3_CDQ009', 'Quest3_CDQ010', 'Exami2_BMXWT', 'Quest3_CDQ008', 'Quest20_PFQ061H', 'Quest7_DIQ010', 'Quest20_PFQ061B', 'Labor1_LBDTCSI', 'Quest17_DPQ040', 'Demog1_RIAGENDR', 'Labor2_URDTIME1', 'Quest22_SMQ890', 'Demog1_DMDMARTL', 'Exami1_BPXPULS', 'Exami1_DiaPulse', 'Demog1_DMDFMSIZ', 'Quest16_MCQ300C', 'Demog1_RIDAGEYR', 'Demog1_DMDHHSZB', 'Labor1_LBXTC', 'Exami1_SysPulse', 'Quest16_MCQ010', 'Quest16_MCQ366B', 'Quest22_SMQ020', 'Quest14_IND235', 'Quest11_HIQ011', 'Quest20_PFQ020', 'Labor2_URXVOL1', 'Quest4_CBD111', 'Quest15_KIQ026', 'Quest17_DPQ020', 'Quest16_MCQ300A', 'Quest14_INQ012', 'Quest17_DPQ030', 'Quest15_KIQ022', 'Quest2_BPQ020', 'Demog1_DMDHHSIZ', 'Quest12_HEQ010', 'Quest1_ALQ111', 'Quest10_ECQ020', 'Quest16_MCQ220', 'Quest4_CBD121', 'Quest16_MCQ366A', 'Labor2_URDFLOW1', 'Demog1_DMDEDUC', 'Quest9_DLQ050', 'Quest20_PFQ061C']
# Quest16_MCQ160B
# 0    4025
# 1    4025
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1343
# 1      50
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTENC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

def prep_data_cross_validation(df, num_folds=5):
  X = df.copy().drop(columns=['Quest16_MCQ160B'])
  y = df['Quest16_MCQ160B']

  y = y.replace({2: 0})
  y = y.replace({9: 0})

  y = y.astype(int)

  categorical_summary = get_categorical(X)
  categorical_cols = [True if data_col in [col['column'] for col in categorical_summary] else False for data_col in X.columns.tolist()]

  kf = KFold(n_splits=num_folds, shuffle=True, random_state=37)

  for train_index, val_index in kf.split(X):
    X_train, X_val, y_train, y_val = X.iloc[train_index, :], X.iloc[val_index, :], y.iloc[train_index], y.iloc[val_index]\

    # Instantiate the SMOTE oversampler
    smotenc = SMOTENC(
        categorical_features=categorical_cols,
        sampling_strategy='auto',
        random_state=37
      )

    # Apply SMOTE to generate synthetic samples
    X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

    scaler = StandardScaler()
    X_resampled.iloc[:, 28:] = scaler.fit_transform(X_resampled.iloc[:, 28:])
    X_val.iloc[:, 28:] = scaler.transform(X_val.iloc[:, 28:])

    X_resampled = np.array(X_resampled).reshape(X_resampled.shape[0], X_resampled.shape[1], 1)
    X_val = np.array(X_val).reshape(X_val.shape[0], X_val.shape[1], 1)

    yield X_resampled, X_val, y_resampled, y_val

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data=()):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data
        self.logs = {}

    def on_epoch_end(self, epoch, logs={}):
        if not self.validation_data:
            raise RuntimeError("Requires validation_data.")
        if self.logs.get('roc_auc', None) == None:
          self.logs['roc_auc'] = []
        if self.logs.get('f1score', None) == None:
          self.logs['f1score'] = []

        X_val, y_val = self.validation_data
        y_proba = self.model.predict(X_val, verbose=0)
        y_pred = np.argmax(y_proba, axis=1)

        # Convert one-hot encoded labels to class labels
        # y_pred =  [1 if preds[1] >= 2.46069816967065e-06 else 0 for preds in y_pred]

        # Compute Metrics score
        f1score = f1_score(y_val, y_pred, average='weighted')
        roc_auc = roc_auc_score(y_val, y_pred, average='weighted')

        # Add Metrics score to logs
        self.logs['roc_auc'].append(roc_auc)
        self.logs['f1score'].append(f1score)

# %%
def build_model():
  model = models.Sequential()
  model.add(layers.Input(input_shape))
  model.add(layers.Conv1D(filters=8, kernel_size=3))
  model.add(layers.Flatten())
  model.add(layers.Dense(units=4))
  model.add(layers.Dense(2, activation='softmax'))

  # Compile the model
  model.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
  )

  return model

# %%
tf.random.set_seed(37)
random.seed(37)

loss = []
accuracy = []
f1score = []
auc = []
train_loss = []
train_accuracy = []
train_f1score = []
train_auc = []

for X_train, X_val, y_train, y_val in prep_data_cross_validation(df_raw, num_folds=4):
  print(y_train.value_counts())
  print(y_val.value_counts())

  model = build_model()

  metrics_callback = MetricsCallback(validation_data=(X_val, y_val))
  train_metrics_callback = MetricsCallback(validation_data=(X_train, y_train))

  model.fit(X_train, y_train, epochs=20, validation_data=(X_val, y_val), callbacks=[metrics_callback, train_metrics_callback])
  _loss, _accuracy = model.evaluate(X_val, y_val, verbose=0)
  loss.append(_loss)
  accuracy.append(_accuracy)
  f1score.append(metrics_callback.logs.get('f1score'))
  auc.append(metrics_callback.logs.get('roc_auc'))

  _train_loss, _train_accuracy = model.evaluate(X_train, y_train, verbose=0)
  train_loss.append(_train_loss)
  train_accuracy.append(_train_accuracy)
  train_f1score.append(train_metrics_callback.logs.get('f1score'))
  train_auc.append(train_metrics_callback.logs.get('roc_auc'))


print()
model.summary()
# Out:
# Quest16_MCQ160B
# 0    4022
# 1    4022
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1346
# 1      47
# Name: count, dtype: int64
# Epoch 1/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.2323 - accuracy: 0.9079 - val_loss: 0.1956 - val_accuracy: 0.9167
# Epoch 2/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1916 - accuracy: 0.9335 - val_loss: 0.2143 - val_accuracy: 0.9131
# Epoch 3/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1881 - accuracy: 0.9321 - val_loss: 0.2263 - val_accuracy: 0.9124
# Epoch 4/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.1857 - accuracy: 0.9318 - val_loss: 0.2912 - val_accuracy: 0.8916
# Epoch 5/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1837 - accuracy: 0.9370 - val_loss: 0.2241 - val_accuracy: 0.9124
# Epoch 6/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1814 - accuracy: 0.9359 - val_loss: 0.2337 - val_accuracy: 0.9081
# Epoch 7/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1804 - accuracy: 0.9360 - val_loss: 0.2721 - val_accuracy: 0.8952
# Epoch 8/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1790 - accuracy: 0.9372 - val_loss: 0.2327 - val_accuracy: 0.9095
# Epoch 9/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1802 - accuracy: 0.9372 - val_loss: 0.2159 - val_accuracy: 0.9139
# Epoch 10/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1799 - accuracy: 0.9355 - val_loss: 0.2607 - val_accuracy: 0.9002
# Epoch 11/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1783 - accuracy: 0.9382 - val_loss: 0.2878 - val_accuracy: 0.8902
# Epoch 12/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1781 - accuracy: 0.9349 - val_loss: 0.2625 - val_accuracy: 0.8973
# Epoch 13/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1761 - accuracy: 0.9392 - val_loss: 0.2184 - val_accuracy: 0.9131
# Epoch 14/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1765 - accuracy: 0.9371 - val_loss: 0.2236 - val_accuracy: 0.9088
# Epoch 15/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1765 - accuracy: 0.9372 - val_loss: 0.2708 - val_accuracy: 0.8966
# Epoch 16/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1769 - accuracy: 0.9380 - val_loss: 0.2518 - val_accuracy: 0.9031
# Epoch 17/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1761 - accuracy: 0.9386 - val_loss: 0.2053 - val_accuracy: 0.9210
# Epoch 18/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1767 - accuracy: 0.9365 - val_loss: 0.2227 - val_accuracy: 0.9124
# Epoch 19/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1760 - accuracy: 0.9372 - val_loss: 0.2473 - val_accuracy: 0.9017
# Epoch 20/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1767 - accuracy: 0.9371 - val_loss: 0.2573 - val_accuracy: 0.8995
# Quest16_MCQ160B
# 0    4040
# 1    4040
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1328
# 1      64
# Name: count, dtype: int64
# Epoch 1/20
# 253/253 [==============================] - 3s 8ms/step - loss: 0.2169 - accuracy: 0.9188 - val_loss: 0.2812 - val_accuracy: 0.8951
# Epoch 2/20
# 253/253 [==============================] - 2s 6ms/step - loss: 0.1699 - accuracy: 0.9434 - val_loss: 0.2496 - val_accuracy: 0.9102
# Epoch 3/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.1637 - accuracy: 0.9457 - val_loss: 0.2943 - val_accuracy: 0.8915
# Epoch 4/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.1606 - accuracy: 0.9474 - val_loss: 0.2772 - val_accuracy: 0.9030
# Epoch 5/20
# 253/253 [==============================] - 1s 6ms/step - loss: 0.1589 - accuracy: 0.9486 - val_loss: 0.2474 - val_accuracy: 0.9203
# Epoch 6/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.1597 - accuracy: 0.9474 - val_loss: 0.2718 - val_accuracy: 0.9001
# Epoch 7/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.1563 - accuracy: 0.9495 - val_loss: 0.2899 - val_accuracy: 0.9001
# Epoch 8/20
# 253/253 [==============================] - 1s 4ms/step - loss: 0.1579 - accuracy: 0.9481 - val_loss: 0.2700 - val_accuracy: 0.9131
# Epoch 9/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.1557 - accuracy: 0.9479 - val_loss: 0.2688 - val_accuracy: 0.9059
# Epoch 10/20
# 253/253 [==============================] - 1s 6ms/step - loss: 0.1565 - accuracy: 0.9494 - val_loss: 0.3191 - val_accuracy: 0.8858
# Epoch 11/20
# 253/253 [==============================] - 2s 7ms/step - loss: 0.1562 - accuracy: 0.9495 - val_loss: 0.2830 - val_accuracy: 0.9030
# Epoch 12/20
# 253/253 [==============================] - 2s 7ms/step - loss: 0.1547 - accuracy: 0.9488 - val_loss: 0.2768 - val_accuracy: 0.9052
# Epoch 13/20
# 253/253 [==============================] - 1s 6ms/step - loss: 0.1551 - accuracy: 0.9502 - val_loss: 0.2961 - val_accuracy: 0.9001
# Epoch 14/20
# 253/253 [==============================] - 1s 4ms/step - loss: 0.1548 - accuracy: 0.9509 - val_loss: 0.2735 - val_accuracy: 0.9080
# Epoch 15/20
# 253/253 [==============================] - 1s 6ms/step - loss: 0.1545 - accuracy: 0.9485 - val_loss: 0.2424 - val_accuracy: 0.9260
# Epoch 16/20
# 253/253 [==============================] - 1s 4ms/step - loss: 0.1545 - accuracy: 0.9500 - val_loss: 0.2634 - val_accuracy: 0.9131
# Epoch 17/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.1534 - accuracy: 0.9490 - val_loss: 0.2682 - val_accuracy: 0.9109
# Epoch 18/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.1529 - accuracy: 0.9515 - val_loss: 0.2609 - val_accuracy: 0.9116
# Epoch 19/20
# 253/253 [==============================] - 1s 4ms/step - loss: 0.1524 - accuracy: 0.9512 - val_loss: 0.2534 - val_accuracy: 0.9152
# Epoch 20/20
# 253/253 [==============================] - 1s 5ms/step - loss: 0.1536 - accuracy: 0.9500 - val_loss: 0.2689 - val_accuracy: 0.9095
# Quest16_MCQ160B
# 0    4017
# 1    4017
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1351
# 1      41
# Name: count, dtype: int64
# Epoch 1/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.2251 - accuracy: 0.9167 - val_loss: 0.1860 - val_accuracy: 0.9217
# Epoch 2/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1725 - accuracy: 0.9449 - val_loss: 0.2507 - val_accuracy: 0.8980
# Epoch 3/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1691 - accuracy: 0.9439 - val_loss: 0.2305 - val_accuracy: 0.9066
# Epoch 4/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1688 - accuracy: 0.9435 - val_loss: 0.2875 - val_accuracy: 0.8851
# Epoch 5/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1668 - accuracy: 0.9452 - val_loss: 0.2368 - val_accuracy: 0.9037
# Epoch 6/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1659 - accuracy: 0.9449 - val_loss: 0.1839 - val_accuracy: 0.9253
# Epoch 7/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.1639 - accuracy: 0.9454 - val_loss: 0.2234 - val_accuracy: 0.9109
# Epoch 8/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1630 - accuracy: 0.9457 - val_loss: 0.1941 - val_accuracy: 0.9239
# Epoch 9/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1641 - accuracy: 0.9472 - val_loss: 0.2249 - val_accuracy: 0.9095
# Epoch 10/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1633 - accuracy: 0.9472 - val_loss: 0.2041 - val_accuracy: 0.9203
# Epoch 11/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1617 - accuracy: 0.9462 - val_loss: 0.2316 - val_accuracy: 0.9066
# Epoch 12/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1627 - accuracy: 0.9476 - val_loss: 0.2271 - val_accuracy: 0.9102
# Epoch 13/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1607 - accuracy: 0.9473 - val_loss: 0.2345 - val_accuracy: 0.9052
# Epoch 14/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1599 - accuracy: 0.9467 - val_loss: 0.2202 - val_accuracy: 0.9080
# Epoch 15/20
# 252/252 [==============================] - 1s 6ms/step - loss: 0.1618 - accuracy: 0.9478 - val_loss: 0.1992 - val_accuracy: 0.9203
# Epoch 16/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1609 - accuracy: 0.9467 - val_loss: 0.2333 - val_accuracy: 0.9045
# Epoch 17/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.1603 - accuracy: 0.9485 - val_loss: 0.2126 - val_accuracy: 0.9131
# Epoch 18/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1616 - accuracy: 0.9476 - val_loss: 0.2406 - val_accuracy: 0.9052
# Epoch 19/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1593 - accuracy: 0.9470 - val_loss: 0.1959 - val_accuracy: 0.9203
# Epoch 20/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1602 - accuracy: 0.9483 - val_loss: 0.2168 - val_accuracy: 0.9124
# Quest16_MCQ160B
# 0    4025
# 1    4025
# Name: count, dtype: int64
# Quest16_MCQ160B
# 0    1343
# 1      49
# Name: count, dtype: int64
# Epoch 1/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1988 - accuracy: 0.9276 - val_loss: 0.3064 - val_accuracy: 0.8836
# Epoch 2/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1538 - accuracy: 0.9486 - val_loss: 0.2819 - val_accuracy: 0.9073
# Epoch 3/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.1482 - accuracy: 0.9513 - val_loss: 0.3458 - val_accuracy: 0.8901
# Epoch 4/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1446 - accuracy: 0.9530 - val_loss: 0.3254 - val_accuracy: 0.8944
# Epoch 5/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1449 - accuracy: 0.9529 - val_loss: 0.2779 - val_accuracy: 0.9138
# Epoch 6/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1428 - accuracy: 0.9530 - val_loss: 0.3270 - val_accuracy: 0.8915
# Epoch 7/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1411 - accuracy: 0.9561 - val_loss: 0.2931 - val_accuracy: 0.9095
# Epoch 8/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1404 - accuracy: 0.9559 - val_loss: 0.2594 - val_accuracy: 0.9231
# Epoch 9/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1407 - accuracy: 0.9580 - val_loss: 0.2927 - val_accuracy: 0.9109
# Epoch 10/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.1396 - accuracy: 0.9557 - val_loss: 0.2642 - val_accuracy: 0.9167
# Epoch 11/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1391 - accuracy: 0.9555 - val_loss: 0.3120 - val_accuracy: 0.8966
# Epoch 12/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1385 - accuracy: 0.9548 - val_loss: 0.2810 - val_accuracy: 0.9131
# Epoch 13/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1399 - accuracy: 0.9550 - val_loss: 0.2941 - val_accuracy: 0.9116
# Epoch 14/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1384 - accuracy: 0.9560 - val_loss: 0.2915 - val_accuracy: 0.9059
# Epoch 15/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1383 - accuracy: 0.9566 - val_loss: 0.3016 - val_accuracy: 0.9030
# Epoch 16/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1368 - accuracy: 0.9561 - val_loss: 0.2790 - val_accuracy: 0.9116
# Epoch 17/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1381 - accuracy: 0.9566 - val_loss: 0.2945 - val_accuracy: 0.9066
# Epoch 18/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1368 - accuracy: 0.9575 - val_loss: 0.2835 - val_accuracy: 0.9095
# Epoch 19/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1382 - accuracy: 0.9569 - val_loss: 0.3147 - val_accuracy: 0.8966
# Epoch 20/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1363 - accuracy: 0.9579 - val_loss: 0.2967 - val_accuracy: 0.9073
#
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_24 (Conv1D)          (None, 83, 8)             32
#
#  flatten_14 (Flatten)        (None, 664)               0
#
#  dense_33 (Dense)            (None, 4)                 2660
#
#  dense_34 (Dense)            (None, 2)                 10
#
# =================================================================
# Total params: 2702 (10.55 KB)
# Trainable params: 2702 (10.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Evaluate Model

print(loss)
print(accuracy)
print(f1score)
print(auc)

print("Training Loss: " + str(np.mean(train_loss)*100) + "%")
print("Training Accuracy: " + str(np.mean(train_accuracy)*100) + "%")
print("Training F1 Score: " + str(np.mean(np.array(train_f1score)[:, -1])*100) + "%")
print("Training AUC: " + str(np.mean(np.array(train_auc)[:, -1])*100) + "%")

print("Loss: " + str(np.mean(loss)*100) + "%")
print("Accuracy: " + str(np.mean(accuracy)*100) + "%")
print("F1 Score: " + str(np.mean(np.array(f1score)[:, -1])*100) + "%")
print("AUC: " + str(np.mean(np.array(auc)[:, -1])*100) + "%")
# Out:
# [0.25734180212020874, 0.2689332365989685, 0.21680417656898499, 0.29674091935157776]
# [0.8994975090026855, 0.9094827771186829, 0.9123563170433044, 0.9073275923728943]
# [[0.9338895905552721, 0.9311667314186893, 0.9314457856781544, 0.9195530588769067, 0.9314457856781544, 0.9289954530099378, 0.9217778481285458, 0.9296632818736813, 0.9321026150204156, 0.924709779805838, 0.9188364809753984, 0.9227382610095767, 0.9314151018690623, 0.9292184996991464, 0.922483883469212, 0.9256707654007981, 0.9357949722987841, 0.9314457856781544, 0.9252040794151193, 0.9240708569918425], [0.9146833211985215, 0.9241963328712536, 0.9118877806962605, 0.9189863142163162, 0.9282873912170717, 0.916299531651805, 0.9174065006952163, 0.9239645763276169, 0.9199716378774249, 0.9087073687709422, 0.9189863142163162, 0.919806300553427, 0.9174065006952163, 0.9213564639865868, 0.9309252534691863, 0.9242898396328547, 0.9225762699634429, 0.9233608589501021, 0.9243172738370569, 0.9216536892843901], [0.9383052750779075, 0.9242624360896478, 0.9296527502532258, 0.9168874968843959, 0.9274882194917867, 0.9402233530482362, 0.9317956479775379, 0.9390738021453177, 0.9304518062606123, 0.9374328322856376, 0.9289777006974888, 0.9318212688998706, 0.9278850499389885, 0.9298362544776191, 0.9369057359713727, 0.9279181569081566, 0.9328477553675992, 0.9287867569282843, 0.9369057359713727, 0.9321669177124877], [0.9112359074391373, 0.9240276047959848, 0.9151225135288126, 0.9169258462197619, 0.9275374872544041, 0.9152141431078291, 0.9256354877840804, 0.9323359383529188, 0.9268158768668726, 0.9281140797703945, 0.9179279573821566, 0.9263885440758213, 0.925543982843618, 0.9225169396697689, 0.92115172307251, 0.9262558557497473, 0.9236003425497618, 0.9242789254575445, 0.9176377328577091, 0.9226585804204666]]
# [[0.7413059972811483, 0.7189149884606872, 0.7493439979766685, 0.7899054724795297, 0.7493439979766685, 0.7573819986721886, 0.7917628276058297, 0.7478581138756285, 0.7398201131801082, 0.7840962979355695, 0.79942935727609, 0.7723435869874491, 0.7291818153077677, 0.7474866428503684, 0.7822389428092694, 0.7445148746482881, 0.7127343428914672, 0.7493439979766685, 0.7643055862919289, 0.7734580000632292], [0.7293862951807228, 0.7298569277108433, 0.7126317771084337, 0.7112198795180723, 0.6756400602409638, 0.6874058734939759, 0.7171498493975903, 0.6793109939759036, 0.690417921686747, 0.7244917168674698, 0.7112198795180723, 0.6974774096385542, 0.7171498493975903, 0.6915474397590362, 0.6563441265060241, 0.6867469879518072, 0.6781814759036144, 0.6859939759036144, 0.658132530120482, 0.6774284638554217], [0.7113339712227618, 0.7109458215233522, 0.7272120019497752, 0.7279341409254212, 0.7020815655972992, 0.7013594266216533, 0.7057825278474843, 0.6887942084454153, 0.6813922839450451, 0.7105937787727248, 0.6917369247711722, 0.7290624830748678, 0.6791717065949342, 0.6924771172212092, 0.6869437273203227, 0.7024516618223178, 0.6950677907963387, 0.7264718094997382, 0.6869437273203227, 0.6828726688451192], [0.6545656237178415, 0.6176926466789249, 0.6579163310893977, 0.6306547935629948, 0.6112115732368896, 0.6291655902867476, 0.6286413299497013, 0.5963879222575107, 0.6392177124014162, 0.5832054340723631, 0.6219399152065889, 0.5911757107906453, 0.5904311091525217, 0.5972844834136186, 0.6056270609509626, 0.6100946707797043, 0.6173203458598631, 0.5893142066953364, 0.6121081343929977, 0.5783655234245597]]
# Training Loss: 14.951197057962418%
# Training Accuracy: 95.12815028429031%
# Training F1 Score: 95.12557928288925%
# Training AUC: 95.12815064055377%
# Loss: 25.9955033659935%
# Accuracy: 90.71660488843918%
# F1 Score: 92.51375111022966%
# AUC: 67.80311640470825%

# %%
model = build_model()

model.summary()

X_train, X_val, y_train, y_val = prep_data(df_raw)


metrics_callback = MetricsCallback(validation_data=(X_val, y_val))
train_metrics_callback = MetricsCallback(validation_data=(X_train, y_train))

history = model.fit(X_train, y_train, epochs=20, validation_data=(X_val, y_val), callbacks=[metrics_callback, train_metrics_callback])
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_25 (Conv1D)          (None, 83, 8)             32
#
#  flatten_15 (Flatten)        (None, 664)               0
#
#  dense_35 (Dense)            (None, 4)                 2660
#
#  dense_36 (Dense)            (None, 2)                 10
#
# =================================================================
# Total params: 2702 (10.55 KB)
# Trainable params: 2702 (10.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Train:  (8050, 85, 1)   (8050,)
# Val:  (1393, 85, 1)   (1393,)
# Column Used:  ['Dieta1_DRDINT', 'Dieta1_DR1TFIBE', 'Quest21_SLQ300', 'Quest19_PAD660', 'Quest19_PAQ635', 'Dieta1_DR1TCHOL', 'Quest19_PAQ655', 'Dieta1_DR1TSFAT', 'Dieta1_DR1TKCAL', 'Exami2_BMXBMI', 'Dieta1_DR1TSUGR', 'Quest21_SLQ320', 'Quest21_SLQ330', 'Quest19_PAD615', 'Quest21_SLD012', 'Quest21_SLD013', 'Dieta1_DR1DAY', 'Quest6_DED120', 'Quest19_PAQ610', 'Quest6_DED125', 'Dieta1_DR1TPROT', 'Quest19_PAQ640', 'Dieta1_DR1TPFAT', 'Dieta1_DR1TMFAT', 'Dieta1_DR1TCALC', 'Dieta1_DR1TCARB', 'Dieta1_DR1TTFAT', 'Quest19_PAD645', 'Exami1_BPXPLS', 'Demog1_RIDRETH3', 'Demog1_DMDHHSZA', 'Demog1_DMDHHSZE', 'Quest14_INQ020', 'Quest18_OCQ210', 'Demog1_INDIN2', 'Quest12_HEQ030', 'Quest22_SMQ900', 'Exami2_BMXHT', 'Quest3_CDQ009', 'Quest3_CDQ010', 'Exami2_BMXWT', 'Quest3_CDQ008', 'Quest20_PFQ061H', 'Quest7_DIQ010', 'Quest20_PFQ061B', 'Labor1_LBDTCSI', 'Quest17_DPQ040', 'Demog1_RIAGENDR', 'Labor2_URDTIME1', 'Quest22_SMQ890', 'Demog1_DMDMARTL', 'Exami1_BPXPULS', 'Exami1_DiaPulse', 'Demog1_DMDFMSIZ', 'Quest16_MCQ300C', 'Demog1_RIDAGEYR', 'Demog1_DMDHHSZB', 'Labor1_LBXTC', 'Exami1_SysPulse', 'Quest16_MCQ010', 'Quest16_MCQ366B', 'Quest22_SMQ020', 'Quest14_IND235', 'Quest11_HIQ011', 'Quest20_PFQ020', 'Labor2_URXVOL1', 'Quest4_CBD111', 'Quest15_KIQ026', 'Quest17_DPQ020', 'Quest16_MCQ300A', 'Quest14_INQ012', 'Quest17_DPQ030', 'Quest15_KIQ022', 'Quest2_BPQ020', 'Demog1_DMDHHSIZ', 'Quest12_HEQ010', 'Quest1_ALQ111', 'Quest10_ECQ020', 'Quest16_MCQ220', 'Quest4_CBD121', 'Quest16_MCQ366A', 'Labor2_URDFLOW1', 'Demog1_DMDEDUC', 'Quest9_DLQ050', 'Quest20_PFQ061C']
# Epoch 1/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.2203 - accuracy: 0.9159 - val_loss: 0.2562 - val_accuracy: 0.9002
# Epoch 2/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1756 - accuracy: 0.9391 - val_loss: 0.2296 - val_accuracy: 0.9189
# Epoch 3/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1713 - accuracy: 0.9426 - val_loss: 0.2283 - val_accuracy: 0.9203
# Epoch 4/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1696 - accuracy: 0.9439 - val_loss: 0.2812 - val_accuracy: 0.8938
# Epoch 5/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1714 - accuracy: 0.9424 - val_loss: 0.2230 - val_accuracy: 0.9232
# Epoch 6/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1683 - accuracy: 0.9420 - val_loss: 0.2231 - val_accuracy: 0.9189
# Epoch 7/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1658 - accuracy: 0.9446 - val_loss: 0.2246 - val_accuracy: 0.9203
# Epoch 8/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1643 - accuracy: 0.9466 - val_loss: 0.2520 - val_accuracy: 0.9009
# Epoch 9/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.1666 - accuracy: 0.9426 - val_loss: 0.2301 - val_accuracy: 0.9153
# Epoch 10/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1638 - accuracy: 0.9453 - val_loss: 0.2125 - val_accuracy: 0.9218
# Epoch 11/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1638 - accuracy: 0.9447 - val_loss: 0.2192 - val_accuracy: 0.9210
# Epoch 12/20
# 252/252 [==============================] - 2s 6ms/step - loss: 0.1624 - accuracy: 0.9458 - val_loss: 0.2334 - val_accuracy: 0.9095
# Epoch 13/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1615 - accuracy: 0.9480 - val_loss: 0.2467 - val_accuracy: 0.9074
# Epoch 14/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1626 - accuracy: 0.9472 - val_loss: 0.2290 - val_accuracy: 0.9131
# Epoch 15/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1625 - accuracy: 0.9443 - val_loss: 0.2234 - val_accuracy: 0.9160
# Epoch 16/20
# 252/252 [==============================] - 1s 4ms/step - loss: 0.1613 - accuracy: 0.9456 - val_loss: 0.2160 - val_accuracy: 0.9203
# Epoch 17/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1616 - accuracy: 0.9471 - val_loss: 0.2393 - val_accuracy: 0.9117
# Epoch 18/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1621 - accuracy: 0.9466 - val_loss: 0.2280 - val_accuracy: 0.9167
# Epoch 19/20
# 252/252 [==============================] - 2s 7ms/step - loss: 0.1617 - accuracy: 0.9463 - val_loss: 0.2829 - val_accuracy: 0.8916
# Epoch 20/20
# 252/252 [==============================] - 1s 5ms/step - loss: 0.1603 - accuracy: 0.9471 - val_loss: 0.2251 - val_accuracy: 0.9153

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_val, np.argmax(model.predict(X_val), axis=1))
# Out:
# 44/44 [==============================] - 0s 2ms/step
# array([[1257,   86],
#        [  32,   18]])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('CNN Model Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('CNN Model Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(train_metrics_callback.logs.get('f1score'), label='Training F1Score')
plt.plot(metrics_callback.logs.get('f1score'), label='Validation F1Score')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('CNN Model Training and Validation F1score')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(train_metrics_callback.logs.get('roc_auc'), label='Training ROC AUC')
plt.plot(metrics_callback.logs.get('roc_auc'), label='Validation ROC AUC')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('CNN Model Training and Validation ROC AUC')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Find Optimum Threshold

# %%
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, classification_report
import matplotlib.pyplot as plt

y_pred_prob = model.predict(X_val)[:, 1]

# Assuming y_val are the true labels and y_pred_prob are the predicted probabilities
# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)
roc_auc = roc_auc_score(y_val, y_pred_prob)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Find the optimal threshold
youden_index = tpr - fpr
optimal_idx = np.argmax(youden_index)
optimal_threshold = thresholds[optimal_idx]

print(f'Optimal Threshold: {optimal_threshold}')

# Apply the optimal threshold
y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

# Evaluate performance at the optimal threshold
print(classification_report(y_val, y_pred_optimal))
print(f'ROC AUC Score: {roc_auc}')
# Out:
# 44/44 [==============================] - 0s 3ms/step
# Optimal Threshold: 0.010290083475410938
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82      1343
#            1       0.10      0.94      0.19        50
#
#     accuracy                           0.70      1393
#    macro avg       0.55      0.82      0.50      1393
# weighted avg       0.96      0.70      0.80      1393
#
# ROC AUC Score: 0.8561429635145197

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data=()):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data
        self.logs = {}

    def on_epoch_end(self, epoch, logs={}):
        if not self.validation_data:
            raise RuntimeError("Requires validation_data.")
        if self.logs.get('roc_auc', None) == None:
          self.logs['roc_auc'] = []
        if self.logs.get('f1score', None) == None:
          self.logs['f1score'] = []

        X_val, y_val = self.validation_data
        y_proba = self.model.predict(X_val, verbose=0)
        # y_pred = np.argmax(y_proba, axis=1)

        # Convert one-hot encoded labels to class labels
        y_pred =  [1 if preds[1] >= optimal_threshold else 0 for preds in y_pred]

        # Compute Metrics score
        f1score = f1_score(y_val, y_pred, average='weighted')
        roc_auc = roc_auc_score(y_val, y_pred, average='weighted')

        # Add Metrics score to logs
        self.logs['roc_auc'].append(roc_auc)
        self.logs['f1score'].append(f1score)

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

# Evaluate Model

y_proba = model.predict(X_val)
y_pred =  [1 if preds[1] >= optimal_threshold else 0 for preds in y_proba]


accuracy = accuracy_score(y_val, y_pred)
f1score = f1_score(y_val, y_pred, average='weighted')
auc = roc_auc_score(y_val, y_pred, average='weighted')

print("Accuracy: " + str(np.mean(accuracy)*100) + "%")
print("F1 Score: " + str(np.mean(f1score)*100) + "%")
print("AUC: " + str(np.mean(auc)*100) + "%")
# Out:
# 44/44 [==============================] - 0s 2ms/step
# Accuracy: 70.42354630294328%
# F1 Score: 79.6558565261347%
# AUC: 81.77289650037228%

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_val,y_pred)
# Out:
# array([[934, 409],
#        [  3,  47]])
