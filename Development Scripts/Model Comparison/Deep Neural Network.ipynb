# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import random
import itertools
import pprint
from imblearn.over_sampling import SMOTENC

from sklearn.metrics import confusion_matrix

import warnings
warnings.filterwarnings('ignore')

drive_path = '/content/drive/MyDrive/Kuliah/Tugas Akhir/Final Project Shared Folder'
data_path = "Dataset/Data Versioning/"
model_path = "Model/ML Model/"
data_version = "Trained_V2-3.csv"
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']

# Ingest Data

df_raw = pd.read_csv(os.path.join(drive_path, data_path+data_version), index_col = 0)
try:
  df_raw = df_raw.set_index('SEQN', drop=True)
  df_raw = df_raw.drop(columns = "Unnamed: 0")
except:
  pass

df_raw.head()
# Out:
#          Dieta1_DRDINT  Dieta1_DR1TFIBE  Quest21_SLQ300  Quest19_PAD660  \
# SEQN
# 93705.0              1                0               2               2
# 93708.0              1                2               2               2
# 93709.0              0                2               2               1
# 93711.0              1                3               1               0
# 93713.0              1                1               2               1
#
#          Quest19_PAQ635  Dieta1_DR1TCHOL  Quest19_PAQ655  Dieta1_DR1TSFAT  \
# SEQN
# 93705.0             2.0                0               2                1
# 93708.0             2.0                0               2                1
# 93709.0             2.0                2               1                2
# 93711.0             1.0                3               3                3
# 93713.0             1.0                1               2                3
#
#          Dieta1_DR1TKCAL  Exami2_BMXBMI  ...  Quest1_ALQ111  Quest10_ECQ020  \
# SEQN                                     ...
# 93705.0                0              2  ...            1.0             9.0
# 93708.0                0              0  ...            2.0             9.0
# 93709.0                1              3  ...            9.0             9.0
# 93711.0                3              0  ...            1.0             9.0
# 93713.0                2              0  ...            1.0             9.0
#
#          Quest16_MCQ220  Quest4_CBD121  Quest16_MCQ366A  Labor2_URDFLOW1  \
# SEQN
# 93705.0             2.0   7.500000e+01              2.0            1.204
# 93708.0             2.0   5.397605e-79              2.0            0.500
# 93709.0             2.0   4.000000e+01              2.0            0.107
# 93711.0             2.0   8.570000e+02              2.0            0.605
# 93713.0             2.0   4.000000e+01              2.0            0.706
#
#          Demog1_DMDEDUC  Quest9_DLQ050  Quest20_PFQ061C  Quest16_MCQ160B
# SEQN
# 93705.0             2.0            2.0              1.0              2.0
# 93708.0             1.0            2.0              2.0              2.0
# 93709.0             4.0            1.0              9.0              2.0
# 93711.0             5.0            2.0              9.0              2.0
# 93713.0             3.0            2.0              1.0              2.0
#
# [5 rows x 86 columns]

# %%
log_raw = pd.DataFrame({
    'convolution_part':[],
    'convolution_hyperparameter':[],
    'dense_part':[],
    'dense_hyperparameter':[],
    'input_shape':[],
    'layer_metadata':[]
})

log_raw.head()
# Out:
# Empty DataFrame
# Columns: [convolution_part, convolution_hyperparameter, dense_part, dense_hyperparameter, input_shape, layer_metadata]
# Index: []

# %%
def get_categorical(df):
    categorical = []
    for col in df.columns.tolist():
        try:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': model_var[model_var['model_var_name'] ==  col]['desc'].values[0],
                    'column': col,
                    'possible_values': df[col].unique().tolist()}
                            )
        except Exception as error:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': None,
                    'column': col,
                    'possible_values': df[col].unique().tolist()})
            # print(f'{col} error: {error}')
    return categorical

X = df_raw.copy().drop(columns=['Quest16_MCQ160B'])
y = df_raw['Quest16_MCQ160B']

categorical_summary = get_categorical(X)
categorical_cols = [True if data_col in [col['column'] for col in categorical_summary] else False for data_col in X.columns.tolist()]
print(categorical_cols)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, False, True, True, False, True, True, False, True, True, True, True, False, True, True, False, True, True, False, False, True, True, False, True, False, False, True, True, True, True, True, True, False, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, False, True, True, True]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from imblearn.over_sampling import SMOTENC

def prep_data_cross_validation(df, num_folds=5):
  X = df.copy().drop(columns=['Quest16_MCQ160B'])
  y = df['Quest16_MCQ160B']

  y = y.replace({2: 0})
  y = y.replace({9: 0})

  y = y.astype(int)

  kf = KFold(n_splits=num_folds, shuffle=True, random_state=37)

  for train_index, val_index in kf.split(X):
    X_train, X_val, y_train, y_val = X.iloc[train_index, :], X.iloc[val_index, :], y.iloc[train_index], y.iloc[val_index]
    # Instantiate the SMOTE oversampler
    smotenc = SMOTENC(
          categorical_features=categorical_cols,
          sampling_strategy='auto',
          random_state=37
        )

      # Apply SMOTE to generate synthetic samples
    X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

    scaler = StandardScaler()
    X_resampled.iloc[:, 28:] = scaler.fit_transform(X_resampled.iloc[:, 28:])
    X_val.iloc[:, 28:] = scaler.transform(X_val.iloc[:, 28:])

    X_resampled = np.array(X_resampled).reshape(X_resampled.shape[0], X_resampled.shape[1], 1)
    X_val = np.array(X_val).reshape(X_val.shape[0], X_val.shape[1], 1)

    yield X_resampled, X_val, y_resampled, y_val

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTENC

def prep_data(df):
  X = df.copy().drop(columns=['Quest16_MCQ160B'])
  y = df['Quest16_MCQ160B']

  y = y.replace({2: 0})
  y = y.replace({9: 0})

  y = y.astype(int)

  X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

  # Instantiate the SMOTE oversampler
  smotenc = SMOTENC(
      categorical_features=categorical_cols,
      sampling_strategy='auto',
      random_state=37
    )

  # Apply SMOTE to generate synthetic samples
  X_resampled, y_resampled = smotenc.fit_resample(X_train, y_train)

  scaler = StandardScaler()
  X_resampled.iloc[:, 28:] = scaler.fit_transform(X_resampled.iloc[:, 28:])
  X_val.iloc[:, 28:] = scaler.transform(X_val.iloc[:, 28:])

  X_resampled = np.array(X_resampled).reshape(X_resampled.shape[0], X_resampled.shape[1], 1)
  X_val = np.array(X_val).reshape(X_val.shape[0], X_val.shape[1], 1)

  print("Train: ", X_resampled.shape, " ", y_resampled.shape)
  print("Val: ", X_val.shape, " ", y_val.shape)
  print("Column Used: ", X.columns.tolist())

  return X_resampled, X_val, y_resampled, y_val

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import tensorflow_datasets as tfds
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, ClassifierMixin

class CNNModel(BaseEstimator, ClassifierMixin):
  def __init__(
      self,
      input_shape,
      layer_metadata,
      convolution_part=['conv1d'],
      intermediate_part=['flatten'],
      dense_part=['dense'],
      convolution_hyperparameter=[{'filters':16, 'kernel_size':3, 'activation':'relu'}],
      intermediate_hyperparameter=[{}],
      dense_hyperparameter=[{'units':32, 'activation':'relu'}],
      optimizer='adam'
  ):
    self.input_shape = input_shape
    self.layer_metadata = layer_metadata
    self.convolution_part = convolution_part
    self.intermediate_part = intermediate_part
    self.dense_part = dense_part
    self.convolution_hyperparameter = convolution_hyperparameter
    self.intermediate_hyperparameter = intermediate_hyperparameter
    self.dense_hyperparameter = dense_hyperparameter
    self.optimizer = optimizer
    self.model = self.build_model(input_shape, convolution_part, intermediate_part, dense_part, convolution_hyperparameter, intermediate_hyperparameter, dense_hyperparameter, optimizer)

  def build_model(
      self,
      input_shape,
      convolution_part,
      intermediate_part,
      dense_part,
      convolution_hyperparameter,
      intermediate_hyperparameter,
      dense_hyperparameter,
      optimizer,
  ):

    def fix_hyperparameter_type(layer, hyperparameter, layer_metadata, warnings=True):
      for layer_info in layer_metadata:
        if(layer == layer_info['layer']):
          for params in layer_info['hyperparameter']:
            val = hyperparameter.get(params['param'], params['default'])
            if(type(val) != params['type']):
              if(warnings): print("Hyperparameter ", params['param'], " Have Invalid Data Type! Using Default..")
              hyperparameter[params['param']] = params['default']
            else:
              hyperparameter[params['param']] = val
        else:
          pass
      return hyperparameter

    model = models.Sequential()
    model.add(layers.Input(input_shape))

    # Convolution Part
    for layer, hyperparameter in zip(convolution_part, convolution_hyperparameter):
      hyperparameter = fix_hyperparameter_type(layer, hyperparameter, self.layer_metadata)

      if(layer == 'conv1d'):
        model.add(layers.Conv1D(filters=hyperparameter['filters'], kernel_size=hyperparameter['kernel_size'], activation=hyperparameter['activation']))
      elif(layer == 'maxpooling1d'):
        model.add(layers.MaxPooling1D(pool_size=hyperparameter['pool_size']))
      else:
        print("'Convolution Part' Layer Invalid!")
        return None

    # Intermediate Part
    for layer, hyperparameter in zip(intermediate_part, intermediate_hyperparameter):
      hyperparameter = fix_hyperparameter_type(layer, hyperparameter, self.layer_metadata)

      if(layer == 'flatten'):
        model.add(layers.Flatten())
      else:
        print("'Intermediate Part' Layer Invalid!")
        return None

    # Dense Part
    for layer, hyperparameter in zip(dense_part, dense_hyperparameter):
      hyperparameter = fix_hyperparameter_type(layer, hyperparameter, self.layer_metadata)

      if(layer == 'dense'):
        model.add(layers.Dense(units=hyperparameter['units'], activation=hyperparameter['activation']))
      else:
        print("'Dense Part' Layer Invalid!")
        return None

    model.add(layers.Dense(2, activation='softmax'))

    # Compile the model
    model.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=[
                    'accuracy'
                ])

    return model

  def fit(self, X_train, y_train, X_test, y_test, epochs, verbose=1, callbacks=[]):
    self.model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), verbose=verbose, callbacks=callbacks)

  def score(self, X, y):
    loss, accuracy = self.model.evaluate(X, y, verbose=0)
    loss_inverse = 1/(loss+1e-20)

    return loss_inverse

  def evaluate(self, X, y, verbose=1):
    # Evaluate the model on the test set
    loss, accuracy = self.model.evaluate(X, y, verbose=0)

    if(verbose != 0):
      print(f"Loss: %.3f%%" % (loss*100) )
      print(f"Accuracy: %.3f%%" % (accuracy*100) )

    return loss, accuracy

  def summary(self):
    self.model.summary()

  def predict(self, X):
    return self.model.predict(X, verbose=0)

  def save(self, path, save_format='keras'):
    return self.model.save(path, save_format)

# %%
layer_metadata = [
  {'layer': 'conv1d', 'hyperparameter': [
      {'param':'filters', 'type':int, 'default':16},
      {'param':'kernel_size', 'type':int, 'default':3},
      {'param':'activation', 'type':str, 'default':'linear'}
    ]
  },
  {'layer': 'maxpooling1d', 'hyperparameter': [
      {'param':'pool_size', 'type':int, 'default':2}
    ]
  },
  {'layer': 'conv2d', 'hyperparameter': [
      {'param':'filters', 'type':int, 'default':16},
      {'param':'kernel_size', 'type':tuple, 'default':(3,3)},
      {'param':'activation', 'type':str, 'default':'linear'}
    ]
  },
  {'layer': 'maxpooling2d', 'hyperparameter': [
      {'param':'pool_size', 'type':tuple, 'default':(2,2)}
    ]
  },
  {'layer': 'flatten', 'hyperparameter': [

    ]
  },
  {'layer': 'dense', 'hyperparameter': [
      {'param':'units', 'type':int, 'default':8},
      {'param':'activation', 'type':str, 'default':'linear'}
    ]
  }
]

# %%
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score
from sklearn.metrics import roc_curve, roc_auc_score

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data=()):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data
        self.logs = {}

    def on_epoch_end(self, epoch, logs={}):
        if not self.validation_data:
            raise RuntimeError("Requires validation_data.")

        X_val, y_val = self.validation_data
        y_proba = self.model.predict(X_val, verbose=0)

        # Convert one-hot encoded labels to class labels
        y_pred = np.argmax(y_proba, axis=1)

        # Compute Metrics score
        f1score = f1_score(y_val, y_pred, average='weighted')
        roc_auc = roc_auc_score(y_val, y_pred, average='weighted')

        # Add Metrics score to logs
        self.logs['roc_auc'] = roc_auc
        self.logs['f1score'] = f1score

        # Calculate ROC curve
        fpr, tpr, thresholds = roc_curve(y_val, y_proba[:, 1])

        # Compute the optimal threshold by maximizing the Youden's J statistic
        J = tpr - fpr
        optimal_idx = np.argmax(J)
        optimal_threshold = thresholds[optimal_idx]

        # Alternatively, you can minimize the distance to the top-left corner (0,1)
        distances = np.sqrt(fpr**2 + (1-tpr)**2)
        optimal_idx = np.argmin(distances)
        optimal_threshold = thresholds[optimal_idx]

        y_pred_optimal_threshold = [1 if prob[1] >= optimal_threshold else 0 for prob in y_proba]

        # Compute Metrics score
        f1score_optimal_threshold = f1_score(y_val, y_pred_optimal_threshold, average='weighted')
        roc_auc_optimal_threshold = roc_auc_score(y_val, y_pred_optimal_threshold, average='weighted')
        accuracy_optimal_threshold = accuracy_score(y_val, y_pred_optimal_threshold)

        self.logs['roc_auc_optimal_threshold'] = roc_auc_optimal_threshold
        self.logs['f1score_optimal_threshold'] = f1score_optimal_threshold
        self.logs['accuracy_optimal_threshold'] = accuracy_optimal_threshold

# %%
tf.random.set_seed(37)
random.seed(37)

X_train, X_val, y_train, y_val = prep_data(df_raw)

log = None

schema_log = [
    row.to_dict()
    for index, row in
    log_raw[
        ['convolution_part', 'convolution_hyperparameter', 'dense_part', 'dense_hyperparameter', 'input_shape', 'layer_metadata']
    ].iterrows()
]

input_shape = X_train.shape[1:]
output_shape = 1

param_grid = {
  'n_conv': [0],
  'n_dense':[1, 2, 3, 4],
  'dense_layer':['dense'],
  'units': [4, 16, 32, 64, 128],
  'activation': ['relu']
}

def save_result(save_state, target_path):
  log.to_csv(target_path, index=False)

def get_schema_combination(part_name, n_layer, layer_values, layer_metadata, param_grid):
  schema_combination = []
  for n in n_layer:
    part_combination=itertools.product(layer_values, repeat=n)

    for part in part_combination:
      hyperparameters = []

      for selected_layer in part:

        # Get selected layers's possible hyperparameters
        hyperparameter_values = {}
        for layer in layer_metadata:
          if(selected_layer == layer['layer']):
            for params in layer['hyperparameter']:
              hyperparameter_values[params['param']] = [params['default']]
              if params['param'] in list(param_grid):
                hyperparameter_values[params['param']] = param_grid[params['param']]

        # get hyperparameter combination to grid search
        hyperparameter_combination = []
        for combination in list(itertools.product(*hyperparameter_values.values())):
          layer_hyperparameter = {}
          for key, val in zip(hyperparameter_values.keys(), combination):
            layer_hyperparameter[key] = val
          hyperparameter_combination.append(layer_hyperparameter)

        hyperparameters.append(hyperparameter_combination)

      for hyperparameter in list(itertools.product(*hyperparameters)):
        schema = {part_name+'_part': list(part), part_name+'_hyperparameter': list(hyperparameter)}
        schema_combination.append(schema)

  return schema_combination

conv_shcema = get_schema_combination(part_name='convolution',
                       n_layer = param_grid.get('n_conv', [1]),
                       layer_values = param_grid.get('conv_layer', ['conv1d']),
                       layer_metadata=layer_metadata,
                       param_grid=param_grid)

dense_schema = get_schema_combination(part_name='dense',
                       n_layer = param_grid.get('n_dense', [1]),
                       layer_values = param_grid.get('dense_layer', ['dense']),
                       layer_metadata=layer_metadata,
                       param_grid=param_grid)

model_schema_combination = []
for schema in itertools.product(conv_shcema, dense_schema):
  model_schema = {}
  for schema_dict in schema:
    model_schema.update(schema_dict)

  model_schema_combination.append(model_schema)

print(len(model_schema_combination))
print(model_schema_combination[0])
print(model_schema_combination[-1])
# Out:
# Train:  (7522, 85, 1)   (7522,)
# Val:  (1671, 85, 1)   (1671,)
# Column Used:  ['Dieta1_DRDINT', 'Dieta1_DR1TFIBE', 'Quest21_SLQ300', 'Quest19_PAD660', 'Quest19_PAQ635', 'Dieta1_DR1TCHOL', 'Quest19_PAQ655', 'Dieta1_DR1TSFAT', 'Dieta1_DR1TKCAL', 'Exami2_BMXBMI', 'Dieta1_DR1TSUGR', 'Quest21_SLQ320', 'Quest21_SLQ330', 'Quest19_PAD615', 'Quest21_SLD012', 'Quest21_SLD013', 'Dieta1_DR1DAY', 'Quest6_DED120', 'Quest19_PAQ610', 'Quest6_DED125', 'Dieta1_DR1TPROT', 'Quest19_PAQ640', 'Dieta1_DR1TPFAT', 'Dieta1_DR1TMFAT', 'Dieta1_DR1TCALC', 'Dieta1_DR1TCARB', 'Dieta1_DR1TTFAT', 'Quest19_PAD645', 'Exami1_BPXPLS', 'Demog1_RIDRETH3', 'Demog1_DMDHHSZA', 'Demog1_DMDHHSZE', 'Quest14_INQ020', 'Quest18_OCQ210', 'Demog1_INDIN2', 'Quest12_HEQ030', 'Quest22_SMQ900', 'Exami2_BMXHT', 'Quest3_CDQ009', 'Quest3_CDQ010', 'Exami2_BMXWT', 'Quest3_CDQ008', 'Quest20_PFQ061H', 'Quest7_DIQ010', 'Quest20_PFQ061B', 'Labor1_LBDTCSI', 'Quest17_DPQ040', 'Demog1_RIAGENDR', 'Labor2_URDTIME1', 'Quest22_SMQ890', 'Demog1_DMDMARTL', 'Exami1_BPXPULS', 'Exami1_DiaPulse', 'Demog1_DMDFMSIZ', 'Quest16_MCQ300C', 'Demog1_RIDAGEYR', 'Demog1_DMDHHSZB', 'Labor1_LBXTC', 'Exami1_SysPulse', 'Quest16_MCQ010', 'Quest16_MCQ366B', 'Quest22_SMQ020', 'Quest14_IND235', 'Quest11_HIQ011', 'Quest20_PFQ020', 'Labor2_URXVOL1', 'Quest4_CBD111', 'Quest15_KIQ026', 'Quest17_DPQ020', 'Quest16_MCQ300A', 'Quest14_INQ012', 'Quest17_DPQ030', 'Quest15_KIQ022', 'Quest2_BPQ020', 'Demog1_DMDHHSIZ', 'Quest12_HEQ010', 'Quest1_ALQ111', 'Quest10_ECQ020', 'Quest16_MCQ220', 'Quest4_CBD121', 'Quest16_MCQ366A', 'Labor2_URDFLOW1', 'Demog1_DMDEDUC', 'Quest9_DLQ050', 'Quest20_PFQ061C']
# 780
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense'], 'dense_hyperparameter': [{'units': 4, 'activation': 'relu'}]}
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 128, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}]}

# %%
import time

random.seed(37)

skipped = 0
# Randomized to get 30 sample
for i, model_schema in enumerate(random.sample(model_schema_combination, min(len(model_schema_combination), 30))):
  start_time = time.time()
  model_schema['input_shape'] = input_shape
  model_schema['layer_metadata'] = layer_metadata

  print(model_schema)

  loss = []
  accuracy = []
  precision = []
  recall = []
  f1score = []
  auc = []
  accuracy_optimal_threshold = []
  f1score_optimal_threshold = []
  auc_optimal_threshold = []
  train_loss = []
  train_accuracy = []
  train_precision = []
  train_recall = []
  train_f1score = []
  train_auc = []
  train_accuracy_optimal_threshold = []
  train_f1score_optimal_threshold = []
  train_auc_optimal_threshold = []

  model = CNNModel(**model_schema)
  model.summary()

  print("Training Model...")
  for X_train, X_val, y_train, y_val in prep_data_cross_validation(df_raw, num_folds=4):

    model = CNNModel(**model_schema)
    metrics_callback = MetricsCallback(validation_data=(X_val, y_val))
    train_metrics_callback = MetricsCallback(validation_data=(X_train, y_train))

    model.fit(X_train, y_train, X_val, y_val, epochs=20, verbose=0, callbacks=[metrics_callback, train_metrics_callback])
    _loss, _accuracy = model.evaluate(X_val, y_val, verbose=0)
    loss.append(_loss)
    accuracy.append(_accuracy)
    f1score.append(metrics_callback.logs.get('f1score'))
    auc.append(metrics_callback.logs.get('roc_auc'))
    accuracy_optimal_threshold.append(metrics_callback.logs.get('accuracy_optimal_threshold'))
    f1score_optimal_threshold.append(metrics_callback.logs.get('f1score_optimal_threshold'))
    auc_optimal_threshold.append(metrics_callback.logs.get('roc_auc_optimal_threshold'))

    _train_loss, _train_accuracy = model.evaluate(X_train, y_train, verbose=0)
    train_loss.append(_train_loss)
    train_accuracy.append(_train_accuracy)
    train_f1score.append(train_metrics_callback.logs.get('f1score'))
    train_auc.append(train_metrics_callback.logs.get('roc_auc'))
    train_accuracy_optimal_threshold.append(train_metrics_callback.logs.get('accuracy_optimal_threshold'))
    train_f1score_optimal_threshold.append(train_metrics_callback.logs.get('f1score_optimal_threshold'))
    train_auc_optimal_threshold.append(train_metrics_callback.logs.get('roc_auc_optimal_threshold'))

  print(f"Loss: %.3f%%" %  (np.mean(loss)*100) )
  print(f"Accuracy: %.3f%%" % (np.mean(accuracy)*100) )
  print(f"F1 Score: %.3f%%" % (np.mean(f1score)*100) )
  print(f"AUC: %.3f%%" % (np.mean(auc)*100) )
  print(f"Accuracy Optimal Threshold: %.3f%%" % (np.mean(accuracy_optimal_threshold)*100) )
  print(f"F1 Score Optimal Threshold: %.3f%%" % (np.mean(f1score_optimal_threshold)*100) )
  print(f"AUC Optimal Threshold: %.3f%%" % (np.mean(auc_optimal_threshold)*100) )

  loss, accuracy, f1score, auc, accuracy_optimal_threshold, f1score_optimal_threshold, auc_optimal_threshold = np.mean(loss), np.mean(accuracy), np.mean(f1score), np.mean(auc), np.mean(accuracy_optimal_threshold), np.mean(f1score_optimal_threshold), np.mean(auc_optimal_threshold)
  train_loss, train_accuracy, train_f1score, train_auc, train_accuracy_optimal_threshold, train_f1score_optimal_threshold, train_auc_optimal_threshold = np.mean(train_loss), np.mean(accuracy), np.mean(train_f1score), np.mean(train_auc), np.mean(train_accuracy_optimal_threshold), np.mean(train_f1score_optimal_threshold), np.mean(train_auc_optimal_threshold)

  end_time = time.time()
  print("Duration (Second):", (end_time - start_time))
  save_state = {}
  save_state.update(model_schema)
  save_state.update({'duration': (end_time - start_time)})
  save_state.update({'loss': loss, 'accuracy': accuracy, 'f1score': f1score, 'auc': auc, 'accuracy_optimal_threshold': accuracy_optimal_threshold, 'f1score_optimal_threshold':f1score_optimal_threshold, 'auc_optimal_threshold':auc_optimal_threshold})
  save_state.update({'train_loss': train_loss, 'train_accuracy': train_accuracy, 'train_f1score': train_f1score, 'train_auc': train_auc, 'train_accuracy_optimal_threshold': train_accuracy_optimal_threshold, 'train_f1score_optimal_threshold':train_f1score_optimal_threshold, 'train_auc_optimal_threshold':train_auc_optimal_threshold})

  log = pd.concat([log, pd.DataFrame({key: [value] for key, value in save_state.items()})])

  save_result(log, drive_path+"/Notebook/Arif's Workspace/Model Comparison/hyperparameter_tuning_log.csv")
# Out:
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 128, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 85)                0
#
#  dense (Dense)               (None, 128)               11008
#
#  dense_1 (Dense)             (None, 16)                2064
#
#  dense_2 (Dense)             (None, 64)                1088
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 18450 (72.07 KB)
# Trainable params: 18450 (72.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 46.032%
# Accuracy: 94.577%
# F1 Score: 94.453%
# AUC: 59.098%
# Accuracy Optimal Threshold: 72.150%
# F1 Score Optimal Threshold: 80.846%
# AUC Optimal Threshold: 77.249%
# Duration (Second): 192.25649905204773
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 64, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 32, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_5 (Flatten)         (None, 85)                0
#
#  dense_25 (Dense)            (None, 64)                5504
#
#  dense_26 (Dense)            (None, 64)                4160
#
#  dense_27 (Dense)            (None, 64)                4160
#
#  dense_28 (Dense)            (None, 32)                2080
#
#  dense_29 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 15970 (62.38 KB)
# Trainable params: 15970 (62.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 50.708%
# Accuracy: 94.020%
# F1 Score: 94.298%
# AUC: 61.994%
# Accuracy Optimal Threshold: 80.643%
# F1 Score Optimal Threshold: 86.549%
# AUC Optimal Threshold: 78.936%
# Duration (Second): 182.06026196479797
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 32, 'activation': 'relu'}, {'units': 32, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_10 (Flatten)        (None, 85)                0
#
#  dense_50 (Dense)            (None, 32)                2752
#
#  dense_51 (Dense)            (None, 32)                1056
#
#  dense_52 (Dense)            (None, 64)                2112
#
#  dense_53 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 6050 (23.63 KB)
# Trainable params: 6050 (23.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 49.011%
# Accuracy: 93.051%
# F1 Score: 93.601%
# AUC: 59.629%
# Accuracy Optimal Threshold: 78.381%
# F1 Score Optimal Threshold: 85.018%
# AUC Optimal Threshold: 75.159%
# Duration (Second): 183.11393928527832
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 64, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}, {'units': 32, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_15 (Flatten)        (None, 85)                0
#
#  dense_70 (Dense)            (None, 64)                5504
#
#  dense_71 (Dense)            (None, 128)               8320
#
#  dense_72 (Dense)            (None, 4)                 516
#
#  dense_73 (Dense)            (None, 32)                160
#
#  dense_74 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 14566 (56.90 KB)
# Trainable params: 14566 (56.90 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 41.936%
# Accuracy: 94.164%
# F1 Score: 94.233%
# AUC: 59.626%
# Accuracy Optimal Threshold: 81.847%
# F1 Score Optimal Threshold: 87.099%
# AUC Optimal Threshold: 74.162%
# Duration (Second): 176.47239804267883
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 128, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_20 (Flatten)        (None, 85)                0
#
#  dense_95 (Dense)            (None, 128)               11008
#
#  dense_96 (Dense)            (None, 16)                2064
#
#  dense_97 (Dense)            (None, 4)                 68
#
#  dense_98 (Dense)            (None, 16)                80
#
#  dense_99 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 13254 (51.77 KB)
# Trainable params: 13254 (51.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 40.493%
# Accuracy: 94.290%
# F1 Score: 94.349%
# AUC: 61.111%
# Accuracy Optimal Threshold: 76.207%
# F1 Score Optimal Threshold: 83.599%
# AUC Optimal Threshold: 77.084%
# Duration (Second): 188.6326985359192
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 128, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_25 (Flatten)        (None, 85)                0
#
#  dense_120 (Dense)           (None, 128)               11008
#
#  dense_121 (Dense)           (None, 128)               16512
#
#  dense_122 (Dense)           (None, 16)                2064
#
#  dense_123 (Dense)           (None, 128)               2176
#
#  dense_124 (Dense)           (None, 2)                 258
#
# =================================================================
# Total params: 32018 (125.07 KB)
# Trainable params: 32018 (125.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 43.901%
# Accuracy: 93.715%
# F1 Score: 94.071%
# AUC: 61.271%
# Accuracy Optimal Threshold: 75.381%
# F1 Score Optimal Threshold: 83.091%
# AUC Optimal Threshold: 77.915%
# Duration (Second): 176.1183159351349
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 64, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_30 (Flatten)        (None, 85)                0
#
#  dense_145 (Dense)           (None, 64)                5504
#
#  dense_146 (Dense)           (None, 128)               8320
#
#  dense_147 (Dense)           (None, 64)                8256
#
#  dense_148 (Dense)           (None, 128)               8320
#
#  dense_149 (Dense)           (None, 2)                 258
#
# =================================================================
# Total params: 30658 (119.76 KB)
# Trainable params: 30658 (119.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 61.064%
# Accuracy: 93.302%
# F1 Score: 93.753%
# AUC: 59.762%
# Accuracy Optimal Threshold: 73.657%
# F1 Score Optimal Threshold: 81.762%
# AUC Optimal Threshold: 76.471%
# Duration (Second): 182.172869682312
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 32, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}, {'units': 32, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_35 (Flatten)        (None, 85)                0
#
#  dense_170 (Dense)           (None, 32)                2752
#
#  dense_171 (Dense)           (None, 128)               4224
#
#  dense_172 (Dense)           (None, 128)               16512
#
#  dense_173 (Dense)           (None, 32)                4128
#
#  dense_174 (Dense)           (None, 2)                 66
#
# =================================================================
# Total params: 27682 (108.13 KB)
# Trainable params: 27682 (108.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 50.926%
# Accuracy: 93.302%
# F1 Score: 93.864%
# AUC: 62.352%
# Accuracy Optimal Threshold: 73.442%
# F1 Score Optimal Threshold: 81.759%
# AUC Optimal Threshold: 75.672%
# Duration (Second): 165.2071270942688
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 4, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_40 (Flatten)        (None, 85)                0
#
#  dense_195 (Dense)           (None, 4)                 344
#
#  dense_196 (Dense)           (None, 16)                80
#
#  dense_197 (Dense)           (None, 16)                272
#
#  dense_198 (Dense)           (None, 2)                 34
#
# =================================================================
# Total params: 730 (2.85 KB)
# Trainable params: 730 (2.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 24.572%
# Accuracy: 92.871%
# F1 Score: 93.593%
# AUC: 61.984%
# Accuracy Optimal Threshold: 79.314%
# F1 Score Optimal Threshold: 85.663%
# AUC Optimal Threshold: 77.535%
# Duration (Second): 173.38696098327637
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 64, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_45 (Flatten)        (None, 85)                0
#
#  dense_215 (Dense)           (None, 64)                5504
#
#  dense_216 (Dense)           (None, 128)               8320
#
#  dense_217 (Dense)           (None, 64)                8256
#
#  dense_218 (Dense)           (None, 16)                1040
#
#  dense_219 (Dense)           (None, 2)                 34
#
# =================================================================
# Total params: 23154 (90.45 KB)
# Trainable params: 23154 (90.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 53.298%
# Accuracy: 94.092%
# F1 Score: 94.262%
# AUC: 60.588%
# Accuracy Optimal Threshold: 73.766%
# F1 Score Optimal Threshold: 81.952%
# AUC Optimal Threshold: 76.845%
# Duration (Second): 177.63013529777527
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 16, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_50 (Flatten)        (None, 85)                0
#
#  dense_240 (Dense)           (None, 16)                1376
#
#  dense_241 (Dense)           (None, 64)                1088
#
#  dense_242 (Dense)           (None, 128)               8320
#
#  dense_243 (Dense)           (None, 64)                8256
#
#  dense_244 (Dense)           (None, 2)                 130
#
# =================================================================
# Total params: 19170 (74.88 KB)
# Trainable params: 19170 (74.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 50.724%
# Accuracy: 93.661%
# F1 Score: 93.997%
# AUC: 60.874%
# Accuracy Optimal Threshold: 73.010%
# F1 Score Optimal Threshold: 81.352%
# AUC Optimal Threshold: 74.810%
# Duration (Second): 177.86200594902039
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 32, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_55"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_55 (Flatten)        (None, 85)                0
#
#  dense_265 (Dense)           (None, 32)                2752
#
#  dense_266 (Dense)           (None, 16)                528
#
#  dense_267 (Dense)           (None, 64)                1088
#
#  dense_268 (Dense)           (None, 64)                4160
#
#  dense_269 (Dense)           (None, 2)                 130
#
# =================================================================
# Total params: 8658 (33.82 KB)
# Trainable params: 8658 (33.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 41.279%
# Accuracy: 93.859%
# F1 Score: 94.117%
# AUC: 59.810%
# Accuracy Optimal Threshold: 75.920%
# F1 Score Optimal Threshold: 83.400%
# AUC Optimal Threshold: 71.911%
# Duration (Second): 178.7060363292694
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 64, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}, {'units': 32, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_60"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_60 (Flatten)        (None, 85)                0
#
#  dense_290 (Dense)           (None, 64)                5504
#
#  dense_291 (Dense)           (None, 4)                 260
#
#  dense_292 (Dense)           (None, 32)                160
#
#  dense_293 (Dense)           (None, 4)                 132
#
#  dense_294 (Dense)           (None, 2)                 10
#
# =================================================================
# Total params: 6066 (23.70 KB)
# Trainable params: 6066 (23.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 34.761%
# Accuracy: 94.218%
# F1 Score: 94.514%
# AUC: 63.956%
# Accuracy Optimal Threshold: 79.315%
# F1 Score Optimal Threshold: 85.304%
# AUC Optimal Threshold: 73.459%
# Duration (Second): 174.84553909301758
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 64, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_65"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_65 (Flatten)        (None, 85)                0
#
#  dense_315 (Dense)           (None, 64)                5504
#
#  dense_316 (Dense)           (None, 16)                1040
#
#  dense_317 (Dense)           (None, 4)                 68
#
#  dense_318 (Dense)           (None, 2)                 10
#
# =================================================================
# Total params: 6622 (25.87 KB)
# Trainable params: 6622 (25.87 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 41.009%
# Accuracy: 94.433%
# F1 Score: 94.354%
# AUC: 58.975%
# Accuracy Optimal Threshold: 75.092%
# F1 Score Optimal Threshold: 82.701%
# AUC Optimal Threshold: 73.790%
# Duration (Second): 162.62027883529663
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 128, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_70"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_70 (Flatten)        (None, 85)                0
#
#  dense_335 (Dense)           (None, 128)               11008
#
#  dense_336 (Dense)           (None, 16)                2064
#
#  dense_337 (Dense)           (None, 64)                1088
#
#  dense_338 (Dense)           (None, 128)               8320
#
#  dense_339 (Dense)           (None, 2)                 258
#
# =================================================================
# Total params: 22738 (88.82 KB)
# Trainable params: 22738 (88.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 52.268%
# Accuracy: 93.356%
# F1 Score: 93.789%
# AUC: 60.248%
# Accuracy Optimal Threshold: 78.488%
# F1 Score Optimal Threshold: 85.111%
# AUC Optimal Threshold: 77.596%
# Duration (Second): 163.67413520812988
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 32, 'activation': 'relu'}, {'units': 32, 'activation': 'relu'}, {'units': 32, 'activation': 'relu'}, {'units': 32, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_75"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_75 (Flatten)        (None, 85)                0
#
#  dense_360 (Dense)           (None, 32)                2752
#
#  dense_361 (Dense)           (None, 32)                1056
#
#  dense_362 (Dense)           (None, 32)                1056
#
#  dense_363 (Dense)           (None, 32)                1056
#
#  dense_364 (Dense)           (None, 2)                 66
#
# =================================================================
# Total params: 5986 (23.38 KB)
# Trainable params: 5986 (23.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 49.176%
# Accuracy: 93.751%
# F1 Score: 94.059%
# AUC: 60.520%
# Accuracy Optimal Threshold: 71.953%
# F1 Score Optimal Threshold: 80.638%
# AUC Optimal Threshold: 74.009%
# Duration (Second): 183.59521174430847
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 64, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 32, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_80"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_80 (Flatten)        (None, 85)                0
#
#  dense_385 (Dense)           (None, 64)                5504
#
#  dense_386 (Dense)           (None, 64)                4160
#
#  dense_387 (Dense)           (None, 32)                2080
#
#  dense_388 (Dense)           (None, 4)                 132
#
#  dense_389 (Dense)           (None, 2)                 10
#
# =================================================================
# Total params: 11886 (46.43 KB)
# Trainable params: 11886 (46.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 49.240%
# Accuracy: 94.254%
# F1 Score: 94.458%
# AUC: 62.883%
# Accuracy Optimal Threshold: 77.913%
# F1 Score Optimal Threshold: 84.624%
# AUC Optimal Threshold: 76.447%
# Duration (Second): 170.15851140022278
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 16, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_85"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_85 (Flatten)        (None, 85)                0
#
#  dense_410 (Dense)           (None, 16)                1376
#
#  dense_411 (Dense)           (None, 4)                 68
#
#  dense_412 (Dense)           (None, 16)                80
#
#  dense_413 (Dense)           (None, 64)                1088
#
#  dense_414 (Dense)           (None, 2)                 130
#
# =================================================================
# Total params: 2742 (10.71 KB)
# Trainable params: 2742 (10.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 24.948%
# Accuracy: 94.128%
# F1 Score: 94.090%
# AUC: 57.477%
# ...
# Model: "sequential_120"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_120 (Flatten)       (None, 85)                0
#
#  dense_575 (Dense)           (None, 32)                2752
#
#  dense_576 (Dense)           (None, 4)                 132
#
#  dense_577 (Dense)           (None, 64)                320
#
#  dense_578 (Dense)           (None, 64)                4160
#
#  dense_579 (Dense)           (None, 2)                 130
#
# =================================================================
# Total params: 7494 (29.27 KB)
# Trainable params: 7494 (29.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 34.845%
# Accuracy: 93.607%
# F1 Score: 93.898%
# AUC: 59.294%
# Accuracy Optimal Threshold: 76.333%
# F1 Score Optimal Threshold: 83.718%
# AUC Optimal Threshold: 76.242%
# Duration (Second): 182.33915734291077
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 16, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_125"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_125 (Flatten)       (None, 85)                0
#
#  dense_600 (Dense)           (None, 16)                1376
#
#  dense_601 (Dense)           (None, 128)               2176
#
#  dense_602 (Dense)           (None, 16)                2064
#
#  dense_603 (Dense)           (None, 2)                 34
#
# =================================================================
# Total params: 5650 (22.07 KB)
# Trainable params: 5650 (22.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 34.684%
# Accuracy: 93.931%
# F1 Score: 94.171%
# AUC: 60.886%
# Accuracy Optimal Threshold: 75.255%
# F1 Score Optimal Threshold: 82.876%
# AUC Optimal Threshold: 74.167%
# Duration (Second): 182.8057816028595
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 64, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_130"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_130 (Flatten)       (None, 85)                0
#
#  dense_620 (Dense)           (None, 64)                5504
#
#  dense_621 (Dense)           (None, 16)                1040
#
#  dense_622 (Dense)           (None, 4)                 68
#
#  dense_623 (Dense)           (None, 16)                80
#
#  dense_624 (Dense)           (None, 2)                 34
#
# =================================================================
# Total params: 6726 (26.27 KB)
# Trainable params: 6726 (26.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 40.466%
# Accuracy: 94.021%
# F1 Score: 94.059%
# AUC: 57.725%
# Accuracy Optimal Threshold: 81.701%
# F1 Score Optimal Threshold: 86.879%
# AUC Optimal Threshold: 69.860%
# Duration (Second): 182.6623408794403
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 16, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_135"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_135 (Flatten)       (None, 85)                0
#
#  dense_645 (Dense)           (None, 16)                1376
#
#  dense_646 (Dense)           (None, 4)                 68
#
#  dense_647 (Dense)           (None, 64)                320
#
#  dense_648 (Dense)           (None, 4)                 260
#
#  dense_649 (Dense)           (None, 2)                 10
#
# =================================================================
# Total params: 2034 (7.95 KB)
# Trainable params: 2034 (7.95 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 29.365%
# Accuracy: 93.967%
# F1 Score: 94.259%
# AUC: 62.177%
# Accuracy Optimal Threshold: 81.450%
# F1 Score Optimal Threshold: 86.814%
# AUC Optimal Threshold: 74.163%
# Duration (Second): 175.81564712524414
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 16, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}, {'units': 32, 'activation': 'relu'}, {'units': 128, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_140"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_140 (Flatten)       (None, 85)                0
#
#  dense_670 (Dense)           (None, 16)                1376
#
#  dense_671 (Dense)           (None, 64)                1088
#
#  dense_672 (Dense)           (None, 32)                2080
#
#  dense_673 (Dense)           (None, 128)               4224
#
#  dense_674 (Dense)           (None, 2)                 258
#
# =================================================================
# Total params: 9026 (35.26 KB)
# Trainable params: 9026 (35.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 45.593%
# Accuracy: 93.356%
# F1 Score: 93.865%
# AUC: 61.780%
# Accuracy Optimal Threshold: 73.010%
# F1 Score Optimal Threshold: 81.374%
# AUC Optimal Threshold: 71.350%
# Duration (Second): 173.2511863708496
# {'convolution_part': [], 'convolution_hyperparameter': [], 'dense_part': ['dense', 'dense', 'dense', 'dense'], 'dense_hyperparameter': [{'units': 128, 'activation': 'relu'}, {'units': 4, 'activation': 'relu'}, {'units': 16, 'activation': 'relu'}, {'units': 64, 'activation': 'relu'}], 'input_shape': (85, 1), 'layer_metadata': [{'layer': 'conv1d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'int'>, 'default': 3}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling1d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'int'>, 'default': 2}]}, {'layer': 'conv2d', 'hyperparameter': [{'param': 'filters', 'type': <class 'int'>, 'default': 16}, {'param': 'kernel_size', 'type': <class 'tuple'>, 'default': (3, 3)}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': [{'param': 'pool_size', 'type': <class 'tuple'>, 'default': (2, 2)}]}, {'layer': 'flatten', 'hyperparameter': []}, {'layer': 'dense', 'hyperparameter': [{'param': 'units', 'type': <class 'int'>, 'default': 8}, {'param': 'activation', 'type': <class 'str'>, 'default': 'linear'}]}]}
# Model: "sequential_145"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_145 (Flatten)       (None, 85)                0
#
#  dense_695 (Dense)           (None, 128)               11008
#
#  dense_696 (Dense)           (None, 4)                 516
#
#  dense_697 (Dense)           (None, 16)                80
#
#  dense_698 (Dense)           (None, 64)                1088
#
#  dense_699 (Dense)           (None, 2)                 130
#
# =================================================================
# Total params: 12822 (50.09 KB)
# Trainable params: 12822 (50.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Training Model...
# Loss: 36.593%
# Accuracy: 94.433%
# F1 Score: 94.352%
# AUC: 58.916%
# Accuracy Optimal Threshold: 74.377%
# F1 Score Optimal Threshold: 82.385%
# AUC Optimal Threshold: 76.403%
# Duration (Second): 177.60725140571594

# %%
hp_log_sorted = pd.read_csv( drive_path+"/Notebook/Arif's Workspace/Model Comparison/hyperparameter_tuning_log.csv")
hp_log_sorted['avg_metrics'] = (hp_log_sorted['accuracy_optimal_threshold'] + hp_log_sorted['f1score_optimal_threshold'] + hp_log_sorted['auc_optimal_threshold']) / 3

hp_log_sorted = hp_log_sorted.sort_values(by=['avg_metrics', 'accuracy_optimal_threshold', 'f1score_optimal_threshold', 'auc_optimal_threshold'], ascending=[False, False, False, False])

hp_log_sorted
# Out:
#    convolution_part convolution_hyperparameter  \
# 1                []                         []
# 23               []                         []
# 3                []                         []
# 8                []                         []
# 27               []                         []
# 14               []                         []
# 22               []                         []
# 17               []                         []
# 16               []                         []
# 21               []                         []
# 2                []                         []
# 26               []                         []
# 12               []                         []
# 18               []                         []
# 4                []                         []
# 5                []                         []
# 24               []                         []
# 19               []                         []
# 29               []                         []
# 9                []                         []
# 25               []                         []
# 6                []                         []
# 13               []                         []
# 11               []                         []
# 7                []                         []
# 0                []                         []
# 10               []                         []
# 20               []                         []
# 15               []                         []
# 28               []                         []
#
#                               dense_part  \
# 1   ['dense', 'dense', 'dense', 'dense']
# 23           ['dense', 'dense', 'dense']
# 3   ['dense', 'dense', 'dense', 'dense']
# 8            ['dense', 'dense', 'dense']
# 27  ['dense', 'dense', 'dense', 'dense']
# 14  ['dense', 'dense', 'dense', 'dense']
# 22           ['dense', 'dense', 'dense']
# 17  ['dense', 'dense', 'dense', 'dense']
# 16  ['dense', 'dense', 'dense', 'dense']
# 21  ['dense', 'dense', 'dense', 'dense']
# 2            ['dense', 'dense', 'dense']
# 26  ['dense', 'dense', 'dense', 'dense']
# 12  ['dense', 'dense', 'dense', 'dense']
# 18  ['dense', 'dense', 'dense', 'dense']
# 4   ['dense', 'dense', 'dense', 'dense']
# 5   ['dense', 'dense', 'dense', 'dense']
# 24  ['dense', 'dense', 'dense', 'dense']
# 19  ['dense', 'dense', 'dense', 'dense']
# 29  ['dense', 'dense', 'dense', 'dense']
# 9   ['dense', 'dense', 'dense', 'dense']
# 25           ['dense', 'dense', 'dense']
# 6   ['dense', 'dense', 'dense', 'dense']
# 13           ['dense', 'dense', 'dense']
# 11  ['dense', 'dense', 'dense', 'dense']
# 7   ['dense', 'dense', 'dense', 'dense']
# 0   ['dense', 'dense', 'dense', 'dense']
# 10  ['dense', 'dense', 'dense', 'dense']
# 20  ['dense', 'dense', 'dense', 'dense']
# 15  ['dense', 'dense', 'dense', 'dense']
# 28  ['dense', 'dense', 'dense', 'dense']
#
#                                  dense_hyperparameter input_shape  \
# 1   [{'units': 64, 'activation': 'relu'}, {'units'...     (85, 1)
# 23  [{'units': 4, 'activation': 'relu'}, {'units':...     (85, 1)
# 3   [{'units': 64, 'activation': 'relu'}, {'units'...     (85, 1)
# 8   [{'units': 4, 'activation': 'relu'}, {'units':...     (85, 1)
# 27  [{'units': 16, 'activation': 'relu'}, {'units'...     (85, 1)
# 14  [{'units': 128, 'activation': 'relu'}, {'units...     (85, 1)
# 22  [{'units': 128, 'activation': 'relu'}, {'units...     (85, 1)
# 17  [{'units': 16, 'activation': 'relu'}, {'units'...     (85, 1)
# 16  [{'units': 64, 'activation': 'relu'}, {'units'...     (85, 1)
# 21  [{'units': 32, 'activation': 'relu'}, {'units'...     (85, 1)
# 2   [{'units': 32, 'activation': 'relu'}, {'units'...     (85, 1)
# 26  [{'units': 64, 'activation': 'relu'}, {'units'...     (85, 1)
# 12  [{'units': 64, 'activation': 'relu'}, {'units'...     (85, 1)
# 18  [{'units': 16, 'activation': 'relu'}, {'units'...     (85, 1)
# 4   [{'units': 128, 'activation': 'relu'}, {'units...     (85, 1)
# 5   [{'units': 128, 'activation': 'relu'}, {'units...     (85, 1)
# 24  [{'units': 32, 'activation': 'relu'}, {'units'...     (85, 1)
# 19  [{'units': 128, 'activation': 'relu'}, {'units...     (85, 1)
# 29  [{'units': 128, 'activation': 'relu'}, {'units...     (85, 1)
# 9   [{'units': 64, 'activation': 'relu'}, {'units'...     (85, 1)
# 25  [{'units': 16, 'activation': 'relu'}, {'units'...     (85, 1)
# 6   [{'units': 64, 'activation': 'relu'}, {'units'...     (85, 1)
# 13  [{'units': 64, 'activation': 'relu'}, {'units'...     (85, 1)
# 11  [{'units': 32, 'activation': 'relu'}, {'units'...     (85, 1)
# 7   [{'units': 32, 'activation': 'relu'}, {'units'...     (85, 1)
# 0   [{'units': 128, 'activation': 'relu'}, {'units...     (85, 1)
# 10  [{'units': 16, 'activation': 'relu'}, {'units'...     (85, 1)
# 20  [{'units': 32, 'activation': 'relu'}, {'units'...     (85, 1)
# 15  [{'units': 32, 'activation': 'relu'}, {'units'...     (85, 1)
# 28  [{'units': 16, 'activation': 'relu'}, {'units'...     (85, 1)
#
#                                        layer_metadata    duration      loss  \
# 1   [{'layer': 'conv1d', 'hyperparameter': [{'para...  182.060262  0.507082
# 23  [{'layer': 'conv1d', 'hyperparameter': [{'para...  163.559588  0.250262
# 3   [{'layer': 'conv1d', 'hyperparameter': [{'para...  176.472398  0.419361
# 8   [{'layer': 'conv1d', 'hyperparameter': [{'para...  173.386961  0.245717
# 27  [{'layer': 'conv1d', 'hyperparameter': [{'para...  175.815647  0.293654
# 14  [{'layer': 'conv1d', 'hyperparameter': [{'para...  163.674135  0.522680
# 22  [{'layer': 'conv1d', 'hyperparameter': [{'para...  179.881797  0.482417
# 17  [{'layer': 'conv1d', 'hyperparameter': [{'para...  169.263867  0.249476
# 16  [{'layer': 'conv1d', 'hyperparameter': [{'para...  170.158511  0.492403
# 21  [{'layer': 'conv1d', 'hyperparameter': [{'para...  184.567027  0.368777
# 2   [{'layer': 'conv1d', 'hyperparameter': [{'para...  183.113939  0.490106
# 26  [{'layer': 'conv1d', 'hyperparameter': [{'para...  182.662341  0.404664
# 12  [{'layer': 'conv1d', 'hyperparameter': [{'para...  174.845539  0.347607
# 18  [{'layer': 'conv1d', 'hyperparameter': [{'para...  184.087599  0.410228
# 4   [{'layer': 'conv1d', 'hyperparameter': [{'para...  188.632699  0.404933
# 5   [{'layer': 'conv1d', 'hyperparameter': [{'para...  176.118316  0.439010
# 24  [{'layer': 'conv1d', 'hyperparameter': [{'para...  182.339157  0.348451
# 19  [{'layer': 'conv1d', 'hyperparameter': [{'para...  170.838419  0.547030
# 29  [{'layer': 'conv1d', 'hyperparameter': [{'para...  177.607251  0.365926
# 9   [{'layer': 'conv1d', 'hyperparameter': [{'para...  177.630135  0.532981
# 25  [{'layer': 'conv1d', 'hyperparameter': [{'para...  182.805782  0.346838
# 6   [{'layer': 'conv1d', 'hyperparameter': [{'para...  182.172870  0.610640
# 13  [{'layer': 'conv1d', 'hyperparameter': [{'para...  162.620279  0.410094
# 11  [{'layer': 'conv1d', 'hyperparameter': [{'para...  178.706036  0.412794
# 7   [{'layer': 'conv1d', 'hyperparameter': [{'para...  165.207127  0.509255
# 0   [{'layer': 'conv1d', 'hyperparameter': [{'para...  192.256499  0.460319
# 10  [{'layer': 'conv1d', 'hyperparameter': [{'para...  177.862006  0.507237
# 20  [{'layer': 'conv1d', 'hyperparameter': [{'para...  161.956082  0.401044
# 15  [{'layer': 'conv1d', 'hyperparameter': [{'para...  183.595212  0.491764
# 28  [{'layer': 'conv1d', 'hyperparameter': [{'para...  173.251186  0.455932
#
#     accuracy   f1score  ...  f1score_optimal_threshold  auc_optimal_threshold  \
# 1   0.940204  0.942976  ...                   0.865490               0.789361
# 23  0.922607  0.931561  ...                   0.863238               0.770089
# 3   0.941641  0.942325  ...                   0.870992               0.741619
# 8   0.928712  0.935931  ...                   0.856628               0.775347
# 27  0.939665  0.942591  ...                   0.868137               0.741633
# 14  0.933560  0.937885  ...                   0.851108               0.775958
# 22  0.946490  0.944591  ...                   0.844323               0.780676
# 17  0.941283  0.940896  ...                   0.845710               0.772042
# 16  0.942539  0.944577  ...                   0.846244               0.764469
# 21  0.939487  0.942011  ...                   0.840802               0.778262
# 2   0.930507  0.936008  ...                   0.850177               0.751593
# 26  0.940205  0.940594  ...                   0.868794               0.698604
# 12  0.942178  0.945137  ...                   0.853035               0.734595
# 18  0.933381  0.938534  ...                   0.847638               0.742898
# 4   0.942898  0.943492  ...                   0.835994               0.770836
# 5   0.937151  0.940715  ...                   0.830909               0.779154
# 24  0.936074  0.938985  ...                   0.837181               0.762422
# 19  0.944514  0.944762  ...                   0.838771               0.756935
# 29  0.944334  0.943522  ...                   0.823854               0.764034
# 9   0.940922  0.942622  ...                   0.819525               0.768445
# 25  0.939306  0.941713  ...                   0.828762               0.741670
# 6   0.933024  0.937531  ...                   0.817620               0.764711
# 13  0.944334  0.943543  ...                   0.827012               0.737899
# 11  0.938587  0.941166  ...                   0.834005               0.719114
# 7   0.933020  0.938644  ...                   0.817589               0.756723
# 0   0.945772  0.944533  ...                   0.808464               0.772485
# 10  0.936614  0.939969  ...                   0.813522               0.748102
# 20  0.934818  0.938453  ...                   0.828863               0.698004
# 15  0.937512  0.940586  ...                   0.806383               0.740087
# 28  0.933561  0.938648  ...                   0.813742               0.713503
#
#     train_loss  train_accuracy  train_f1score  train_auc  \
# 1     0.002373        0.940204       0.999473   0.999473
# 23    0.088941        0.922607       0.975189   0.975190
# 3     0.007524        0.941641       0.998665   0.998665
# 8     0.090189        0.928712       0.973858   0.973859
# 27    0.039424        0.939665       0.990092   0.990092
# 14    0.003819        0.933560       0.998759   0.998759
# 22    0.000052        0.946490       1.000000   1.000000
# 17    0.037509        0.941283       0.989286   0.989286
# 16    0.001039        0.942539       0.999689   0.999689
# 21    0.010563        0.939487       0.996553   0.996553
# 2     0.009446        0.930507       0.996583   0.996583
# 26    0.012389        0.940205       0.997452   0.997452
# 12    0.017219        0.942178       0.996122   0.996122
# 18    0.017382        0.933381       0.994507   0.994507
# 4     0.001123        0.942898       0.999689   0.999689
# 5     0.004635        0.937151       0.998542   0.998542
# 24    0.020146        0.936074       0.994223   0.994223
# 19    0.000702        0.944514       0.999876   0.999876
# 29    0.008189        0.944334       0.996802   0.996802
# 9     0.001157        0.940922       0.999566   0.999566
# 25    0.014202        0.939306       0.995839   0.995839
# 6     0.003963        0.933024       0.998571   0.998571
# 13    0.006335        0.944334       0.997917   0.997917
# 11    0.009865        0.938587       0.997017   0.997017
# 7     0.009396        0.933020       0.997824   0.997824
# 0     0.001069        0.945772       0.999689   0.999689
# 10    0.008824        0.936614       0.997050   0.997050
# 20    0.015358        0.934818       0.995091   0.995091
# 15    0.006538        0.937512       0.998041   0.998041
# 28    0.012793        0.933561       0.995559   0.995559
#
#     train_accuracy_optimal_threshold  train_f1score_optimal_threshold  \
# 1                           0.999659                         0.999659
# 23                          0.976712                         0.976711
# 3                           0.998696                         0.998696
# 8                           0.974542                         0.974542
# 27                          0.990620                         0.990620
# 14                          0.999379                         0.999379
# 22                          1.000000                         1.000000
# 17                          0.990652                         0.990652
# 16                          0.999782                         0.999782
# 21                          0.997018                         0.997018
# 2                           0.998261                         0.998261
# 26                          0.997918                         0.997918
# 12                          0.996402                         0.996402
# 18                          0.994971                         0.994971
# 4                           0.999782                         0.999782
# 5                           0.999131                         0.999131
# 24                          0.994347                         0.994347
# 19                          0.999938                         0.999938
# 29                          0.998135                         0.998135
# 9                           0.999721                         0.999721
# 25                          0.996491                         0.996491
# 6                           0.999316                         0.999316
# 13                          0.998787                         0.998787
# 11                          0.997733                         0.997733
# 7                           0.998384                         0.998384
# 0                           0.999876                         0.999876
# 10                          0.997765                         0.997765
# 20                          0.995557                         0.995557
# 15                          0.998103                         0.998103
# 28                          0.996211                         0.996211
#
#     train_auc_optimal_threshold  avg_metrics
# 1                      0.999659     0.820426
# 23                     0.976712     0.812354
# 3                      0.998696     0.810360
# 8                      0.974542     0.808370
# 27                     0.990620     0.808088
# 14                     0.999379     0.803982
# 22                     1.000000     0.800419
# 17                     0.990652     0.798005
# 16                     0.999782     0.796614
# 21                     0.997018     0.796166
# 2                      0.998261     0.795192
# 26                     0.997918     0.794802
# 12                     0.996402     0.793593
# 18                     0.994971     0.790189
# 4                      0.999782     0.789632
# 5                      0.999131     0.787959
# 24                     0.994347     0.787643
# 19                     0.999938     0.787242
# 29                     0.998135     0.777218
# 9                      0.999721     0.775210
# 25                     0.996491     0.774328
# 6                      0.999316     0.772967
# 13                     0.998787     0.771945
# 11                     0.997733     0.770773
# 7                      0.998384     0.769577
# 0                      0.999876     0.767483
# 10                     0.997765     0.763909
# 20                     0.995557     0.759448
# 15                     0.998103     0.755332
# 28                     0.996211     0.752448
#
# [30 rows x 22 columns]

# %%
# Top 3 Model

for i in range(3):
  print("Best Model #", i+1)
  print("-"*10)
  pprint.pprint(hp_log_sorted.iloc[-i-1].to_dict())
  print("-"*10)
# Out:
# Best Model # 1
# ----------
# {'accuracy': 0.9335605800151824,
#  'accuracy_optimal_threshold': 0.7300984344959609,
#  'auc': 0.617797987994414,
#  'auc_optimal_threshold': 0.7135034447725397,
#  'avg_metrics': 0.7524480189945075,
#  'convolution_hyperparameter': '[]',
#  'convolution_part': '[]',
#  'dense_hyperparameter': "[{'units': 16, 'activation': 'relu'}, {'units': 64, "
#                          "'activation': 'relu'}, {'units': 32, 'activation': "
#                          "'relu'}, {'units': 128, 'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense', 'dense', 'dense']",
#  'duration': 173.2511863708496,
#  'f1score': 0.9386478497205052,
#  'f1score_optimal_threshold': 0.8137421777150223,
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'conv2d', "
#                    "'hyperparameter': [{'param': 'filters', 'type': <class "
#                    "'int'>, 'default': 16}, {'param': 'kernel_size', 'type': "
#                    "<class 'tuple'>, 'default': (3, 3)}, {'param': "
#                    "'activation', 'type': <class 'str'>, 'default': "
#                    "'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': "
#                    "[{'param': 'pool_size', 'type': <class 'tuple'>, "
#                    "'default': (2, 2)}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.4559324756264686,
#  'train_accuracy': 0.9335605800151824,
#  'train_accuracy_optimal_threshold': 0.9962113968471248,
#  'train_auc': 0.9955593125506276,
#  'train_auc_optimal_threshold': 0.9962113968471248,
#  'train_f1score': 0.9955593018797088,
#  'train_f1score_optimal_threshold': 0.9962113909047726,
#  'train_loss': 0.0127932613249868}
# ----------
# Best Model # 2
# ----------
# {'accuracy': 0.937511995434761,
#  'accuracy_optimal_threshold': 0.7195258930118573,
#  'auc': 0.6052018675838042,
#  'auc_optimal_threshold': 0.7400873848659857,
#  'avg_metrics': 0.7553321686764892,
#  'convolution_hyperparameter': '[]',
#  'convolution_part': '[]',
#  'dense_hyperparameter': "[{'units': 32, 'activation': 'relu'}, {'units': 32, "
#                          "'activation': 'relu'}, {'units': 32, 'activation': "
#                          "'relu'}, {'units': 32, 'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense', 'dense', 'dense']",
#  'duration': 183.59521174430847,
#  'f1score': 0.940586192011894,
#  'f1score_optimal_threshold': 0.8063832281516248,
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'conv2d', "
#                    "'hyperparameter': [{'param': 'filters', 'type': <class "
#                    "'int'>, 'default': 16}, {'param': 'kernel_size', 'type': "
#                    "<class 'tuple'>, 'default': (3, 3)}, {'param': "
#                    "'activation', 'type': <class 'str'>, 'default': "
#                    "'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': "
#                    "[{'param': 'pool_size', 'type': <class 'tuple'>, "
#                    "'default': (2, 2)}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.4917640686035156,
#  'train_accuracy': 0.937511995434761,
#  'train_accuracy_optimal_threshold': 0.9981027378274344,
#  'train_auc': 0.9980405641772488,
#  'train_auc_optimal_threshold': 0.9981027378274342,
#  'train_f1score': 0.9980405636328832,
#  'train_f1score_optimal_threshold': 0.998102737579046,
#  'train_loss': 0.0065383898108848}
# ----------
# Best Model # 3
# ----------
# {'accuracy': 0.9348180294036864,
#  'accuracy_optimal_threshold': 0.7514776520121131,
#  'auc': 0.5907324677109282,
#  'auc_optimal_threshold': 0.6980041823752039,
#  'avg_metrics': 0.7594483035371518,
#  'convolution_hyperparameter': '[]',
#  'convolution_part': '[]',
#  'dense_hyperparameter': "[{'units': 32, 'activation': 'relu'}, {'units': 16, "
#                          "'activation': 'relu'}, {'units': 4, 'activation': "
#                          "'relu'}, {'units': 64, 'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense', 'dense', 'dense']",
#  'duration': 161.95608186721802,
#  'f1score': 0.9384526377878544,
#  'f1score_optimal_threshold': 0.8288630762241381,
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'conv2d', "
#                    "'hyperparameter': [{'param': 'filters', 'type': <class "
#                    "'int'>, 'default': 16}, {'param': 'kernel_size', 'type': "
#                    "<class 'tuple'>, 'default': (3, 3)}, {'param': "
#                    "'activation', 'type': <class 'str'>, 'default': "
#                    "'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': "
#                    "[{'param': 'pool_size', 'type': <class 'tuple'>, "
#                    "'default': (2, 2)}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.4010438807308674,
#  'train_accuracy': 0.9348180294036864,
#  'train_accuracy_optimal_threshold': 0.99555671989129,
#  'train_auc': 0.99509063985203,
#  'train_auc_optimal_threshold': 0.99555671989129,
#  'train_f1score': 0.9950905029293496,
#  'train_f1score_optimal_threshold': 0.9955567037477276,
#  'train_loss': 0.0153580647893249}
# ----------

# %%
# Bottom 3 Model

for i in range(3):
  print("Worst Model #", i+1)
  print("-"*10)
  pprint.pprint(hp_log_sorted.iloc[i].to_dict())
  print("-"*10)
# Out:
# Worst Model # 1
# ----------
# {'accuracy': 0.9402037560939788,
#  'accuracy_optimal_threshold': 0.80642642605474,
#  'auc': 0.6199351362289272,
#  'auc_optimal_threshold': 0.7893607189914458,
#  'avg_metrics': 0.8204256644844793,
#  'convolution_hyperparameter': '[]',
#  'convolution_part': '[]',
#  'dense_hyperparameter': "[{'units': 64, 'activation': 'relu'}, {'units': 64, "
#                          "'activation': 'relu'}, {'units': 64, 'activation': "
#                          "'relu'}, {'units': 32, 'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense', 'dense', 'dense']",
#  'duration': 182.060261964798,
#  'f1score': 0.9429761657984452,
#  'f1score_optimal_threshold': 0.8654898484072522,
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'conv2d', "
#                    "'hyperparameter': [{'param': 'filters', 'type': <class "
#                    "'int'>, 'default': 16}, {'param': 'kernel_size', 'type': "
#                    "<class 'tuple'>, 'default': (3, 3)}, {'param': "
#                    "'activation', 'type': <class 'str'>, 'default': "
#                    "'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': "
#                    "[{'param': 'pool_size', 'type': <class 'tuple'>, "
#                    "'default': (2, 2)}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.5070816874504089,
#  'train_accuracy': 0.9402037560939788,
#  'train_accuracy_optimal_threshold': 0.999658823154894,
#  'train_auc': 0.999472948977414,
#  'train_auc_optimal_threshold': 0.999658823154894,
#  'train_f1score': 0.9994729487189504,
#  'train_f1score_optimal_threshold': 0.9996588231240828,
#  'train_loss': 0.0023725228511466}
# ----------
# Worst Model # 2
# ----------
# {'accuracy': 0.9226071834564208,
#  'accuracy_optimal_threshold': 0.803734394468236,
#  'auc': 0.601118929531826,
#  'auc_optimal_threshold': 0.7700892397154693,
#  'avg_metrics': 0.8123537470517744,
#  'convolution_hyperparameter': '[]',
#  'convolution_part': '[]',
#  'dense_hyperparameter': "[{'units': 4, 'activation': 'relu'}, {'units': 128, "
#                          "'activation': 'relu'}, {'units': 4, 'activation': "
#                          "'relu'}]",
#  'dense_part': "['dense', 'dense', 'dense']",
#  'duration': 163.55958819389343,
#  'f1score': 0.9315610061351666,
#  'f1score_optimal_threshold': 0.8632376069716178,
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'conv2d', "
#                    "'hyperparameter': [{'param': 'filters', 'type': <class "
#                    "'int'>, 'default': 16}, {'param': 'kernel_size', 'type': "
#                    "<class 'tuple'>, 'default': (3, 3)}, {'param': "
#                    "'activation', 'type': <class 'str'>, 'default': "
#                    "'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': "
#                    "[{'param': 'pool_size', 'type': <class 'tuple'>, "
#                    "'default': (2, 2)}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.2502616159617901,
#  'train_accuracy': 0.9226071834564208,
#  'train_accuracy_optimal_threshold': 0.9767115561768324,
#  'train_auc': 0.9751898728122684,
#  'train_auc_optimal_threshold': 0.9767115561768324,
#  'train_f1score': 0.9751887710280892,
#  'train_f1score_optimal_threshold': 0.9767114107950884,
#  'train_loss': 0.0889414642006158}
# ----------
# Worst Model # 3
# ----------
# {'accuracy': 0.9416411817073822,
#  'accuracy_optimal_threshold': 0.8184683681131437,
#  'auc': 0.5962565621613743,
#  'auc_optimal_threshold': 0.7416187053660641,
#  'avg_metrics': 0.8103595473099651,
#  'convolution_hyperparameter': '[]',
#  'convolution_part': '[]',
#  'dense_hyperparameter': "[{'units': 64, 'activation': 'relu'}, {'units': 128, "
#                          "'activation': 'relu'}, {'units': 4, 'activation': "
#                          "'relu'}, {'units': 32, 'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense', 'dense', 'dense']",
#  'duration': 176.47239804267883,
#  'f1score': 0.9423254412298137,
#  'f1score_optimal_threshold': 0.8709915684506876,
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'conv2d', "
#                    "'hyperparameter': [{'param': 'filters', 'type': <class "
#                    "'int'>, 'default': 16}, {'param': 'kernel_size', 'type': "
#                    "<class 'tuple'>, 'default': (3, 3)}, {'param': "
#                    "'activation', 'type': <class 'str'>, 'default': "
#                    "'linear'}]}, {'layer': 'maxpooling2d', 'hyperparameter': "
#                    "[{'param': 'pool_size', 'type': <class 'tuple'>, "
#                    "'default': (2, 2)}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.419361412525177,
#  'train_accuracy': 0.9416411817073822,
#  'train_accuracy_optimal_threshold': 0.9986958899156138,
#  'train_auc': 0.9986649493215544,
#  'train_auc_optimal_threshold': 0.9986958899156138,
#  'train_f1score': 0.9986649269573966,
#  'train_f1score_optimal_threshold': 0.9986958675500344,
#  'train_loss': 0.0075238730496494}
# ----------
