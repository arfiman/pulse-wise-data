# %% [markdown]
# # Prepare Environment

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import json

import warnings
warnings.filterwarnings('ignore')

drive_path = '/content/drive/MyDrive/Kuliah/Tugas Akhir/Final Project Shared Folder'
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Ingest Data

# %%
data_path = "Dataset/Data Versioning/Combined_All_V6.csv"

df_raw = pd.read_csv(os.path.join(drive_path, data_path), index_col = 0)
df_raw = df_raw.set_index('SEQN')
df_raw.head()
# Out:
#          Demog1_RIAGENDR  Demog1_RIDAGEYR  Demog1_RIDRETH3  Demog1_DMDMARTL  \
# SEQN
# 93703.0              2.0              2.0              6.0              5.0
# 93704.0              1.0              2.0              3.0              5.0
# 93705.0              2.0             66.0              4.0              3.0
# 93706.0              1.0             18.0              6.0              5.0
# 93707.0              1.0             13.0              7.0              5.0
#
#          Demog1_DMDHHSIZ  Demog1_DMDFMSIZ  Demog1_DMDHHSZA  Demog1_DMDHHSZB  \
# SEQN
# 93703.0              5.0              5.0     3.000000e+00     5.397605e-79
# 93704.0              4.0              4.0     2.000000e+00     5.397605e-79
# 93705.0              1.0              1.0     5.397605e-79     5.397605e-79
# 93706.0              5.0              5.0     5.397605e-79     5.397605e-79
# 93707.0              7.0              7.0     5.397605e-79     3.000000e+00
#
#          Demog1_DMDHHSZE  Demog1_DMDEDUC  ...  Dieta1_DR1TPROT  \
# SEQN                                      ...
# 93703.0     5.397605e-79             1.0  ...        46.795385
# 93704.0     5.397605e-79             1.0  ...        51.580000
# 93705.0     1.000000e+00             2.0  ...        20.010000
# 93706.0     1.000000e+00             4.0  ...        94.190000
# 93707.0     5.397605e-79             1.0  ...        59.480000
#
#          Dieta1_DR1TCARB  Dieta1_DR1TSUGR  Dieta1_DR1TFIBE  Dieta1_DR1TTFAT  \
# SEQN
# 93703.0       183.161302        93.418166        11.005325        49.559349
# 93704.0       160.460000        76.970000         5.900000        43.240000
# 93705.0       157.450000        91.550000         8.400000        56.980000
# 93706.0        89.820000        14.730000         7.100000       137.390000
# 93707.0       188.150000        84.220000        10.900000        89.180000
#
#          Dieta1_DR1TSFAT  Dieta1_DR1TMFAT  Dieta1_DR1TPFAT  Dieta1_DR1TCHOL  \
# SEQN
# 93703.0        17.118651        16.306485         10.77397       162.313609
# 93704.0        11.372000        14.333000         12.50600       144.000000
# 93705.0        16.435000        16.432000         19.78600        14.000000
# 93706.0        35.169000        45.805000         49.87300       462.000000
# 93707.0        33.252000        33.712000         12.42400       585.000000
#
#          Dieta1_DR1TCALC
# SEQN
# 93703.0        893.39645
# 93704.0        700.00000
# 93705.0        314.00000
# 93706.0        869.00000
# 93707.0        535.00000
#
# [5 rows x 91 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9254 entries, 93703.0 to 102956.0
# Data columns (total 91 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   
#  67  Quest20_PFQ061C  9254 non-null   float64
#  68  Quest20_PFQ061H  9254 non-null   float64
#  69  Quest21_SLQ300   9254 non-null   float64
#  70  Quest21_SLD012   9254 non-null   float64
#  71  Quest21_SLQ320   9254 non-null   float64
#  72  Quest21_SLQ330   9254 non-null   float64
#  73  Quest21_SLD013   9254 non-null   float64
#  74  Quest22_SMQ020   9254 non-null   float64
#  75  Quest22_SMQ890   9254 non-null   float64
#  76  Quest22_SMQ900   9254 non-null   float64
#  77  Quest3_CDQ009    9254 non-null   float64
#  78  Dieta1_DRDINT    9254 non-null   float64
#  79  Dieta1_DR1DAY    9254 non-null   float64
#  80  Dieta1_DR1TKCAL  9254 non-null   float64
#  81  Dieta1_DR1TPROT  9254 non-null   float64
#  82  Dieta1_DR1TCARB  9254 non-null   float64
#  83  Dieta1_DR1TSUGR  9254 non-null   float64
#  84  Dieta1_DR1TFIBE  9254 non-null   float64
#  85  Dieta1_DR1TTFAT  9254 non-null   float64
#  86  Dieta1_DR1TSFAT  9254 non-null   float64
#  87  Dieta1_DR1TMFAT  9254 non-null   float64
#  88  Dieta1_DR1TPFAT  9254 non-null   float64
#  89  Dieta1_DR1TCHOL  9254 non-null   float64
#  90  Dieta1_DR1TCALC  9254 non-null   float64
# dtypes: float64(91)
# memory usage: 6.5 MB

# %% [markdown]
# # Clean Data

# %%
df = df_raw.copy()

# ----------------------------------------------------
# Fill in cvd status for person with less then 20 years old
# ----------------------------------------------------

# conditions = (df['Quest16_MCQ160B'].isna()) | (df['Quest16_MCQ160C'].isna()) | (df['Quest16_MCQ160D'].isna()) | (df['Quest16_MCQ160E'].isna()) | (df['Quest16_MCQ160F'].isna())
# df.loc[conditions, ['Quest16_MCQ160B', 'Quest16_MCQ160C', 'Quest16_MCQ160D', 'Quest16_MCQ160D', 'Quest16_MCQ160E', 'Quest16_MCQ160F']] = 1.0

# df['Quest16_MCQ160B'] = df['Quest16_MCQ160B'].fillna(1.0)

# ----------------------------------------------------
# Fill in Asthma and others
# ----------------------------------------------------

df[['Quest16_MCQ010', 'Quest16_MCQ220', 'Quest16_MCQ300C', 'Quest16_MCQ300A', 'Quest16_MCQ366A', 'Quest16_MCQ366B']] = df.loc[:, ['Quest16_MCQ010', 'Quest16_MCQ220', 'Quest16_MCQ300C', 'Quest16_MCQ300A', 'Quest16_MCQ366A', 'Quest16_MCQ366B']].fillna(value=9)

# ----------------------------------------------------
# Drop Unnecessary Column
# ----------------------------------------------------

df.drop(['Quest16_MCQ092'], axis=1, inplace=True)

# ----------------------------------------------------
# Label of heart failure disease (dropped other than heart failure)
# ----------------------------------------------------

df.drop(['Quest16_MCQ160C', 'Quest16_MCQ160D', 'Quest16_MCQ160E', 'Quest16_MCQ160F'], axis=1, inplace=True)

df = df.dropna()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5569 entries, 93705.0 to 102956.0
# Data columns (total 86 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   
#  66  Quest21_SLQ320   5569 non-null   float64
#  67  Quest21_SLQ330   5569 non-null   float64
#  68  Quest21_SLD013   5569 non-null   float64
#  69  Quest22_SMQ020   5569 non-null   float64
#  70  Quest22_SMQ890   5569 non-null   float64
#  71  Quest22_SMQ900   5569 non-null   float64
#  72  Quest3_CDQ009    5569 non-null   float64
#  73  Dieta1_DRDINT    5569 non-null   float64
#  74  Dieta1_DR1DAY    5569 non-null   float64
#  75  Dieta1_DR1TKCAL  5569 non-null   float64
#  76  Dieta1_DR1TPROT  5569 non-null   float64
#  77  Dieta1_DR1TCARB  5569 non-null   float64
#  78  Dieta1_DR1TSUGR  5569 non-null   float64
#  79  Dieta1_DR1TFIBE  5569 non-null   float64
#  80  Dieta1_DR1TTFAT  5569 non-null   float64
#  81  Dieta1_DR1TSFAT  5569 non-null   float64
#  82  Dieta1_DR1TMFAT  5569 non-null   float64
#  83  Dieta1_DR1TPFAT  5569 non-null   float64
#  84  Dieta1_DR1TCHOL  5569 non-null   float64
#  85  Dieta1_DR1TCALC  5569 non-null   float64
# dtypes: float64(86)
# memory usage: 3.7 MB

# %% [markdown]
# # Rearrange Column

# %%
var_mapping_path = 'Dataset/Variable Mapping V2.xlsx'

var_mapping = pd.read_excel(os.path.join(drive_path, var_mapping_path))
var_mapping['group'] = var_mapping['group'].replace({'Dieta2': 'Dieta1'})
var_mapping['model_var_name'] = var_mapping['group'] + "_" + var_mapping['variable']

var_mapping
# Out:
#       model_var_name           name                                     title  \
# 0    Demog1_RIAGENDR   Demographics  Demographic Variables and Sample Weights
# 1    Demog1_RIDAGEYR   Demographics  Demographic Variables and Sample Weights
# 2    Demog1_RIDRETH3   Demographics  Demographic Variables and Sample Weights
# 3    Demog1_DMDEDUC3   Demographics  Demographic Variables and Sample Weights
# 4    Demog1_DMDEDUC2   Demographics  Demographic Variables and Sample Weights
# ..               ...            ...                                       ...
# 148   Demog1_DMDEDUC    Demographic  Demographic Variables and Sample Weights
# 149    Demog1_INDIN2    Demographic  Demographic Variables and Sample Weights
# 150  Exami1_SysPulse    Examination                            Blood Pressure
# 151  Exami1_DiaPulse    Examination                            Blood Pressure
# 152    Quest3_CDQ009  Questionnaire                     Cardiovascular Health
#
#      variable                                               desc  is_used  \
# 0    RIAGENDR                                             Gender     True
# 1    RIDAGEYR                          Age In Years At Screening     True
# 2    RIDRETH3                   Race/Hispanic Origin W/ Nh Asian     True
# 3    DMDEDUC3              Education Level - Children/Youth 6-19     True
# 4    DMDEDUC2                       Education Level - Adults 20+     True
# ..        ...                                                ...      ...
# 148   DMDEDUC                            Education Level all age     True
# 149    INDIN2  Average income from household income & family ...     True
# 150  SysPulse                            Systolic Pulse Combined     True
# 151  DiaPulse                           Diastolic Pulse Combined     True
# 152    CDQ009                            Pain In Body (Combined)     True
#
#      lifestyle   group
# 0        False  Demog1
# 1        False  Demog1
# 2        False  Demog1
# 3        False  Demog1
# 4        False  Demog1
# ..         ...     ...
# 148      False  Demog1
# 149      False  Demog1
# 150      False  Exami1
# 151      False  Exami1
# 152      False  Quest3
#
# [153 rows x 8 columns]

# %%
model_var = pd.DataFrame({'model_var_name': df.columns.tolist()})

model_var = pd.merge(model_var, var_mapping, left_on=model_var['model_var_name'].str.lower(), right_on=var_mapping['model_var_name'].str.lower(), how='outer', indicator=True).query('_merge!="right_only"')

# To Check if all variable is tagged
# model_var[model_var['_merge'] == "left_only"]

model_var = model_var[['model_var_name_x', 'lifestyle']].rename(columns={'model_var_name_x': 'model_var_name'}).drop_duplicates().reset_index(drop=True)

model_var
# Out:
#      model_var_name  lifestyle
# 0   Demog1_RIAGENDR      False
# 1   Demog1_RIDAGEYR      False
# 2   Demog1_RIDRETH3      False
# 3   Demog1_DMDMARTL      False
# 4   Demog1_DMDHHSIZ      False
# ..              ...        ...
# 81  Dieta1_DR1TSFAT       True
# 82  Dieta1_DR1TMFAT       True
# 83  Dieta1_DR1TPFAT       True
# 84  Dieta1_DR1TCHOL       True
# 85  Dieta1_DR1TCALC       True
#
# [86 rows x 2 columns]

# %%
label_cols = list([col for col in model_var['model_var_name'] if "Quest16_MCQ160B" in col])

lifestyle_cols = model_var.loc[model_var['lifestyle'] == True, 'model_var_name'].tolist()
charac_cols = model_var.loc[model_var['lifestyle'] == False, 'model_var_name'].tolist()

lifestyle_cols = list(set(lifestyle_cols) - set(label_cols))
charac_cols = list(set(charac_cols) - set(label_cols))

print("Overall Cols:", len(model_var['model_var_name']))
print("Lifestyle Cols:", len(lifestyle_cols))
print(lifestyle_cols)
print("Characteristics Cols:", len(charac_cols))
print(charac_cols)
print("Label Cols:", len(label_cols))
print(label_cols)
# Out:
# Overall Cols: 86
# Lifestyle Cols: 28
# ['Dieta1_DRDINT', 'Dieta1_DR1TFIBE', 'Quest21_SLQ300', 'Quest19_PAD660', 'Quest19_PAQ635', 'Dieta1_DR1TCHOL', 'Quest19_PAQ655', 'Dieta1_DR1TSFAT', 'Dieta1_DR1TKCAL', 'Exami2_BMXBMI', 'Dieta1_DR1TSUGR', 'Quest21_SLQ320', 'Quest21_SLQ330', 'Quest19_PAD615', 'Quest21_SLD012', 'Quest21_SLD013', 'Dieta1_DR1DAY', 'Quest6_DED120', 'Quest19_PAQ610', 'Quest6_DED125', 'Dieta1_DR1TPROT', 'Quest19_PAQ640', 'Dieta1_DR1TPFAT', 'Dieta1_DR1TMFAT', 'Dieta1_DR1TCALC', 'Dieta1_DR1TCARB', 'Dieta1_DR1TTFAT', 'Quest19_PAD645']
# Characteristics Cols: 57
# ['Exami1_BPXPLS', 'Demog1_RIDRETH3', 'Demog1_DMDHHSZA', 'Demog1_DMDHHSZE', 'Quest14_INQ020', 'Quest18_OCQ210', 'Demog1_INDIN2', 'Quest12_HEQ030', 'Quest22_SMQ900', 'Exami2_BMXHT', 'Quest3_CDQ009', 'Quest3_CDQ010', 'Exami2_BMXWT', 'Quest3_CDQ008', 'Quest20_PFQ061H', 'Quest7_DIQ010', 'Quest20_PFQ061B', 'Labor1_LBDTCSI', 'Quest17_DPQ040', 'Demog1_RIAGENDR', 'Labor2_URDTIME1', 'Quest22_SMQ890', 'Demog1_DMDMARTL', 'Exami1_BPXPULS', 'Exami1_DiaPulse', 'Demog1_DMDFMSIZ', 'Quest16_MCQ300C', 'Demog1_RIDAGEYR', 'Demog1_DMDHHSZB', 'Labor1_LBXTC', 'Exami1_SysPulse', 'Quest16_MCQ010', 'Quest16_MCQ366B', 'Quest22_SMQ020', 'Quest14_IND235', 'Quest11_HIQ011', 'Quest20_PFQ020', 'Labor2_URXVOL1', 'Quest4_CBD111', 'Quest15_KIQ026', 'Quest17_DPQ020', 'Quest16_MCQ300A', 'Quest14_INQ012', 'Quest17_DPQ030', 'Quest15_KIQ022', 'Quest2_BPQ020', 'Demog1_DMDHHSIZ', 'Quest12_HEQ010', 'Quest1_ALQ111', 'Quest10_ECQ020', 'Quest16_MCQ220', 'Quest4_CBD121', 'Quest16_MCQ366A', 'Labor2_URDFLOW1', 'Demog1_DMDEDUC', 'Quest9_DLQ050', 'Quest20_PFQ061C']
# Label Cols: 1
# ['Quest16_MCQ160B']

# %%
rearranged_df = df.copy()

rearranged_df = rearranged_df[lifestyle_cols + charac_cols + label_cols]

rearranged_df
# Out:
#           Dieta1_DRDINT  Dieta1_DR1TFIBE  Quest21_SLQ300  Quest19_PAD660  \
# SEQN
# 93705.0         2.00000         8.400000          1380.0       71.704698
# 93708.0         2.00000        16.600000          1350.0       71.704698
# 93709.0         1.86000        17.436000          1350.0       67.828947
# 93711.0         2.00000        44.500000          1320.0       60.000000
# 93713.0         2.00000        14.600000          1350.0       68.558824
# ...                 ...              ...             ...             ...
# 102950.0        1.84375        17.047917           180.0       72.043478
# 102952.0        2.00000        28.700000          1350.0       65.134021
# 102953.0        1.00000        57.000000          1320.0       61.261719
# 102954.0        2.00000         9.500000          1320.0       62.415385
# 102956.0        2.00000         9.900000          1380.0       68.338235
#
#           Quest19_PAQ635  Dieta1_DR1TCHOL  Quest19_PAQ655  Dieta1_DR1TSFAT  \
# SEQN
# 93705.0              2.0         14.00000        3.353333        16.435000
# 93708.0              2.0         71.00000        3.353333        17.446000
# 93709.0              2.0        346.32000        3.210526        27.547400
# 93711.0              1.0        546.00000        4.000000        41.268000
# 93713.0              1.0        176.00000        3.357664        36.172000
# ...                  ...              ...             ...              ...
# 102950.0             2.0        269.90625        3.271605        25.209792
# 102952.0             2.0         56.00000        3.371134         7.652000
# 102953.0             2.0        306.00000        3.394531        25.831000
# 102954.0             2.0        361.00000        3.330769        20.526000
# 102956.0             2.0        307.00000        3.448529        15.625000
#
#           Dieta1_DR1TKCAL  Exami2_BMXBMI  ...  Quest1_ALQ111  Quest10_ECQ020  \
# SEQN                                      ...
# 93705.0        1202.00000      31.700000  ...            1.0             9.0
# 93708.0        1251.00000      23.700000  ...            2.0             9.0
# 93709.0        2001.84000      38.900000  ...            9.0             9.0
# 93711.0        2840.00000      21.300000  ...            1.0             9.0
# 93713.0        2040.00000      23.500000  ...            1.0             9.0
# ...                   ...            ...  ...            ...             ...
# 102950.0       2016.65625      28.919231  ...            9.0             9.0
# 102952.0       1080.00000      20.000000  ...            1.0             9.0
# 102953.0       3072.00000      35.800000  ...            1.0             9.0
# 102954.0       1757.00000      26.100000  ...            2.0             9.0
# 102956.0       1591.00000      36.100000  ...            1.0             9.0
#
#           Quest16_MCQ220  Quest4_CBD121  Quest16_MCQ366A  Labor2_URDFLOW1  \
# SEQN
# 93705.0              2.0   7.500000e+01              2.0          1.20400
# 93708.0              2.0   5.397605e-79              2.0          0.50000
# 93709.0              2.0   4.000000e+01              2.0          0.10700
# 93711.0              2.0   8.570000e+02              2.0          0.60500
# 93713.0              2.0   4.000000e+01              2.0          0.70600
# ...                  ...            ...              ...              ...
# 102950.0             2.0   2.140000e+02              1.0          0.98811
# 102952.0             2.0   1.200000e+02              2.0          0.52500
# 102953.0             2.0   2.000000e+02              1.0          0.52900
# 102954.0             2.0   2.000000e+02              1.0          1.03900
# 102956.0             2.0   2.000000e+02              2.0          0.22800
#
#           Demog1_DMDEDUC  Quest9_DLQ050  Quest20_PFQ061C  Quest16_MCQ160B
# SEQN
# 93705.0              2.0            2.0              1.0              2.0
# 93708.0              1.0            2.0              2.0              2.0
# 93709.0              4.0            1.0              9.0              2.0
# 93711.0              5.0            2.0              9.0              2.0
# 93713.0              3.0            2.0              1.0              2.0
# ...                  ...            ...              ...              ...
# 102950.0             3.0            1.0              2.0              1.0
# 102952.0             3.0            2.0              1.0              2.0
# 102953.0             3.0            2.0              9.0              2.0
# 102954.0             5.0            2.0              1.0              2.0
# 102956.0             4.0            1.0              9.0              2.0
#
# [5569 rows x 86 columns]

# %% [markdown]
# # Discretization
#
# PENTING, JANGAN DIHAPUS

# %%
discretized_df = rearranged_df.copy()

temp = discretized_df.copy()

variable_discrete_val = {}

for ls in lifestyle_cols:
    variable_discrete_val[ls] = {}

    # Dont discretize already discretized columns
    if ls == 'Dieta2_DR1DAY' or len(discretized_df[ls].value_counts().to_list()) <=5:
        for k in df[ls].unique():
            variable_discrete_val[ls][str(k)] = k
        continue

    print(f'Categorizing column: {ls}, with value: ', end=' ')
    try:
        temp[ls] = pd.qcut(discretized_df[ls].to_numpy(), q=4, duplicates='drop') # For discretization label
        discretized_df[ls] = pd.qcut(discretized_df[ls].to_numpy(), q=4, labels=False, duplicates='drop') # Discretized columns

        for k, v in zip(discretized_df[ls].unique(), temp[ls].unique()):
            variable_discrete_val[ls][str(k)]=str(v)

    except Exception as error:
        print(f'{ls} cannot be discretized')
        print(f"ERROR DUE TO {error}")
        continue

print(variable_discrete_val)
# Out:
# Categorizing column: Dieta1_DRDINT, with value:  Categorizing column: Dieta1_DR1TFIBE, with value:  Categorizing column: Quest21_SLQ300, with value:  Categorizing column: Quest19_PAD660, with value:  Categorizing column: Dieta1_DR1TCHOL, with value:  Categorizing column: Quest19_PAQ655, with value:  Categorizing column: Dieta1_DR1TSFAT, with value:  Categorizing column: Dieta1_DR1TKCAL, with value:  Categorizing column: Exami2_BMXBMI, with value:  Categorizing column: Dieta1_DR1TSUGR, with value:  Categorizing column: Quest21_SLQ320, with value:  Categorizing column: Quest21_SLQ330, with value:  Categorizing column: Quest19_PAD615, with value:  Categorizing column: Quest21_SLD012, with value:  Categorizing column: Quest21_SLD013, with value:  Categorizing column: Dieta1_DR1DAY, with value:  Categorizing column: Quest6_DED120, with value:  Categorizing column: Quest19_PAQ610, with value:  Categorizing column: Quest6_DED125, with value:  Categorizing column: Dieta1_DR1TPROT, with value:  Categorizing column: Quest19_PAQ640, with value:  Categorizing column: Dieta1_DR1TPFAT, with value:  Categorizing column: Dieta1_DR1TMFAT, with value:  Categorizing column: Dieta1_DR1TCALC, with value:  Categorizing column: Dieta1_DR1TCARB, with value:  Categorizing column: Dieta1_DR1TTFAT, with value:  Categorizing column: Quest19_PAD645, with value:  {'Dieta1_DRDINT': {'1': '(1.938, 2.0]', '0': '(0.999, 1.938]'}, 'Dieta1_DR1TFIBE': {'0': '(-0.001, 10.2]', '2': '(15.5, 20.2]', '3': '(20.2, 107.8]', '1': '(10.2, 15.5]'}, 'Quest21_SLQ300': {'2': '(1320.0, 1380.0]', '1': '(240.0, 1320.0]', '0': '(-0.001, 240.0]', '3': '(1380.0, 1425.0]'}, 'Quest19_PAD660': {'2': '(69.153, 72.5]', '1': '(62.415, 69.153]', '0': '(9.999, 62.415]', '3': '(72.5, 9999.0]'}, 'Quest19_PAQ635': {'2.0': 2.0, '1.0': 1.0}, 'Dieta1_DR1TCHOL': {'0': '(-0.001, 144.0]', '2': '(275.039, 379.0]', '3': '(379.0, 2403.0]', '1': '(144.0, 275.039]'}, 'Quest19_PAQ655': {'2': '(3.315, 3.429]', '1': '(3.205, 3.315]', '3': '(3.429, 99.0]', '0': '(0.999, 3.205]'}, 'Dieta1_DR1TSFAT': {'1': '(16.384, 24.859]', '2': '(24.859, 33.11]', '3': '(33.11, 195.852]', '0': '(-0.001, 16.384]'}, 'Dieta1_DR1TKCAL': {'0': '(-0.001, 1502.0]', '1': '(1502.0, 2003.078]', '3': '(2475.444, 12501.0]', '2': '(2003.078, 2475.444]'}, 'Exami2_BMXBMI': {'2': '(28.8, 33.1]', '0': '(14.199, 25.1]', '3': '(33.1, 86.2]', '1': '(25.1, 28.8]'}, 'Dieta1_DR1TSUGR': {'1': '(60.47, 96.031]', '0': '(-0.001, 60.47]', '2': '(96.031, 128.5]', '3': '(128.5, 931.16]'}, 'Quest21_SLQ320': {'3': '(1350.0, 1430.0]', '2': '(1260.0, 1350.0]', '0': '(-0.001, 60.0]', '1': '(60.0, 1260.0]'}, 'Quest21_SLQ330': {'1': '(390.0, 450.0]', '0': '(-0.001, 390.0]', '2': '(450.0, 540.0]', '3': '(540.0, 1380.0]'}, 'Quest19_PAD615': {'0': '(9.999, 166.617]', '1': '(166.617, 190.605]', '3': '(214.342, 9999.0]', '2': '(190.605, 214.342]'}, 'Quest21_SLD012': {'2': '(7.5, 8.5]', '1': '(6.5, 7.5]', '0': '(1.999, 6.5]', '3': '(8.5, 14.0]'}, 'Quest21_SLD013': {'1': '(7.0, 8.0]', '0': '(1.999, 7.0]', '2': '(8.0, 9.0]', '3': '(9.0, 14.0]'}, 'Dieta1_DR1DAY': {'0': '(0.999, 3.0]', '3': '(6.0, 7.0]', '1': '(3.0, 5.0]', '2': '(5.0, 6.0]'}, 'Quest6_DED120': {'1': '(60.0, 116.493]', '0': '(-0.001, 60.0]', '2': '(116.493, 120.0]', '3': '(120.0, 9999.0]'}, 'Quest19_PAQ610': {'1': '(3.503, 4.077]', '0': '(0.999, 3.503]', '2': '(4.077, 4.411]', '3': '(4.411, 99.0]'}, 'Quest6_DED125': {'1': '(120.0, 148.855]', '2': '(148.855, 9999.0]', '0': '(-0.001, 120.0]'}, 'Dieta1_DR1TPROT': {'0': '(-0.001, 54.27]', '2': '(74.44, 94.43]', '3': '(94.43, 545.2]', '1': '(54.27, 74.44]'}, 'Quest19_PAQ640': {'1': '(4.579, 4.667]', '3': '(4.753, 99.0]', '0': '(0.999, 4.579]', '2': '(4.667, 4.753]'}, 'Dieta1_DR1TPFAT': {'2': '(18.545, 24.318]', '1': '(12.052, 18.545]', '3': '(24.318, 200.697]', '0': '(-0.001, 12.052]'}, 'Dieta1_DR1TMFAT': {'0': '(-0.001, 18.698]', '2': '(27.213, 35.11]', '3': '(35.11, 200.097]', '1': '(18.698, 27.213]'}, 'Dieta1_DR1TCALC': {'0': '(-0.001, 572.0]', '2': '(840.3 ...

# %%
with open('variable_discrete_value.json', 'w') as json_file:
    json.dump(variable_discrete_val, json_file)

# %%
discretized_df.head()
# Out:
#          Dieta1_DRDINT  Dieta1_DR1TFIBE  Quest21_SLQ300  Quest19_PAD660  \
# SEQN
# 93705.0              1                0               2               2
# 93708.0              1                2               2               2
# 93709.0              0                2               2               1
# 93711.0              1                3               1               0
# 93713.0              1                1               2               1
#
#          Quest19_PAQ635  Dieta1_DR1TCHOL  Quest19_PAQ655  Dieta1_DR1TSFAT  \
# SEQN
# 93705.0             2.0                0               2                1
# 93708.0             2.0                0               2                1
# 93709.0             2.0                2               1                2
# 93711.0             1.0                3               3                3
# 93713.0             1.0                1               2                3
#
#          Dieta1_DR1TKCAL  Exami2_BMXBMI  ...  Quest1_ALQ111  Quest10_ECQ020  \
# SEQN                                     ...
# 93705.0                0              2  ...            1.0             9.0
# 93708.0                0              0  ...            2.0             9.0
# 93709.0                1              3  ...            9.0             9.0
# 93711.0                3              0  ...            1.0             9.0
# 93713.0                2              0  ...            1.0             9.0
#
#          Quest16_MCQ220  Quest4_CBD121  Quest16_MCQ366A  Labor2_URDFLOW1  \
# SEQN
# 93705.0             2.0   7.500000e+01              2.0            1.204
# 93708.0             2.0   5.397605e-79              2.0            0.500
# 93709.0             2.0   4.000000e+01              2.0            0.107
# 93711.0             2.0   8.570000e+02              2.0            0.605
# 93713.0             2.0   4.000000e+01              2.0            0.706
#
#          Demog1_DMDEDUC  Quest9_DLQ050  Quest20_PFQ061C  Quest16_MCQ160B
# SEQN
# 93705.0             2.0            2.0              1.0              2.0
# 93708.0             1.0            2.0              2.0              2.0
# 93709.0             4.0            1.0              9.0              2.0
# 93711.0             5.0            2.0              9.0              2.0
# 93713.0             3.0            2.0              1.0              2.0
#
# [5 rows x 86 columns]

# %% [markdown]
# # Save Data

# %%
target_path = "Dataset/Data Versioning/Trained_V2-3.csv"
final = discretized_df.copy()

final.to_csv(os.path.join(drive_path, target_path))
