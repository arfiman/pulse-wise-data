# %% [markdown]
# # Prep Environment & Ingest Data

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import random

from sklearn.metrics import confusion_matrix

import warnings
warnings.filterwarnings('ignore')

drive_path = '/content/drive/MyDrive/Kuliah/Tugas Akhir/Final Project Shared Folder'
data_path = "Dataset/Data Versioning/"
model_path = "Model/ML Model/"
data_version = "Trained_V2-3.csv"
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']
# Out:
# Mounted at /content/drive

# %%
df_raw = pd.read_csv(os.path.join(drive_path, data_path+data_version), index_col = 0)
try:
  df_raw = df_raw.set_index('SEQN', drop=True)
  df_raw = df_raw.drop(columns = "Unnamed: 0")
except:
  pass

df_raw.head()
# Out:
#          Dieta1_DRDINT  Dieta1_DR1TFIBE  Quest21_SLQ300  Quest19_PAD660  \
# SEQN
# 93705.0              1                0               2               2
# 93708.0              1                2               2               2
# 93709.0              0                2               2               1
# 93711.0              1                3               1               0
# 93713.0              1                1               2               1
#
#          Quest19_PAQ635  Dieta1_DR1TCHOL  Quest19_PAQ655  Dieta1_DR1TSFAT  \
# SEQN
# 93705.0             2.0                0               2                1
# 93708.0             2.0                0               2                1
# 93709.0             2.0                2               1                2
# 93711.0             1.0                3               3                3
# 93713.0             1.0                1               2                3
#
#          Dieta1_DR1TKCAL  Exami2_BMXBMI  ...  Quest1_ALQ111  Quest10_ECQ020  \
# SEQN                                     ...
# 93705.0                0              2  ...            1.0             9.0
# 93708.0                0              0  ...            2.0             9.0
# 93709.0                1              3  ...            9.0             9.0
# 93711.0                3              0  ...            1.0             9.0
# 93713.0                2              0  ...            1.0             9.0
#
#          Quest16_MCQ220  Quest4_CBD121  Quest16_MCQ366A  Labor2_URDFLOW1  \
# SEQN
# 93705.0             2.0   7.500000e+01              2.0            1.204
# 93708.0             2.0   5.397605e-79              2.0            0.500
# 93709.0             2.0   4.000000e+01              2.0            0.107
# 93711.0             2.0   8.570000e+02              2.0            0.605
# 93713.0             2.0   4.000000e+01              2.0            0.706
#
#          Demog1_DMDEDUC  Quest9_DLQ050  Quest20_PFQ061C  Quest16_MCQ160B
# SEQN
# 93705.0             2.0            2.0              1.0              2.0
# 93708.0             1.0            2.0              2.0              2.0
# 93709.0             4.0            1.0              9.0              2.0
# 93711.0             5.0            2.0              9.0              2.0
# 93713.0             3.0            2.0              1.0              2.0
#
# [5 rows x 86 columns]

# %% [markdown]
# # Oversampling

# %% [markdown]
# ## Define Target Variable

# %%
X = df_raw.copy().drop(columns=['Quest16_MCQ160B'])
y = df_raw['Quest16_MCQ160B']
y = y.replace({2: 0})
y = y.replace({9: 0})
y = y.astype(int)

# %%
y.value_counts()
# Out:
# Quest16_MCQ160B
# 0    5368
# 1     201
# Name: count, dtype: int64

# %% [markdown]
# ## Oversampling Using SMOTE

# %%
def get_categorical(df):
    categorical = []
    for col in df.columns.tolist():
        try:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': model_var[model_var['model_var_name'] ==  col]['desc'].values[0],
                    'column': col,
                    'possible_values': df[col].unique().tolist()}
                            )
        except Exception as error:
            if len(df[col].unique().tolist()) < 20:
                categorical.append({
                    'desc': None,
                    'column': col,
                    'possible_values': df[col].unique().tolist()})
            # print(f'{col} error: {error}')
    return categorical

categorical_summary = get_categorical(X)
categorical_cols = [True if data_col in [col['column'] for col in categorical_summary] else False for data_col in X.columns.tolist()]
print(categorical_cols)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, False, True, True, False, True, True, False, True, True, True, True, False, True, True, False, True, True, False, False, True, True, False, True, False, False, True, True, True, True, True, True, False, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, False, True, True, True]

# %%
from imblearn.over_sampling import SMOTENC

# Instantiate the SMOTE oversampler
smotenc = SMOTENC(
    categorical_features=categorical_cols,
    sampling_strategy='auto',
    random_state=37
  )

# Apply SMOTE to generate synthetic samples
X_resampled, y_resampled = smotenc.fit_resample(X, y)

# Print the number of samples in each class after oversampling
print("Class distribution after oversampling:", {label: count for label, count in zip(*np.unique(y_resampled, return_counts=True))})
# Out:
# Class distribution after oversampling: {0: 5368, 1: 5368}

# %% [markdown]
# # Evaluate Oversampling Result

# %% [markdown]
# ### Summary Data Before vs After Oversampling

# %%
X.iloc[:, :20].describe()
# Out:
#        Dieta1_DRDINT  Dieta1_DR1TFIBE  Quest21_SLQ300  Quest19_PAD660  \
# count    5569.000000      5569.000000     5569.000000     5569.000000
# mean        0.749865         1.495062        1.114383        1.436883
# std         0.433129         1.120771        0.835859        1.078465
# min         0.000000         0.000000        0.000000        0.000000
# 25%         0.000000         0.000000        0.000000        0.000000
# 50%         1.000000         1.000000        1.000000        1.000000
# 75%         1.000000         2.000000        2.000000        2.000000
# max         1.000000         3.000000        3.000000        3.000000
#
#        Quest19_PAQ635  Dieta1_DR1TCHOL  Quest19_PAQ655  Dieta1_DR1TSFAT  \
# count     5569.000000      5569.000000     5569.000000      5569.000000
# mean         1.762076         1.476567        1.461304         1.499731
# std          0.425851         1.118611        1.119792         1.118215
# min          1.000000         0.000000        0.000000         0.000000
# 25%          2.000000         0.000000        0.000000         0.000000
# 50%          2.000000         1.000000        1.000000         1.000000
# 75%          2.000000         2.000000        2.000000         2.000000
# max          2.000000         3.000000        3.000000         3.000000
#
#        Dieta1_DR1TKCAL  Exami2_BMXBMI  Dieta1_DR1TSUGR  Quest21_SLQ320  \
# count      5569.000000    5569.000000      5569.000000     5569.000000
# mean          1.497755       1.495960         1.499731        1.436883
# std           1.118052       1.118689         1.118215        1.145649
# min           0.000000       0.000000         0.000000        0.000000
# 25%           0.000000       0.000000         0.000000        0.000000
# 50%           1.000000       1.000000         1.000000        1.000000
# 75%           2.000000       2.000000         2.000000        2.000000
# max           3.000000       3.000000         3.000000        3.000000
#
#        Quest21_SLQ330  Quest19_PAD615  Quest21_SLD012  Quest21_SLD013  \
# count     5569.000000     5569.000000     5569.000000     5569.000000
# mean         1.360029        1.467948        1.475669        1.430598
# std          1.059741        1.116308        1.102583        1.118630
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          1.000000        1.000000        1.000000        1.000000
# 75%          2.000000        2.000000        2.000000        2.000000
# max          3.000000        3.000000        3.000000        3.000000
#
#        Dieta1_DR1DAY  Quest6_DED120  Quest19_PAQ610  Quest6_DED125
# count    5569.000000    5569.000000     5569.000000    5569.000000
# mean        1.303466       1.169510        1.477465       0.883821
# std         1.083041       1.102829        1.119593       0.774484
# min         0.000000       0.000000        0.000000       0.000000
# 25%         0.000000       0.000000        0.000000       0.000000
# 50%         1.000000       1.000000        1.000000       1.000000
# 75%         2.000000       2.000000        2.000000       1.000000
# max         3.000000       3.000000        3.000000       2.000000

# %%
X_resampled.iloc[:, :20].describe()
# Out:
#        Dieta1_DRDINT  Dieta1_DR1TFIBE  Quest21_SLQ300  Quest19_PAD660  \
# count   10736.000000     10736.000000    10736.000000    10736.000000
# mean        0.788376         1.341841        1.041170        1.574143
# std         0.408479         1.087655        0.798217        0.867623
# min         0.000000         0.000000        0.000000        0.000000
# 25%         1.000000         0.000000        0.000000        1.000000
# 50%         1.000000         1.000000        1.000000        2.000000
# 75%         1.000000         2.000000        2.000000        2.000000
# max         1.000000         3.000000        3.000000        3.000000
#
#        Quest19_PAQ635  Dieta1_DR1TCHOL  Quest19_PAQ655  Dieta1_DR1TSFAT  \
# count    10736.000000     10736.000000    10736.000000     10736.000000
# mean         1.871740         1.435637        1.052534         1.444020
# std          0.334395         1.114645        1.053146         1.058967
# min          1.000000         0.000000        0.000000         0.000000
# 25%          2.000000         0.000000        0.000000         1.000000
# 50%          2.000000         1.000000        1.000000         1.000000
# 75%          2.000000         2.000000        2.000000         2.000000
# max          2.000000         3.000000        3.000000         3.000000
#
#        Dieta1_DR1TKCAL  Exami2_BMXBMI  Dieta1_DR1TSUGR  Quest21_SLQ320  \
# count     10736.000000   10736.000000     10736.000000    10736.000000
# mean          1.274870       1.793126         1.530458        1.420268
# std           1.053389       1.052490         1.041032        1.125466
# min           0.000000       0.000000         0.000000        0.000000
# 25%           0.000000       1.000000         1.000000        0.000000
# 50%           1.000000       2.000000         2.000000        1.000000
# 75%           2.000000       3.000000         2.000000        2.000000
# max           3.000000       3.000000         3.000000        3.000000
#
#        Quest21_SLQ330  Quest19_PAD615  Quest21_SLD012  Quest21_SLD013  \
# count    10736.000000    10736.000000    10736.000000    10736.000000
# mean         1.190387        1.073864        1.543778        1.253446
# std          1.066614        0.976216        1.186535        1.115892
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          1.000000        1.000000        2.000000        1.000000
# 75%          2.000000        2.000000        3.000000        2.000000
# max          3.000000        3.000000        3.000000        3.000000
#
#        Dieta1_DR1DAY  Quest6_DED120  Quest19_PAQ610  Quest6_DED125
# count   10736.000000   10736.000000    10736.000000   10736.000000
# mean        1.148007       1.091841        0.939735       0.938897
# std         0.990021       0.808401        1.057103       0.567060
# min         0.000000       0.000000        0.000000       0.000000
# 25%         0.000000       1.000000        0.000000       1.000000
# 50%         1.000000       1.000000        1.000000       1.000000
# 75%         2.000000       1.000000        2.000000       1.000000
# max         3.000000       3.000000        3.000000       2.000000

# %%
X.iloc[:, 20:40].describe()
# Out:
#        Dieta1_DR1TPROT  Quest19_PAQ640  Dieta1_DR1TPFAT  Dieta1_DR1TMFAT  \
# count      5569.000000     5569.000000      5569.000000      5569.000000
# mean          1.498474        1.416233         1.499192         1.498474
# std           1.118214        1.114750         1.118214         1.118374
# min           0.000000        0.000000         0.000000         0.000000
# 25%           0.000000        0.000000         0.000000         0.000000
# 50%           1.000000        1.000000         1.000000         1.000000
# 75%           2.000000        2.000000         2.000000         2.000000
# max           3.000000        3.000000         3.000000         3.000000
#
#        Dieta1_DR1TCALC  Dieta1_DR1TCARB  Dieta1_DR1TTFAT  Quest19_PAD645  \
# count      5569.000000      5569.000000      5569.000000     5569.000000
# mean          1.495421         1.497935         1.499551        1.480158
# std           1.118366         1.118213         1.118215        1.118520
# min           0.000000         0.000000         0.000000        0.000000
# 25%           0.000000         0.000000         0.000000        0.000000
# 50%           1.000000         1.000000         1.000000        1.000000
# 75%           2.000000         2.000000         2.000000        2.000000
# max           3.000000         3.000000         3.000000        3.000000
#
#        Exami1_BPXPLS  Demog1_RIDRETH3  Demog1_DMDHHSZA  Demog1_DMDHHSZE  \
# count    5569.000000      5569.000000     5.569000e+03     5.569000e+03
# mean       71.664099         3.509248     2.495960e-01     7.240079e-01
# std        11.133882         1.640114     6.051535e-01     8.342093e-01
# min        34.000000         1.000000     5.397605e-79     5.397605e-79
# 25%        64.000000         3.000000     5.397605e-79     5.397605e-79
# 50%        70.810811         3.000000     5.397605e-79     5.397605e-79
# 75%        78.000000         4.000000     5.397605e-79     1.000000e+00
# max       136.000000         7.000000     3.000000e+00     3.000000e+00
#
#        Quest14_INQ020  Quest18_OCQ210  Demog1_INDIN2  Quest12_HEQ030  \
# count     5569.000000     5569.000000    5569.000000     5569.000000
# mean         1.780212        7.859939      17.408332        2.017418
# std          1.990773        2.680441      26.055169        0.513697
# min          1.000000        1.000000       1.000000        1.000000
# 25%          1.000000        9.000000       6.000000        2.000000
# 50%          1.000000        9.000000       9.000000        2.000000
# 75%          2.000000        9.000000      15.000000        2.000000
# max          9.000000        9.000000      99.000000        9.000000
#
#        Quest22_SMQ900  Exami2_BMXHT  Quest3_CDQ009  Quest3_CDQ010
# count     5569.000000   5569.000000    5569.000000    5569.000000
# mean         1.811456    166.246497       0.039145       3.878614
# std          0.391181      9.777816       0.193958       3.421848
# min          1.000000    138.300000       0.000000       1.000000
# 25%          2.000000    159.200000       0.000000       1.000000
# 50%          2.000000    165.800000       0.000000       2.000000
# 75%          2.000000    172.900000       0.000000       9.000000
# max          2.000000    197.700000       1.000000       9.000000

# %%
X_resampled.iloc[:, 20:40].describe()
# Out:
#        Dieta1_DR1TPROT  Quest19_PAQ640  Dieta1_DR1TPFAT  Dieta1_DR1TMFAT  \
# count     10736.000000    10736.000000     10736.000000     10736.000000
# mean          1.228484        1.258849         1.355160         1.411233
# std           1.081087        0.925429         1.086513         1.067861
# min           0.000000        0.000000         0.000000         0.000000
# 25%           0.000000        1.000000         0.000000         1.000000
# 50%           1.000000        1.000000         1.000000         1.000000
# 75%           2.000000        2.000000         2.000000         2.000000
# max           3.000000        3.000000         3.000000         3.000000
#
#        Dieta1_DR1TCALC  Dieta1_DR1TCARB  Dieta1_DR1TTFAT  Quest19_PAD645  \
# count     10736.000000     10736.000000     10736.000000    10736.000000
# mean          1.349292         1.276732         1.362239        1.340723
# std           1.058078         1.063465         1.103336        0.931148
# min           0.000000         0.000000         0.000000        0.000000
# 25%           0.000000         0.000000         0.000000        1.000000
# 50%           1.000000         1.000000         1.000000        1.000000
# 75%           2.000000         2.000000         2.000000        2.000000
# max           3.000000         3.000000         3.000000        3.000000
#
#        Exami1_BPXPLS  Demog1_RIDRETH3  Demog1_DMDHHSZA  Demog1_DMDHHSZE  \
# count   10736.000000     10736.000000     1.073600e+04     1.073600e+04
# mean       70.752955         3.440294     1.294709e-01     1.048249e+00
# std         9.700859         1.309481     4.533203e-01     7.829701e-01
# min        34.000000         1.000000     5.397605e-79     5.397605e-79
# 25%        64.713513         3.000000     5.397605e-79     5.397605e-79
# 50%        70.000000         3.000000     5.397605e-79     1.000000e+00
# 75%        76.000000         4.000000     5.397605e-79     2.000000e+00
# max       136.000000         7.000000     3.000000e+00     3.000000e+00
#
#        Quest14_INQ020  Quest18_OCQ210  Demog1_INDIN2  Quest12_HEQ030  \
# count    10736.000000    10736.000000   10736.000000    10736.000000
# mean         1.885153        8.408625      15.310658        2.009035
# std          1.812121        2.012730      23.788460        0.370063
# min          1.000000        1.000000       1.000000        1.000000
# 25%          1.000000        9.000000       5.171529        2.000000
# 50%          1.000000        9.000000       7.500000        2.000000
# 75%          2.000000        9.000000      14.000000        2.000000
# max          9.000000        9.000000      99.000000        9.000000
#
#        Quest22_SMQ900  Exami2_BMXHT  Quest3_CDQ009  Quest3_CDQ010
# count    10736.000000  10736.000000   10736.000000   10736.000000
# mean         1.893536    166.787402       0.049739       2.532880
# std          0.308445      9.092116       0.217416       2.839314
# min          1.000000    138.300000       0.000000       1.000000
# 25%          2.000000    160.841829       0.000000       1.000000
# 50%          2.000000    166.544311       0.000000       1.000000
# 75%          2.000000    172.808903       0.000000       2.000000
# max          2.000000    197.700000       1.000000       9.000000

# %%
X.iloc[:, 40:].describe()
# Out:
#        Exami2_BMXWT  Quest3_CDQ008  Quest20_PFQ061H  Quest7_DIQ010  \
# count   5569.000000    5569.000000      5569.000000    5569.000000
# mean      82.739950       7.527743         4.921889       1.878614
# std       22.163483       2.921444         3.900593       0.456818
# min       32.600000       1.000000         1.000000       1.000000
# 25%       68.000000       9.000000         1.000000       2.000000
# 50%       79.600000       9.000000         2.000000       2.000000
# 75%       93.300000       9.000000         9.000000       2.000000
# max      242.600000       9.000000         9.000000       9.000000
#
#        Quest20_PFQ061B  Labor1_LBDTCSI  Quest17_DPQ040  Demog1_RIAGENDR  \
# count      5569.000000     5569.000000    5.569000e+03      5569.000000
# mean          6.086191        4.859067    1.830670e+00         1.514814
# std           3.720251        1.008385    2.914901e+00         0.499825
# min           1.000000        1.970000    5.397605e-79         1.000000
# 25%           1.000000        4.220000    5.397605e-79         1.000000
# 50%           9.000000        4.781616    1.000000e+00         2.000000
# 75%           9.000000        5.400000    2.000000e+00         2.000000
# max           9.000000       11.530000    9.000000e+00         2.000000
#
#        Labor2_URDTIME1  Quest22_SMQ890  ...  Quest12_HEQ010  Quest1_ALQ111  \
# count      5569.000000     5569.000000  ...     5569.000000    5569.000000
# mean        147.109676        1.639073  ...        2.017418       2.075417
# std          96.053089        0.500814  ...        0.451154       2.609262
# min           4.000000        1.000000  ...        1.000000       1.000000
# 25%          89.000000        1.000000  ...        2.000000       1.000000
# 50%         138.857977        2.000000  ...        2.000000       1.000000
# 75%         164.000000        2.000000  ...        2.000000       1.000000
# max        1243.000000        9.000000  ...        9.000000       9.000000
#
#        Quest10_ECQ020  Quest16_MCQ220  Quest4_CBD121  Quest16_MCQ366A  \
# count          5569.0     5569.000000   5.569000e+03      5569.000000
# mean              9.0        1.896929   2.826513e+04         1.720776
# std               0.0        0.335527   1.642453e+05         0.470541
# min               9.0        1.000000   5.397605e-79         1.000000
# 25%               9.0        2.000000   4.000000e+01         1.000000
# 50%               9.0        2.000000   1.000000e+02         2.000000
# 75%               9.0        2.000000   2.000000e+02         2.000000
# max               9.0        9.000000   9.999990e+05         9.000000
#
#        Labor2_URDFLOW1  Demog1_DMDEDUC  Quest9_DLQ050  Quest20_PFQ061C
# count     5.569000e+03     5569.000000    5569.000000      5569.000000
# mean      9.147597e-01        3.525768       1.831388         6.025139
# std       1.162899e+00        1.240231       0.412771         3.783673
# min       5.397605e-79        1.000000       1.000000         1.000000
# 25%       4.390000e-01        3.000000       2.000000         1.000000
# 50%       7.640000e-01        4.000000       2.000000         9.000000
# 75%       1.018974e+00        4.000000       2.000000         9.000000
# max       5.050000e+01        9.000000       9.000000         9.000000
#
# [8 rows x 45 columns]

# %%
X_resampled.iloc[:, 40:].describe()
# Out:
#        Exami2_BMXWT  Quest3_CDQ008  Quest20_PFQ061H  Quest7_DIQ010  \
# count  10736.000000   10736.000000     10736.000000   10736.000000
# mean      87.034262       6.091002         3.288003       1.681073
# std       21.358663       3.574350         3.371287       0.524215
# min       32.600000       1.000000         1.000000       1.000000
# 25%       73.300000       2.000000         1.000000       1.000000
# 50%       83.700000       9.000000         1.000000       2.000000
# 75%       98.800000       9.000000         9.000000       2.000000
# max      242.600000       9.000000         9.000000       9.000000
#
#        Quest20_PFQ061B  Labor1_LBDTCSI  Quest17_DPQ040  Demog1_RIAGENDR  \
# count     10736.000000    10736.000000    1.073600e+04     10736.000000
# mean          6.783625        4.626942    2.441971e+00         1.436941
# std           3.458993        0.976295    3.404562e+00         0.496031
# min           1.000000        1.970000    5.397605e-79         1.000000
# 25%           2.000000        3.917830    5.397605e-79         1.000000
# 50%           9.000000        4.598256    1.000000e+00         1.000000
# 75%           9.000000        5.150000    3.000000e+00         2.000000
# max           9.000000       11.530000    9.000000e+00         2.000000
#
#        Labor2_URDTIME1  Quest22_SMQ890  ...  Quest12_HEQ010  Quest1_ALQ111  \
# count     10736.000000    10736.000000  ...    10736.000000   10736.000000
# mean        147.814433        1.541729  ...        2.009035       2.262016
# std          96.977034        0.508640  ...        0.325034       2.856903
# min           4.000000        1.000000  ...        1.000000       1.000000
# 25%          92.000000        1.000000  ...        2.000000       1.000000
# 50%         138.423154        2.000000  ...        2.000000       1.000000
# 75%         158.000000        2.000000  ...        2.000000       1.000000
# max        1243.000000        9.000000  ...        9.000000       9.000000
#
#        Quest10_ECQ020  Quest16_MCQ220  Quest4_CBD121  Quest16_MCQ366A  \
# count         10736.0    10736.000000   1.073600e+04     10736.000000
# mean              9.0        1.893536   2.457593e+04         1.561662
# std               0.0        0.324918   1.520942e+05         0.506610
# min               9.0        1.000000   5.397605e-79         1.000000
# 25%               9.0        2.000000   2.500000e+01         1.000000
# 50%               9.0        2.000000   8.000000e+01         2.000000
# 75%               9.0        2.000000   1.800000e+02         2.000000
# max               9.0        9.000000   9.999990e+05         9.000000
#
#        Labor2_URDFLOW1  Demog1_DMDEDUC  Quest9_DLQ050  Quest20_PFQ061C
# count     1.073600e+04    10736.000000   10736.000000     10736.000000
# mean      9.083769e-01        3.427627       1.577776         6.531017
# std       1.578674e+00        1.125881       0.509533         3.641244
# min       5.397605e-79        1.000000       1.000000         1.000000
# 25%       4.290000e-01        3.000000       1.000000         1.000000
# 50%       7.427424e-01        4.000000       2.000000         9.000000
# 75%       9.881101e-01        4.000000       2.000000         9.000000
# max       5.050000e+01        9.000000       9.000000         9.000000
#
# [8 rows x 45 columns]

# %% [markdown]
# ### Get Variables Info

# %%
var_mapping_path = 'Dataset/Variable Mapping V2.xlsx'

var_mapping = pd.read_excel(os.path.join(drive_path, var_mapping_path))
var_mapping['group'] = var_mapping['group'].replace({'Dieta2': 'Dieta1'})
var_mapping['model_var_name'] = var_mapping['group'] + "_" + var_mapping['variable']

var_mapping = var_mapping.set_index('model_var_name')

var_mapping
# Out:
#                           name                                     title  \
# model_var_name
# Demog1_RIAGENDR   Demographics  Demographic Variables and Sample Weights
# Demog1_RIDAGEYR   Demographics  Demographic Variables and Sample Weights
# Demog1_RIDRETH3   Demographics  Demographic Variables and Sample Weights
# Demog1_DMDEDUC3   Demographics  Demographic Variables and Sample Weights
# Demog1_DMDEDUC2   Demographics  Demographic Variables and Sample Weights
# ...                        ...                                       ...
# Demog1_DMDEDUC     Demographic  Demographic Variables and Sample Weights
# Demog1_INDIN2      Demographic  Demographic Variables and Sample Weights
# Exami1_SysPulse    Examination                            Blood Pressure
# Exami1_DiaPulse    Examination                            Blood Pressure
# Quest3_CDQ009    Questionnaire                     Cardiovascular Health
#
#                  variable                                               desc  \
# model_var_name
# Demog1_RIAGENDR  RIAGENDR                                             Gender
# Demog1_RIDAGEYR  RIDAGEYR                          Age In Years At Screening
# Demog1_RIDRETH3  RIDRETH3                   Race/Hispanic Origin W/ Nh Asian
# Demog1_DMDEDUC3  DMDEDUC3              Education Level - Children/Youth 6-19
# Demog1_DMDEDUC2  DMDEDUC2                       Education Level - Adults 20+
# ...                   ...                                                ...
# Demog1_DMDEDUC    DMDEDUC                            Education Level all age
# Demog1_INDIN2      INDIN2  Average income from household income & family ...
# Exami1_SysPulse  SysPulse                            Systolic Pulse Combined
# Exami1_DiaPulse  DiaPulse                           Diastolic Pulse Combined
# Quest3_CDQ009      CDQ009                            Pain In Body (Combined)
#
#                  is_used  lifestyle   group
# model_var_name
# Demog1_RIAGENDR     True      False  Demog1
# Demog1_RIDAGEYR     True      False  Demog1
# Demog1_RIDRETH3     True      False  Demog1
# Demog1_DMDEDUC3     True      False  Demog1
# Demog1_DMDEDUC2     True      False  Demog1
# ...                  ...        ...     ...
# Demog1_DMDEDUC      True      False  Demog1
# Demog1_INDIN2       True      False  Demog1
# Exami1_SysPulse     True      False  Exami1
# Exami1_DiaPulse     True      False  Exami1
# Quest3_CDQ009       True      False  Quest3
#
# [153 rows x 7 columns]

# %% [markdown]
# ### Summarize Relative Changes

# %%
before = X.describe().loc[['mean', 'std'], :].transpose()
after = X_resampled.describe().loc[['mean', 'std'], :].transpose()

before_after = before.join(after, rsuffix='_oversampled')

before_after['mean_relative_change'] = (before_after['mean_oversampled'] - before_after['mean']) / before_after['mean']
before_after['std_relative_change'] = (before_after['std_oversampled'] - before_after['std']) / before_after['std']

# Get Variable's description
before_after = before_after.join(var_mapping['desc'])

before_after
# Out:
#                          mean            std  mean_oversampled  \
# Demog1_DMDEDUC       3.525768       1.240231          3.427627
# Demog1_DMDFMSIZ      2.971988       1.667688          2.449236
# Demog1_DMDHHSIZ      3.112408       1.625256          2.558867
# Demog1_DMDHHSZA      0.249596       0.605154          0.129471
# Demog1_DMDHHSZB      0.490573       0.849670          0.264903
# ...                       ...            ...               ...
# Quest4_CBD121    28265.128097  164245.278134      24575.927644
# Quest6_DED120        1.169510       1.102829          1.091841
# Quest6_DED125        0.883821       0.774484          0.938897
# Quest7_DIQ010        1.878614       0.456818          1.681073
# Quest9_DLQ050        1.831388       0.412771          1.577776
#
#                  std_oversampled  mean_relative_change  std_relative_change  \
# Demog1_DMDEDUC          1.125881             -0.027835            -0.092201
# Demog1_DMDFMSIZ         1.459860             -0.175893            -0.124621
# Demog1_DMDHHSIZ         1.445317             -0.177850            -0.110714
# Demog1_DMDHHSZA         0.453320             -0.481278            -0.250900
# Demog1_DMDHHSZB         0.666492             -0.460013            -0.215587
# ...                          ...                   ...                  ...
# Quest4_CBD121      152094.174623             -0.130521            -0.073981
# Quest6_DED120           0.808401             -0.066412            -0.266976
# Quest6_DED125           0.567060              0.062316            -0.267822
# Quest7_DIQ010           0.524215             -0.105152             0.147537
# Quest9_DLQ050           0.509533             -0.138481             0.234421
#
#                                                     desc
# Demog1_DMDEDUC                   Education Level all age
# Demog1_DMDFMSIZ     Total Number Of People In The Family
# Demog1_DMDHHSIZ  Total Number Of People In The Household
# Demog1_DMDHHSZA   # Of Children 5 Years Or Younger In Hh
# Demog1_DMDHHSZB       # Of Children 6-17 Years Old In Hh
# ...                                                  ...
# Quest4_CBD121                  Money Spent On Eating Out
# Quest6_DED120        Minutes Outdoors 9Am - 5Pm Work Day
# Quest6_DED125    Minutes Outdoors 9Am - 5Pm Not Work Day
# Quest7_DIQ010              Doctor Told You Have Diabetes
# Quest9_DLQ050           Have Serious Difficulty Walking?
#
# [87 rows x 7 columns]

# %% [markdown]
# #### Mean Relative Changes

# %%
before_after.sort_values(by=['mean_relative_change']).head(10)
# Out:
#                          mean            std  mean_oversampled  \
# Demog1_DMDHHSZA      0.249596       0.605154          0.129471
# Demog1_DMDHHSZB      0.490573       0.849670          0.264903
# Quest4_CBD111    16612.483330  126081.947610       9793.447034
# Quest19_PAQ610       1.477465       1.119593          0.939735
# Quest3_CDQ010        3.878614       3.421848          2.532880
# Quest20_PFQ061H      4.921889       3.900593          3.288003
# Quest19_PAQ655       1.461304       1.119792          1.052534
# Quest19_PAD615       1.467948       1.116308          1.073864
# Quest3_CDQ008        7.527743       2.921444          6.091002
# Dieta1_DR1TPROT      1.498474       1.118214          1.228484
#
#                  std_oversampled  mean_relative_change  std_relative_change  \
# Demog1_DMDHHSZA         0.453320             -0.481278            -0.250900
# Demog1_DMDHHSZB         0.666492             -0.460013            -0.215587
# Quest4_CBD111       95014.987972             -0.410477            -0.246403
# Quest19_PAQ610          1.057103             -0.363954            -0.055815
# Quest3_CDQ010           2.839314             -0.346963            -0.170240
# Quest20_PFQ061H         3.371287             -0.331963            -0.135699
# Quest19_PAQ655          1.053146             -0.279730            -0.059517
# Quest19_PAD615          0.976216             -0.268459            -0.125496
# Quest3_CDQ008           3.574350             -0.190859             0.223487
# Dieta1_DR1TPROT         1.081087             -0.180177            -0.033201
#
#                                                      desc
# Demog1_DMDHHSZA    # Of Children 5 Years Or Younger In Hh
# Demog1_DMDHHSZB        # Of Children 6-17 Years Old In Hh
# Quest4_CBD111         Money Spent On Food At Other Stores
# Quest19_PAQ610               Number Of Days Vigorous Work
# Quest3_CDQ010      Shortness Of Breath On Stairs/Inclines
# Quest20_PFQ061H          Difficulty Walking Between Rooms
# Quest19_PAQ655      Days Vigorous Recreational Activities
# Quest19_PAD615            Minutes Vigorous-Intensity Work
# Quest3_CDQ008    Severe Pain In Chest More Than Half Hour
# Dieta1_DR1TPROT                              Protein (Gm)

# %%
before_after.sort_values(by=['mean_relative_change']).tail(10)
# Out:
#                       mean        std  mean_oversampled  std_oversampled  \
# Quest1_ALQ111     2.075417   2.609262          2.262016         2.856903
# Quest19_PAD660    1.436883   1.078465          1.574143         0.867623
# Quest20_PFQ061B   6.086191   3.720251          6.783625         3.458993
# Demog1_RIDAGEYR  51.503681  17.812855         59.848812        16.576309
# Exami2_BMXBMI     1.495960   1.118689          1.793126         1.052490
# Quest3_CDQ009     0.039145   0.193958          0.049739         0.217416
# Quest17_DPQ020    1.480697   2.988309          1.936103         3.482663
# Quest17_DPQ030    1.725983   2.955484          2.282507         3.462113
# Quest17_DPQ040    1.830670   2.914901          2.441971         3.404562
# Demog1_DMDHHSZE   0.724008   0.834209          1.048249         0.782970
#
#                  mean_relative_change  std_relative_change  \
# Quest1_ALQ111                0.089909             0.094909
# Quest19_PAD660               0.095526            -0.195502
# Quest20_PFQ061B              0.114593            -0.070226
# Demog1_RIDAGEYR              0.162030            -0.069419
# Exami2_BMXBMI                0.198646            -0.059176
# Quest3_CDQ009                0.270631             0.120943
# Quest17_DPQ020               0.307562             0.165429
# Quest17_DPQ030               0.322439             0.171420
# Quest17_DPQ040               0.333922             0.167986
# Demog1_DMDHHSZE              0.447842            -0.061423
#
#                                                      desc
# Quest1_ALQ111     Ever Had A Drink Of Any Kind Of Alcohol
# Quest19_PAD660   Minutes Vigorous Recreational Activities
# Quest20_PFQ061B     Difficulty Walking For A Quarter Mile
# Demog1_RIDAGEYR                 Age In Years At Screening
# Exami2_BMXBMI                   Body Mass Index (Kg/M**2)
# Quest3_CDQ009                     Pain In Body (Combined)
# Quest17_DPQ020       Feeling Down, Depressed, Or Hopeless
# Quest17_DPQ030      Trouble Sleeping Or Sleeping Too Much
# Quest17_DPQ040      Feeling Tired Or Having Little Energy
# Demog1_DMDHHSZE       # Of Adults 60 Years Or Older In Hh

# %% [markdown]
# #### Standard Deviation Relative Changes

# %%
before_after.sort_values(by=['std_relative_change']).head(10)
# Out:
#                          mean            std  mean_oversampled  \
# Quest12_HEQ030       2.017418       0.513697          2.009035
# Quest12_HEQ010       2.017418       0.451154          2.009035
# Quest6_DED125        0.883821       0.774484          0.938897
# Quest6_DED120        1.169510       1.102829          1.091841
# Quest11_HIQ011       1.175435       0.561837          1.091002
# Demog1_DMDHHSZA      0.249596       0.605154          0.129471
# Quest18_OCQ210       7.859939       2.680441          8.408625
# Quest4_CBD111    16612.483330  126081.947610       9793.447034
# Quest15_KIQ026       1.914347       0.434698          1.938618
# Demog1_DMDHHSZB      0.490573       0.849670          0.264903
#
#                  std_oversampled  mean_relative_change  std_relative_change  \
# Quest12_HEQ030          0.370063             -0.004155            -0.279608
# Quest12_HEQ010          0.325034             -0.004155            -0.279549
# Quest6_DED125           0.567060              0.062316            -0.267822
# Quest6_DED120           0.808401             -0.066412            -0.266976
# Quest11_HIQ011          0.414017             -0.071831            -0.263101
# Demog1_DMDHHSZA         0.453320             -0.481278            -0.250900
# Quest18_OCQ210          2.012730              0.069808            -0.249105
# Quest4_CBD111       95014.987972             -0.410477            -0.246403
# Quest15_KIQ026          0.339120              0.012678            -0.219873
# Demog1_DMDHHSZB         0.666492             -0.460013            -0.215587
#
#                                                     desc
# Quest12_HEQ030           Ever Told You Have Hepatitis C?
# Quest12_HEQ010           Ever Told You Have Hepatitis B?
# Quest6_DED125    Minutes Outdoors 9Am - 5Pm Not Work Day
# Quest6_DED120        Minutes Outdoors 9Am - 5Pm Work Day
# Quest11_HIQ011               Covered By Health Insurance
# Demog1_DMDHHSZA   # Of Children 5 Years Or Younger In Hh
# Quest18_OCQ210    Usually Work 35 Or More Hours Per Week
# Quest4_CBD111        Money Spent On Food At Other Stores
# Quest15_KIQ026                   Ever Had Kidney Stones?
# Demog1_DMDHHSZB       # Of Children 6-17 Years Old In Hh

# %%
before_after.sort_values(by=['std_relative_change']).tail(10)
# Out:
#                      mean       std  mean_oversampled  std_oversampled  \
# Quest7_DIQ010    1.878614  0.456818          1.681073         0.524215
# Quest17_DPQ020   1.480697  2.988309          1.936103         3.482663
# Quest17_DPQ040   1.830670  2.914901          2.441971         3.404562
# Quest17_DPQ030   1.725983  2.955484          2.282507         3.462113
# Quest3_CDQ008    7.527743  2.921444          6.091002         3.574350
# Quest9_DLQ050    1.831388  0.412771          1.577776         0.509533
# Labor2_URDFLOW1  0.914760  1.162899          0.908377         1.578674
# Exami1_BPXPULS   1.038546  0.181753          1.103204         0.253753
# Quest10_ECQ020   9.000000  0.000000          9.000000         0.000000
# Quest20_PFQ020   9.000000  0.000000          9.000000         0.000000
#
#                  mean_relative_change  std_relative_change  \
# Quest7_DIQ010               -0.105152             0.147537
# Quest17_DPQ020               0.307562             0.165429
# Quest17_DPQ040               0.333922             0.167986
# Quest17_DPQ030               0.322439             0.171420
# Quest3_CDQ008               -0.190859             0.223487
# Quest9_DLQ050               -0.138481             0.234421
# Labor2_URDFLOW1             -0.006978             0.357533
# Exami1_BPXPULS               0.062258             0.396144
# Quest10_ECQ020               0.000000                  NaN
# Quest20_PFQ020               0.000000                  NaN
#
#                                                      desc
# Quest7_DIQ010               Doctor Told You Have Diabetes
# Quest17_DPQ020       Feeling Down, Depressed, Or Hopeless
# Quest17_DPQ040      Feeling Tired Or Having Little Energy
# Quest17_DPQ030      Trouble Sleeping Or Sleeping Too Much
# Quest3_CDQ008    Severe Pain In Chest More Than Half Hour
# Quest9_DLQ050            Have Serious Difficulty Walking?
# Labor2_URDFLOW1               Urine #1 Flow Rate (Ml/Min)
# Exami1_BPXPULS                Pulse Regular Or Irregular?
# Quest10_ECQ020                Mother Smoked When Pregnant
# Quest20_PFQ020         Crawl, Walk, Run, Play Limitations

# %% [markdown]
# ## Export Data

# %%
df = X_resampled.copy()
df['Quest16_MCQ160B'] = y_resampled
df
# Out:
#        Dieta1_DRDINT  Dieta1_DR1TFIBE  Quest21_SLQ300  Quest19_PAD660  \
# 0                  1                0               2               2
# 1                  1                2               2               2
# 2                  0                2               2               1
# 3                  1                3               1               0
# 4                  1                1               2               1
# ...              ...              ...             ...             ...
# 10731              1                2               1               2
# 10732              1                1               2               2
# 10733              1                0               0               2
# 10734              1                2               1               2
# 10735              1                0               0               2
#
#        Quest19_PAQ635  Dieta1_DR1TCHOL  Quest19_PAQ655  Dieta1_DR1TSFAT  \
# 0                 2.0                0               2                1
# 1                 2.0                0               2                1
# 2                 2.0                2               1                2
# 3                 1.0                3               3                3
# 4                 1.0                1               2                3
# ...               ...              ...             ...              ...
# 10731             2.0                3               1                3
# 10732             2.0                3               0                3
# 10733             2.0                0               0                1
# 10734             2.0                2               0                2
# 10735             2.0                0               0                0
#
#        Dieta1_DR1TKCAL  Exami2_BMXBMI  ...  Quest1_ALQ111  Quest10_ECQ020  \
# 0                    0              2  ...            1.0             9.0
# 1                    0              0  ...            2.0             9.0
# 2                    1              3  ...            9.0             9.0
# 3                    3              0  ...            1.0             9.0
# 4                    2              0  ...            1.0             9.0
# ...                ...            ...  ...            ...             ...
# 10731                3              1  ...            1.0             9.0
# 10732                0              3  ...            1.0             9.0
# 10733                2              3  ...            1.0             9.0
# 10734                1              2  ...            9.0             9.0
# 10735                1              2  ...            1.0             9.0
#
#        Quest16_MCQ220  Quest4_CBD121  Quest16_MCQ366A  Labor2_URDFLOW1  \
# 0                 2.0   7.500000e+01              2.0         1.204000
# 1                 2.0   5.397605e-79              2.0         0.500000
# 2                 2.0   4.000000e+01              2.0         0.107000
# 3                 2.0   8.570000e+02              2.0         0.605000
# 4                 2.0   4.000000e+01              2.0         0.706000
# ...               ...            ...              ...              ...
# 10731             2.0   4.691092e+01              2.0         0.837825
# 10732             2.0   3.546832e+01              1.0         0.209351
# 10733             2.0   2.991748e+01              1.0         0.963971
# 10734             2.0   4.415803e+00              1.0         1.027300
# 10735             2.0   5.000000e+01              2.0         0.343267
#
#        Demog1_DMDEDUC  Quest9_DLQ050  Quest20_PFQ061C  Quest16_MCQ160B
# 0                 2.0            2.0              1.0                0
# 1                 1.0            2.0              2.0                0
# 2                 4.0            1.0              9.0                0
# 3                 5.0            2.0              9.0                0
# 4                 3.0            2.0              1.0                0
# ...               ...            ...              ...              ...
# 10731             3.0            1.0              9.0                1
# 10732             2.0            1.0              9.0                1
# 10733             3.0            1.0              9.0                1
# 10734             2.0            1.0              9.0                1
# 10735             4.0            2.0              9.0                1
#
# [10736 rows x 86 columns]

# %%
target_path = "Dataset/Data Versioning/Trained_Oversampled-2.csv"
final = df.copy()

final.to_csv(os.path.join(drive_path, target_path))
