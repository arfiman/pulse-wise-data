# %% [markdown]
# # Prepare Environment

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re

import warnings
warnings.filterwarnings('ignore')

drive_path = '/content/drive/MyDrive/Kuliah/Tugas Akhir/Final Project Shared Folder'
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Ingest Data

# %%
data_path = "Dataset/Data Versioning/Combined_All_V6.csv"

df_raw = pd.read_csv(os.path.join(drive_path, data_path), index_col = 0)
df_raw = df_raw.set_index('SEQN')
df_raw.head()
# Out:
#          Demog1_RIAGENDR  Demog1_RIDAGEYR  Demog1_RIDRETH3  Demog1_DMDMARTL  \
# SEQN
# 93703.0              2.0              2.0              6.0              5.0
# 93704.0              1.0              2.0              3.0              5.0
# 93705.0              2.0             66.0              4.0              3.0
# 93706.0              1.0             18.0              6.0              5.0
# 93707.0              1.0             13.0              7.0              5.0
#
#          Demog1_DMDHHSIZ  Demog1_DMDFMSIZ  Demog1_DMDHHSZA  Demog1_DMDHHSZB  \
# SEQN
# 93703.0              5.0              5.0     3.000000e+00     5.397605e-79
# 93704.0              4.0              4.0     2.000000e+00     5.397605e-79
# 93705.0              1.0              1.0     5.397605e-79     5.397605e-79
# 93706.0              5.0              5.0     5.397605e-79     5.397605e-79
# 93707.0              7.0              7.0     5.397605e-79     3.000000e+00
#
#          Demog1_DMDHHSZE  Demog1_DMDEDUC  ...  Dieta1_DR1TPROT  \
# SEQN                                      ...
# 93703.0     5.397605e-79             1.0  ...        46.795385
# 93704.0     5.397605e-79             1.0  ...        51.580000
# 93705.0     1.000000e+00             2.0  ...        20.010000
# 93706.0     1.000000e+00             4.0  ...        94.190000
# 93707.0     5.397605e-79             1.0  ...        59.480000
#
#          Dieta1_DR1TCARB  Dieta1_DR1TSUGR  Dieta1_DR1TFIBE  Dieta1_DR1TTFAT  \
# SEQN
# 93703.0       183.161302        93.418166        11.005325        49.559349
# 93704.0       160.460000        76.970000         5.900000        43.240000
# 93705.0       157.450000        91.550000         8.400000        56.980000
# 93706.0        89.820000        14.730000         7.100000       137.390000
# 93707.0       188.150000        84.220000        10.900000        89.180000
#
#          Dieta1_DR1TSFAT  Dieta1_DR1TMFAT  Dieta1_DR1TPFAT  Dieta1_DR1TCHOL  \
# SEQN
# 93703.0        17.118651        16.306485         10.77397       162.313609
# 93704.0        11.372000        14.333000         12.50600       144.000000
# 93705.0        16.435000        16.432000         19.78600        14.000000
# 93706.0        35.169000        45.805000         49.87300       462.000000
# 93707.0        33.252000        33.712000         12.42400       585.000000
#
#          Dieta1_DR1TCALC
# SEQN
# 93703.0        893.39645
# 93704.0        700.00000
# 93705.0        314.00000
# 93706.0        869.00000
# 93707.0        535.00000
#
# [5 rows x 91 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9254 entries, 93703.0 to 102956.0
# Data columns (total 91 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Demog1_RIAGENDR  9254 non-null   float64
#  1   Demog1_RIDAGEYR  9254 non-null   float64
#  2   Demog1_RIDRETH3  9254 non-null   float64
#  3   Demog1_DMDMARTL  9254 non-null   float64
#  4   Demog1_DMDHHSIZ  9254 non-null   float64
#  5   Demog1_DMDFMSIZ  9254 non-null   float64
#  6   Demog1_DMDHHSZA  9254 non-null   float64
#  7   Demog1_DMDHHSZB  9254 non-null   float64
#  8   Demog1_DMDHHSZE  9254 non-null   float64
#  9   Demog1_DMDEDUC   9254 non-null   float64
#  10  Demog1_INDIN2    9254 non-null   float64
#  11  Labor1_LBXTC     9254 non-null   float64
#  12  Labor1_LBDTCSI   9254 non-null   float64
#  13  Labor2_URXVOL1   9254 non-null   float64
#  14  Labor2_URDFLOW1  9254 non-null   float64
#  15  Labor2_URDTIME1  9254 non-null   float64
#  16  Exami1_BPXPLS    9254 non-null   float64
#  17  Exami1_BPXPULS   9254 non-null   float64
#  18  Exami2_BMXWT     9254 non-null   float64
#  19  Exami2_BMXHT     9254 non-null   float64
#  20  Exami2_BMXBMI    9254 non-null   float64
#  21  Exami1_SysPulse  9254 non-null   float64
#  22  Exami1_DiaPulse  9254 non-null   float64
#  23  Quest1_ALQ111    9254 non-null   float64
#  24  Quest2_BPQ020    9254 non-null   float64
#  25  Quest3_CDQ008    9254 non-null   float64
#  26  Quest3_CDQ010    9254 non-null   float64
#  27  Quest4_CBD111    9254 non-null   float64
#  28  Quest4_CBD121    9254 non-null   float64
#  29  Quest6_DED120    9254 non-null   float64
#  30  Quest6_DED125    9254 non-null   float64
#  31  Quest7_DIQ010    9254 non-null   float64
#  32  Quest9_DLQ050    9254 non-null   float64
#  33  Quest10_ECQ020   9254 non-null   float64
#  34  Quest11_HIQ011   9254 non-null   float64
#  35  Quest12_HEQ010   9254 non-null   float64
#  36  Quest12_HEQ030   9254 non-null   float64
#  37  Quest14_INQ020   9254 non-null   float64
#  38  Quest14_INQ012   9254 non-null   float64
#  39  Quest14_IND235   9254 non-null   float64
#  40  Quest15_KIQ022   9254 non-null   float64
#  41  Quest15_KIQ026   9254 non-null   float64
#  42  Quest16_MCQ010   8897 non-null   float64
#  43  Quest16_MCQ092   7878 non-null   float64
#  44  Quest16_MCQ160B  5569 non-null   float64
#  45  Quest16_MCQ160C  5569 non-null   float64
#  46  Quest16_MCQ160D  5569 non-null   float64
#  47  Quest16_MCQ160E  5569 non-null   float64
#  48  Quest16_MCQ160F  5569 non-null   float64
#  49  Quest16_MCQ220   5569 non-null   float64
#  50  Quest16_MCQ300C  5569 non-null   float64
#  51  Quest16_MCQ300A  5569 non-null   float64
#  52  Quest16_MCQ366A  6161 non-null   float64
#  53  Quest16_MCQ366B  6161 non-null   float64
#  54  Quest17_DPQ020   9254 non-null   float64
#  55  Quest17_DPQ030   9254 non-null   float64
#  56  Quest17_DPQ040   9254 non-null   float64
#  57  Quest18_OCQ210   9254 non-null   float64
#  58  Quest19_PAQ610   9254 non-null   float64
#  59  Quest19_PAD615   9254 non-null   float64
#  60  Quest19_PAQ635   9254 non-null   float64
#  61  Quest19_PAQ640   9254 non-null   float64
#  62  Quest19_PAD645   9254 non-null   float64
#  63  Quest19_PAQ655   9254 non-null   float64
#  64  Quest19_PAD660   9254 non-null   float64
#  65  Quest20_PFQ020   9254 non-null   float64
#  66  Quest20_PFQ061B  9254 non-null   float64
#  67  Quest20_PFQ061C  9254 non-null   float64
#  68  Quest20_PFQ061H  9254 non-null   float64
#  69  Quest21_SLQ300   9254 non-null   float64
#  70  Quest21_SLD012   9254 non-null   float64
#  71  Quest21_SLQ320   9254 non-null   float64
#  72  Quest21_SLQ330   9254 non-null   float64
#  73  Quest21_SLD013   9254 non-null   float64
#  74  Quest22_SMQ020   9254 non-null   float64
#  75  Quest22_SMQ890   9254 non-null   float64
#  76  Quest22_SMQ900   9254 non-null   float64
#  77  Quest3_CDQ009    9254 non-null   float64
#  78  Dieta1_DRDINT    9254 non-null   float64
#  79  Dieta1_DR1DAY    9254 non-null   float64
#  80  Dieta1_DR1TKCAL  9254 non-null   float64
#  81  Dieta1_DR1TPROT  9254 non-null   float64
#  82  Dieta1_DR1TCARB  9254 non-null   float64
#  83  Dieta1_DR1TSUGR  9254 non-null   float64
#  84  Dieta1_DR1TFIBE  9254 non-null   float64
#  85  Dieta1_DR1TTFAT  9254 non-null   float64
#  86  Dieta1_DR1TSFAT  9254 non-null   float64
#  87  Dieta1_DR1TMFAT  9254 non-null   float64
#  88  Dieta1_DR1TPFAT  9254 non-null   float64
#  89  Dieta1_DR1TCHOL  9254 non-null   float64
#  90  Dieta1_DR1TCALC  9254 non-null   float64
# dtypes: float64(91)
# memory usage: 6.5 MB

# %% [markdown]
# # Clean Data

# %%
df = df_raw.copy()

# ----------------------------------------------------
# Fill in cvd status for person with less then 20 years old
# ----------------------------------------------------

conditions = (df['Quest16_MCQ160B'].isna()) | (df['Quest16_MCQ160C'].isna()) | (df['Quest16_MCQ160D'].isna()) | (df['Quest16_MCQ160E'].isna()) | (df['Quest16_MCQ160F'].isna())
df.loc[conditions, ['Quest16_MCQ160B', 'Quest16_MCQ160C', 'Quest16_MCQ160D', 'Quest16_MCQ160D', 'Quest16_MCQ160E', 'Quest16_MCQ160F']] = 1.0

# df['Quest16_MCQ160B'] = df['Quest16_MCQ160B'].fillna(1.0)

# ----------------------------------------------------
# Fill in Asthma and others
# ----------------------------------------------------

df[['Quest16_MCQ010', 'Quest16_MCQ220', 'Quest16_MCQ300C', 'Quest16_MCQ300A', 'Quest16_MCQ366A', 'Quest16_MCQ366B']] = df.loc[:, ['Quest16_MCQ010', 'Quest16_MCQ220', 'Quest16_MCQ300C', 'Quest16_MCQ300A', 'Quest16_MCQ366A', 'Quest16_MCQ366B']].fillna(value=9)

# ----------------------------------------------------
# Drop Unnecessary Column
# ----------------------------------------------------

df.drop(['Quest16_MCQ092'], axis=1, inplace=True)

# ----------------------------------------------------
# Label of heart failure disease (dropped other than heart failure)
# ----------------------------------------------------

df.drop(['Quest16_MCQ160C', 'Quest16_MCQ160D', 'Quest16_MCQ160E', 'Quest16_MCQ160F'], axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9254 entries, 93703.0 to 102956.0
# Data columns (total 86 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Demog1_RIAGENDR  9254 non-null   float64
#  1   Demog1_RIDAGEYR  9254 non-null   float64
#  2   Demog1_RIDRETH3  9254 non-null   float64
#  3   Demog1_DMDMARTL  9254 non-null   float64
#  4   Demog1_DMDHHSIZ  9254 non-null   float64
#  5   Demog1_DMDFMSIZ  9254 non-null   float64
#  6   Demog1_DMDHHSZA  9254 non-null   float64
#  7   Demog1_DMDHHSZB  9254 non-null   float64
#  8   Demog1_DMDHHSZE  9254 non-null   float64
#  9   Demog1_DMDEDUC   9254 non-null   float64
#  10  Demog1_INDIN2    9254 non-null   float64
#  11  Labor1_LBXTC     9254 non-null   float64
#  12  Labor1_LBDTCSI   9254 non-null   float64
#  13  Labor2_URXVOL1   9254 non-null   float64
#  14  Labor2_URDFLOW1  9254 non-null   float64
#  15  Labor2_URDTIME1  9254 non-null   float64
#  16  Exami1_BPXPLS    9254 non-null   float64
#  17  Exami1_BPXPULS   9254 non-null   float64
#  18  Exami2_BMXWT     9254 non-null   float64
#  19  Exami2_BMXHT     9254 non-null   float64
#  20  Exami2_BMXBMI    9254 non-null   float64
#  21  Exami1_SysPulse  9254 non-null   float64
#  22  Exami1_DiaPulse  9254 non-null   float64
#  23  Quest1_ALQ111    9254 non-null   float64
#  24  Quest2_BPQ020    9254 non-null   float64
#  25  Quest3_CDQ008    9254 non-null   float64
#  26  Quest3_CDQ010    9254 non-null   float64
#  27  Quest4_CBD111    9254 non-null   float64
#  28  Quest4_CBD121    9254 non-null   float64
#  29  Quest6_DED120    9254 non-null   float64
#  30  Quest6_DED125    9254 non-null   float64
#  31  Quest7_DIQ010    9254 non-null   float64
#  32  Quest9_DLQ050    9254 non-null   float64
#  33  Quest10_ECQ020   9254 non-null   float64
#  34  Quest11_HIQ011   9254 non-null   float64
#  35  Quest12_HEQ010   9254 non-null   float64
#  36  Quest12_HEQ030   9254 non-null   float64
#  37  Quest14_INQ020   9254 non-null   float64
#  38  Quest14_INQ012   9254 non-null   float64
#  39  Quest14_IND235   9254 non-null   float64
#  40  Quest15_KIQ022   9254 non-null   float64
#  41  Quest15_KIQ026   9254 non-null   float64
#  42  Quest16_MCQ010   9254 non-null   float64
#  43  Quest16_MCQ160B  9254 non-null   float64
#  44  Quest16_MCQ220   9254 non-null   float64
#  45  Quest16_MCQ300C  9254 non-null   float64
#  46  Quest16_MCQ300A  9254 non-null   float64
#  47  Quest16_MCQ366A  9254 non-null   float64
#  48  Quest16_MCQ366B  9254 non-null   float64
#  49  Quest17_DPQ020   9254 non-null   float64
#  50  Quest17_DPQ030   9254 non-null   float64
#  51  Quest17_DPQ040   9254 non-null   float64
#  52  Quest18_OCQ210   9254 non-null   float64
#  53  Quest19_PAQ610   9254 non-null   float64
#  54  Quest19_PAD615   9254 non-null   float64
#  55  Quest19_PAQ635   9254 non-null   float64
#  56  Quest19_PAQ640   9254 non-null   float64
#  57  Quest19_PAD645   9254 non-null   float64
#  58  Quest19_PAQ655   9254 non-null   float64
#  59  Quest19_PAD660   9254 non-null   float64
#  60  Quest20_PFQ020   9254 non-null   float64
#  61  Quest20_PFQ061B  9254 non-null   float64
#  62  Quest20_PFQ061C  9254 non-null   float64
#  63  Quest20_PFQ061H  9254 non-null   float64
#  64  Quest21_SLQ300   9254 non-null   float64
#  65  Quest21_SLD012   9254 non-null   float64
#  66  Quest21_SLQ320   9254 non-null   float64
#  67  Quest21_SLQ330   9254 non-null   float64
#  68  Quest21_SLD013   9254 non-null   float64
#  69  Quest22_SMQ020   9254 non-null   float64
#  70  Quest22_SMQ890   9254 non-null   float64
#  71  Quest22_SMQ900   9254 non-null   float64
#  72  Quest3_CDQ009    9254 non-null   float64
#  73  Dieta1_DRDINT    9254 non-null   float64
#  74  Dieta1_DR1DAY    9254 non-null   float64
#  75  Dieta1_DR1TKCAL  9254 non-null   float64
#  76  Dieta1_DR1TPROT  9254 non-null   float64
#  77  Dieta1_DR1TCARB  9254 non-null   float64
#  78  Dieta1_DR1TSUGR  9254 non-null   float64
#  79  Dieta1_DR1TFIBE  9254 non-null   float64
#  80  Dieta1_DR1TTFAT  9254 non-null   float64
#  81  Dieta1_DR1TSFAT  9254 non-null   float64
#  82  Dieta1_DR1TMFAT  9254 non-null   float64
#  83  Dieta1_DR1TPFAT  9254 non-null   float64
#  84  Dieta1_DR1TCHOL  9254 non-null   float64
#  85  Dieta1_DR1TCALC  9254 non-null   float64
# dtypes: float64(86)
# memory usage: 6.1 MB

# %% [markdown]
# # Rearrange Column

# %%
var_mapping_path = 'Dataset/Variable Mapping V2.xlsx'

var_mapping = pd.read_excel(os.path.join(drive_path, var_mapping_path))
var_mapping['group'] = var_mapping['group'].replace({'Dieta2': 'Dieta1'})
var_mapping['model_var_name'] = var_mapping['group'] + "_" + var_mapping['variable']

var_mapping
# Out:
#       model_var_name           name                                     title  \
# 0    Demog1_RIAGENDR   Demographics  Demographic Variables and Sample Weights
# 1    Demog1_RIDAGEYR   Demographics  Demographic Variables and Sample Weights
# 2    Demog1_RIDRETH3   Demographics  Demographic Variables and Sample Weights
# 3    Demog1_DMDEDUC3   Demographics  Demographic Variables and Sample Weights
# 4    Demog1_DMDEDUC2   Demographics  Demographic Variables and Sample Weights
# ..               ...            ...                                       ...
# 148   Demog1_DMDEDUC    Demographic  Demographic Variables and Sample Weights
# 149    Demog1_INDIN2    Demographic  Demographic Variables and Sample Weights
# 150  Exami1_SysPulse    Examination                            Blood Pressure
# 151  Exami1_DiaPulse    Examination                            Blood Pressure
# 152    Quest3_CDQ009  Questionnaire                     Cardiovascular Health
#
#      variable                                               desc  is_used  \
# 0    RIAGENDR                                             Gender     True
# 1    RIDAGEYR                          Age In Years At Screening     True
# 2    RIDRETH3                   Race/Hispanic Origin W/ Nh Asian     True
# 3    DMDEDUC3              Education Level - Children/Youth 6-19     True
# 4    DMDEDUC2                       Education Level - Adults 20+     True
# ..        ...                                                ...      ...
# 148   DMDEDUC                            Education Level all age     True
# 149    INDIN2  Average income from household income & family ...     True
# 150  SysPulse                            Systolic Pulse Combined     True
# 151  DiaPulse                           Diastolic Pulse Combined     True
# 152    CDQ009                            Pain In Body (Combined)     True
#
#      lifestyle   group
# 0        False  Demog1
# 1        False  Demog1
# 2        False  Demog1
# 3        False  Demog1
# 4        False  Demog1
# ..         ...     ...
# 148      False  Demog1
# 149      False  Demog1
# 150      False  Exami1
# 151      False  Exami1
# 152      False  Quest3
#
# [153 rows x 8 columns]

# %%
model_var = pd.DataFrame({'model_var_name': df.columns.tolist()})

model_var = pd.merge(model_var, var_mapping, left_on=model_var['model_var_name'].str.lower(), right_on=var_mapping['model_var_name'].str.lower(), how='outer', indicator=True).query('_merge!="right_only"')

# To Check if all variable is tagged
# model_var[model_var['_merge'] == "left_only"]

model_var = model_var[['model_var_name_x', 'lifestyle']].rename(columns={'model_var_name_x': 'model_var_name'}).drop_duplicates().reset_index(drop=True)

model_var
# Out:
#      model_var_name  lifestyle
# 0   Demog1_RIAGENDR      False
# 1   Demog1_RIDAGEYR      False
# 2   Demog1_RIDRETH3      False
# 3   Demog1_DMDMARTL      False
# 4   Demog1_DMDHHSIZ      False
# ..              ...        ...
# 81  Dieta1_DR1TSFAT       True
# 82  Dieta1_DR1TMFAT       True
# 83  Dieta1_DR1TPFAT       True
# 84  Dieta1_DR1TCHOL       True
# 85  Dieta1_DR1TCALC       True
#
# [86 rows x 2 columns]

# %%
label_cols = list([col for col in model_var['model_var_name'] if "Quest16" in col])

lifestyle_cols = model_var.loc[model_var['lifestyle'] == True, 'model_var_name'].tolist()
charac_cols = model_var.loc[model_var['lifestyle'] == False, 'model_var_name'].tolist()

lifestyle_cols = list(set(lifestyle_cols) - set(label_cols))
charac_cols = list(set(charac_cols) - set(label_cols))

print("Overall Cols:", len(model_var['model_var_name']))
print("Lifestyle Cols:", len(lifestyle_cols))
print(lifestyle_cols)
print("Characteristics Cols:", len(charac_cols))
print(charac_cols)
print("Label Cols:", len(label_cols))
print(label_cols)
# Out:
# Overall Cols: 86
# Lifestyle Cols: 28
# ['Quest19_PAQ640', 'Quest6_DED125', 'Dieta1_DR1TTFAT', 'Quest19_PAD660', 'Dieta1_DR1TPROT', 'Dieta1_DR1TCARB', 'Dieta1_DR1TMFAT', 'Quest19_PAQ610', 'Quest19_PAQ635', 'Quest21_SLQ320', 'Quest21_SLD013', 'Dieta1_DR1TFIBE', 'Dieta1_DR1TCALC', 'Dieta1_DRDINT', 'Quest19_PAQ655', 'Quest21_SLQ330', 'Quest6_DED120', 'Quest19_PAD615', 'Quest21_SLD012', 'Dieta1_DR1TSFAT', 'Dieta1_DR1TCHOL', 'Quest19_PAD645', 'Dieta1_DR1TSUGR', 'Dieta1_DR1DAY', 'Dieta1_DR1TKCAL', 'Exami2_BMXBMI', 'Dieta1_DR1TPFAT', 'Quest21_SLQ300']
# Characteristics Cols: 51
# ['Demog1_RIAGENDR', 'Quest4_CBD121', 'Quest20_PFQ061C', 'Exami1_BPXPLS', 'Quest17_DPQ020', 'Quest2_BPQ020', 'Demog1_RIDAGEYR', 'Quest10_ECQ020', 'Exami1_BPXPULS', 'Exami2_BMXWT', 'Exami1_DiaPulse', 'Demog1_DMDHHSZE', 'Quest22_SMQ020', 'Quest7_DIQ010', 'Quest3_CDQ008', 'Quest17_DPQ030', 'Exami2_BMXHT', 'Quest14_INQ012', 'Demog1_INDIN2', 'Labor1_LBDTCSI', 'Quest20_PFQ061B', 'Quest1_ALQ111', 'Quest14_IND235', 'Labor2_URDTIME1', 'Quest12_HEQ030', 'Demog1_DMDFMSIZ', 'Quest17_DPQ040', 'Quest3_CDQ010', 'Quest15_KIQ026', 'Quest22_SMQ900', 'Demog1_DMDHHSZB', 'Demog1_DMDHHSZA', 'Quest9_DLQ050', 'Quest20_PFQ020', 'Labor2_URXVOL1', 'Quest3_CDQ009', 'Quest4_CBD111', 'Quest22_SMQ890', 'Quest15_KIQ022', 'Quest11_HIQ011', 'Demog1_DMDHHSIZ', 'Demog1_DMDEDUC', 'Exami1_SysPulse', 'Quest14_INQ020', 'Labor2_URDFLOW1', 'Quest12_HEQ010', 'Labor1_LBXTC', 'Quest20_PFQ061H', 'Demog1_DMDMARTL', 'Demog1_RIDRETH3', 'Quest18_OCQ210']
# Label Cols: 7
# ['Quest16_MCQ010', 'Quest16_MCQ160B', 'Quest16_MCQ220', 'Quest16_MCQ300C', 'Quest16_MCQ300A', 'Quest16_MCQ366A', 'Quest16_MCQ366B']

# %%
final = df.copy()

final = final[lifestyle_cols + charac_cols + label_cols]

final
# Out:
#           Quest19_PAQ640  Quest6_DED125  Dieta1_DR1TTFAT  Quest19_PAD660  \
# SEQN
# 93703.0         4.680830     148.854618        49.559349       75.630091
# 93704.0         4.680830     148.854618        43.240000       75.630091
# 93705.0         4.585774     148.854618        56.980000       71.704698
# 93706.0         5.000000     154.092949       137.390000       97.682927
# 93707.0         4.793651     148.854618        89.180000      103.243243
# ...                  ...            ...              ...             ...
# 102952.0        4.587912     148.854618        38.680000       65.134021
# 102953.0        4.575342     120.000000       114.960000       61.261719
# 102954.0        4.522321     180.000000        66.580000       62.415385
# 102955.0        4.877193     148.854618        44.110000       96.205674
# 102956.0        4.774059     180.000000        40.590000       68.338235
#
#           Dieta1_DR1TPROT  Dieta1_DR1TCARB  Dieta1_DR1TMFAT  Quest19_PAQ610  \
# SEQN
# 93703.0         46.795385       183.161302        16.306485        4.020545
# 93704.0         51.580000       160.460000        14.333000        4.020545
# 93705.0         20.010000       157.450000        16.432000        3.744589
# 93706.0         94.190000        89.820000        45.805000        4.073034
# 93707.0         59.480000       188.150000        33.712000        3.600000
# ...                   ...              ...              ...             ...
# 102952.0        52.590000       139.920000        15.611000        3.522293
# 102953.0       188.170000       333.410000        44.604000        3.000000
# 102954.0        72.700000       218.100000        23.098000        4.220472
# 102955.0        29.620000       192.730000        11.406000        3.897059
# 102956.0        93.910000       215.310000        11.741000        4.363309
#
#           Quest19_PAQ635  Quest21_SLQ320  ...  Demog1_DMDMARTL  \
# SEQN                                      ...
# 93703.0              9.0           753.0  ...              5.0
# 93704.0              9.0           753.0  ...              5.0
# 93705.0              2.0          1380.0  ...              3.0
# 93706.0              1.0            30.0  ...              5.0
# 93707.0              9.0           528.0  ...              5.0
# ...                  ...             ...  ...              ...
# 102952.0             2.0          1350.0  ...              1.0
# 102953.0             2.0          1380.0  ...              4.0
# 102954.0             2.0             0.0  ...              5.0
# 102955.0             9.0           487.0  ...              5.0
# 102956.0             2.0           120.0  ...              3.0
#
#           Demog1_RIDRETH3  Quest18_OCQ210  Quest16_MCQ010  Quest16_MCQ160B  \
# SEQN
# 93703.0               6.0             9.0             2.0              1.0
# 93704.0               3.0             9.0             2.0              1.0
# 93705.0               4.0             1.0             1.0              2.0
# 93706.0               6.0             9.0             2.0              1.0
# 93707.0               7.0             9.0             2.0              1.0
# ...                   ...             ...             ...              ...
# 102952.0              6.0             9.0             2.0              2.0
# 102953.0              1.0             9.0             1.0              2.0
# 102954.0              4.0             9.0             2.0              2.0
# 102955.0              4.0             9.0             2.0              1.0
# 102956.0              3.0             9.0             2.0              2.0
#
#           Quest16_MCQ220  Quest16_MCQ300C  Quest16_MCQ300A  Quest16_MCQ366A  \
# SEQN
# 93703.0              9.0              9.0              9.0              9.0
# 93704.0              9.0              9.0              9.0              9.0
# 93705.0              2.0              1.0              2.0              2.0
# 93706.0              9.0              9.0              9.0              2.0
# 93707.0              9.0              9.0              9.0              9.0
# ...                  ...              ...              ...              ...
# 102952.0             2.0              2.0              2.0              2.0
# 102953.0             2.0              2.0              2.0              1.0
# 102954.0             2.0              1.0              2.0              1.0
# 102955.0             9.0              9.0              9.0              9.0
# 102956.0             2.0              2.0              2.0              2.0
#
#           Quest16_MCQ366B
# SEQN
# 93703.0               9.0
# 93704.0               9.0
# 93705.0               2.0
# 93706.0               2.0
# 93707.0               9.0
# ...                   ...
# 102952.0              2.0
# 102953.0              1.0
# 102954.0              2.0
# 102955.0              9.0
# 102956.0              2.0
#
# [9254 rows x 86 columns]

# %% [markdown]
# # Save Data

# %%
# target_path = "Dataset/Data Versioning/Trained_V2.csv"

# final.to_csv(os.path.join(drive_path, target_path))
