# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import random
import math
import itertools
import pprint

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import tensorflow_datasets as tfds
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, ClassifierMixin

drive_path = '/content/drive/MyDrive/Kuliah/Tugas Akhir/Final Project Shared Folder'
data_path = "Dataset/Data Versioning/"
model_path = "Model/ML Model/"
hyperparameter_log_path = "Notebook/Arif's Workspace/Hyperparameter Tuning/Log/Merged"
data_version = "Trained_V2-2.csv"
hyperparameter_log = "V2.csv"
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']

# %% [markdown]
# # Model Builder

# %%
class CNNModel(BaseEstimator, ClassifierMixin):
  def __init__(
      self,
      input_shape,
      output_shape,
      layer_metadata,
      convolution_part=['conv1d'],
      intermediate_part=['flatten'],
      dense_part=['dense'],
      convolution_hyperparameter=[{'filters':16, 'kernel_size':3, 'activation':'relu'}],
      intermediate_hyperparameter=[{}],
      dense_hyperparameter=[{'units':32, 'activation':'relu'}],
      optimizer='adam',
      loss='binary_crossentropy',
      metrics=['accuracy']
  ):
    self.input_shape = input_shape
    self.layer_metadata = layer_metadata
    self.convolution_part = convolution_part
    self.intermediate_part = intermediate_part
    self.dense_part = dense_part
    self.convolution_hyperparameter = convolution_hyperparameter
    self.intermediate_hyperparameter = intermediate_hyperparameter
    self.dense_hyperparameter = dense_hyperparameter
    self.optimizer = optimizer
    self.model = self.build_model(input_shape, output_shape, convolution_part, intermediate_part, dense_part, convolution_hyperparameter, intermediate_hyperparameter, dense_hyperparameter, optimizer, loss, metrics)



  def build_model(
      self,
      input_shape,
      output_shape,
      convolution_part,
      intermediate_part,
      dense_part,
      convolution_hyperparameter,
      intermediate_hyperparameter,
      dense_hyperparameter,
      optimizer,
      loss,
      metrics
  ):

    def fix_hyperparameter_type(layer, hyperparameter, layer_metadata, warnings=True):
      for layer_info in layer_metadata:
        if(layer == layer_info['layer']):
          for params in layer_info['hyperparameter']:
            val = hyperparameter.get(params['param'], params['default'])
            if(type(val) != params['type']):
              if(warnings): print("Hyperparameter ", params['param'], " Have Invalid Data Type! Using Default..")
              hyperparameter[params['param']] = params['default']
            else:
              hyperparameter[params['param']] = val
        else:
          pass
      return hyperparameter

    model = keras.models.Sequential()
    model.add(keras.layers.Input(input_shape))

    # Convolution Part
    for layer, hyperparameter in zip(convolution_part, convolution_hyperparameter):
      hyperparameter = fix_hyperparameter_type(layer, hyperparameter, self.layer_metadata)

      if(layer == 'conv1d'):
        model.add(keras.layers.Conv1D(filters=hyperparameter['filters'], kernel_size=hyperparameter['kernel_size'], activation=hyperparameter['activation']))
      elif(layer == 'maxpooling1d'):
        model.add(keras.layers.MaxPooling1D(pool_size=hyperparameter['pool_size']))
      elif(layer == 'conv2d'):
        model.add(keras.layers.Conv2D(filters=hyperparameter['filters'], kernel_size=hyperparameter['kernel_size'], activation=hyperparameter['activation']))
      elif(layer == 'maxpooling2d'):
        model.add(keras.layers.MaxPooling2D(pool_size=hyperparameter['pool_size']))
      else:
        print("'Convolution Part' Layer Invalid!")
        return None

    # Intermediate Part
    for layer, hyperparameter in zip(intermediate_part, intermediate_hyperparameter):
      hyperparameter = fix_hyperparameter_type(layer, hyperparameter, self.layer_metadata)

      if(layer == 'flatten'):
        model.add(keras.layers.Flatten())
      else:
        print("'Intermediate Part' Layer Invalid!")
        return None

    # Dense Part
    for layer, hyperparameter in zip(dense_part, dense_hyperparameter):
      hyperparameter = fix_hyperparameter_type(layer, hyperparameter, self.layer_metadata)

      if(layer == 'dense'):
        model.add(keras.layers.Dense(units=hyperparameter['units'], activation=hyperparameter['activation']))
      else:
        print("'Dense Part' Layer Invalid!")
        return None

    model.add(keras.layers.Dense(output_shape, activation='sigmoid'))

    # Compile the model
    model.compile(optimizer=optimizer,
                loss=loss,
                metrics=metrics)

    return model

  def fit(self, X_train, y_train, X_test, y_test, epochs, verbose=1):
    self.model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), verbose=verbose)

  def score(self, X, y):
    loss, accuracy = self.model.evaluate(X, y, verbose=0)
    loss_inverse = 1/(loss+1e-20)

    return loss_inverse

  def evaluate(self, X, y):
    # Evaluate the model on the test set
    loss, accuracy = self.model.evaluate(X, y, verbose=0)

    print(f"Loss: %.3f%%" % (loss*100) )
    print(f"Accuracy: %.3f%%" % (accuracy*100) )

    return loss, accuracy

  def summary(self):
    self.model.summary()

  def predict(self, X):
    return self.model.predict(X, verbose=0)

# %%
layer_metadata = [
  {'layer': 'conv1d', 'hyperparameter': [
      {'param':'filters', 'type':int, 'default':16},
      {'param':'kernel_size', 'type':int, 'default':3},
      {'param':'activation', 'type':str, 'default':'linear'}
    ]
  },
  {'layer': 'maxpooling1d', 'hyperparameter': [
      {'param':'pool_size', 'type':int, 'default':2}
    ]
  },
  {'layer': 'flatten', 'hyperparameter': [

    ]
  },
  {'layer': 'dense', 'hyperparameter': [
      {'param':'units', 'type':int, 'default':8},
      {'param':'activation', 'type':str, 'default':'linear'}
    ]
  }
]

# %% [markdown]
# # Check Hyperparameter Log

# %%
hp_log = pd.read_csv(os.path.join(drive_path, hyperparameter_log_path+"/"+hyperparameter_log))

hp_log['convolution_hyperparameter'].replace(r"<class '(.*?)'>", r"\1", regex=True)
hp_log['dense_hyperparameter'].replace(r"<class '(.*?)'>", r"\1", regex=True)

hp_log
# Out:
#                           convolution_part  \
# 0                               ['conv1d']
# 1                               ['conv1d']
# 2                               ['conv1d']
# 3                               ['conv1d']
# 4                               ['conv1d']
# ...                                    ...
# 1788        ['conv1d', 'conv1d', 'conv1d']
# 1789  ['conv1d', 'conv1d', 'maxpooling1d']
# 1790        ['conv1d', 'conv1d', 'conv1d']
# 1791        ['conv1d', 'conv1d', 'conv1d']
# 1792        ['conv1d', 'conv1d', 'conv1d']
#
#                              convolution_hyperparameter          dense_part  \
# 0     [{'filters': 2, 'kernel_size': 1, 'activation'...                  []
# 1     [{'filters': 2, 'kernel_size': 1, 'activation'...           ['dense']
# 2     [{'filters': 2, 'kernel_size': 1, 'activation'...           ['dense']
# 3     [{'filters': 2, 'kernel_size': 1, 'activation'...           ['dense']
# 4     [{'filters': 2, 'kernel_size': 1, 'activation'...           ['dense']
# ...                                                 ...                 ...
# 1788  [{'filters': 2, 'kernel_size': 2, 'activation'...  ['dense', 'dense']
# 1789  [{'filters': 2, 'kernel_size': 3, 'activation'...  ['dense', 'dense']
# 1790  [{'filters': 2, 'kernel_size': 3, 'activation'...  ['dense', 'dense']
# 1791  [{'filters': 8, 'kernel_size': 3, 'activation'...  ['dense', 'dense']
# 1792  [{'filters': 16, 'kernel_size': 2, 'activation...  ['dense', 'dense']
#
#                                    dense_hyperparameter input_shape  \
# 0                                                    []     (85, 1)
# 1                [{'units': 2, 'activation': 'linear'}]     (85, 1)
# 2                  [{'units': 2, 'activation': 'relu'}]     (85, 1)
# 3               [{'units': 16, 'activation': 'linear'}]     (85, 1)
# 4                 [{'units': 16, 'activation': 'relu'}]     (85, 1)
# ...                                                 ...         ...
# 1788  [{'units': 4, 'activation': 'relu'}, {'units':...     (85, 1)
# 1789  [{'units': 16, 'activation': 'relu'}, {'units'...     (85, 1)
# 1790  [{'units': 8, 'activation': 'relu'}, {'units':...     (85, 1)
# 1791  [{'units': 16, 'activation': 'relu'}, {'units'...     (85, 1)
# 1792  [{'units': 16, 'activation': 'relu'}, {'units'...     (85, 1)
#
#                                          layer_metadata      loss  accuracy  \
# 0     [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.075551  0.976226
# 1     [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.075768  0.976767
# 2     [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.079794  0.977415
# 3     [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.078772  0.976335
# 4     [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.079255  0.976983
# ...                                                 ...       ...       ...
# 1788  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.089139  0.977631
# 1789  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.079429  0.976983
# 1790  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.076449  0.976119
# 1791  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.102054  0.977739
# 1792  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.239426  0.876183
#
#       train_loss  train_accuracy
# 0       0.068099        0.978856
# 1       0.067970        0.978640
# 2       0.075291        0.978784
# 3       0.068539        0.978496
# 4       0.054908        0.981233
# ...          ...             ...
# 1788    0.077528        0.979144
# 1789    0.058103        0.980153
# 1790    0.060578        0.979756
# 1791    0.098972        0.978244
# 1792    0.217385        0.881053
#
# [1793 rows x 10 columns]

# %%
np.sum(hp_log['convolution_part'] == "['conv1d', 'maxpooling1d']" )
# Out:
# 21

# %%
hp_log_sorted = hp_log.copy()
hp_log_sorted = hp_log_sorted.sort_values(by=['accuracy', 'loss', 'train_accuracy', 'train_loss'], ascending=[True, False, True, False])

hp_log_sorted
# Out:
#                           convolution_part  \
# 1288        ['conv1d', 'conv1d', 'conv1d']
# 1270        ['conv1d', 'conv1d', 'conv1d']
# 1389  ['maxpooling1d', 'conv1d', 'conv1d']
# 1464        ['conv1d', 'conv1d', 'conv1d']
# 1108        ['conv1d', 'conv1d', 'conv1d']
# ...                                    ...
# 1664  ['maxpooling1d', 'conv1d', 'conv1d']
# 1112  ['maxpooling1d', 'conv1d', 'conv1d']
# 1689        ['conv1d', 'conv1d', 'conv1d']
# 1137        ['conv1d', 'conv1d', 'conv1d']
# 1413  ['maxpooling1d', 'conv1d', 'conv1d']
#
#                              convolution_hyperparameter          dense_part  \
# 1288  [{'filters': 16, 'kernel_size': 2, 'activation...  ['dense', 'dense']
# 1270  [{'filters': 8, 'kernel_size': 2, 'activation'...  ['dense', 'dense']
# 1389  [{'pool_size': 2}, {'filters': 4, 'kernel_size...  ['dense', 'dense']
# 1464  [{'filters': 12, 'kernel_size': 3, 'activation...  ['dense', 'dense']
# 1108  [{'filters': 16, 'kernel_size': 2, 'activation...  ['dense', 'dense']
# ...                                                 ...                 ...
# 1664  [{'pool_size': 2}, {'filters': 4, 'kernel_size...  ['dense', 'dense']
# 1112  [{'pool_size': 2}, {'filters': 4, 'kernel_size...  ['dense', 'dense']
# 1689  [{'filters': 2, 'kernel_size': 2, 'activation'...           ['dense']
# 1137  [{'filters': 2, 'kernel_size': 2, 'activation'...           ['dense']
# 1413  [{'pool_size': 2}, {'filters': 4, 'kernel_size...           ['dense']
#
#                                    dense_hyperparameter input_shape  \
# 1288  [{'units': 8, 'activation': 'relu'}, {'units':...     (85, 1)
# 1270  [{'units': 4, 'activation': 'relu'}, {'units':...     (85, 1)
# 1389  [{'units': 2, 'activation': 'relu'}, {'units':...     (85, 1)
# 1464  [{'units': 8, 'activation': 'relu'}, {'units':...     (85, 1)
# 1108  [{'units': 2, 'activation': 'relu'}, {'units':...     (85, 1)
# ...                                                 ...         ...
# 1664  [{'units': 2, 'activation': 'relu'}, {'units':...     (85, 1)
# 1112  [{'units': 2, 'activation': 'relu'}, {'units':...     (85, 1)
# 1689               [{'units': 8, 'activation': 'relu'}]     (85, 1)
# 1137               [{'units': 8, 'activation': 'relu'}]     (85, 1)
# 1413              [{'units': 16, 'activation': 'relu'}]     (85, 1)
#
#                                          layer_metadata      loss  accuracy  \
# 1288  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.395260  0.777112
# 1270  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.394043  0.777112
# 1389  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.387605  0.777934
# 1464  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.385361  0.778258
# 1108  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.390873  0.778906
# ...                                                 ...       ...       ...
# 1664  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.095816  0.978820
# 1112  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.095787  0.978820
# 1689  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.075142  0.978928
# 1137  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.075541  0.978928
# 1413  [{'layer': 'conv1d', 'hyperparameter': [{'para...  0.078248  0.979036
#
#       train_loss  train_accuracy
# 1288    0.386128        0.780297
# 1270    0.390169        0.779973
# 1389    0.383692        0.779771
# 1464    0.380086        0.779987
# 1108    0.389107        0.778942
# ...          ...             ...
# 1664    0.089106        0.978676
# 1112    0.089088        0.978712
# 1689    0.063804        0.979396
# 1137    0.063969        0.979360
# 1413    0.069514        0.979252
#
# [1793 rows x 10 columns]

# %%
# Top 5 Model

for i in range(5):
  print("Best Model #", i+1)
  print("-"*10)
  pprint.pprint(hp_log_sorted.iloc[-i-1].to_dict())
  print("-"*10)
# Out:
# Best Model # 1
# ----------
# {'accuracy': 0.9790357649326324,
#  'convolution_hyperparameter': "[{'pool_size': 2}, {'filters': 4, "
#                                "'kernel_size': 2, 'activation': 'relu'}, "
#                                "{'filters': 2, 'kernel_size': 3, 'activation': "
#                                "'relu'}]",
#  'convolution_part': "['maxpooling1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 16, 'activation': 'relu'}]",
#  'dense_part': "['dense']",
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0782480668276548,
#  'train_accuracy': 0.979252189397812,
#  'train_loss': 0.0695141125470399}
# ----------
# Best Model # 2
# ----------
# {'accuracy': 0.978927806019783,
#  'convolution_hyperparameter': "[{'filters': 2, 'kernel_size': 2, "
#                                "'activation': 'relu'}, {'filters': 2, "
#                                "'kernel_size': 2, 'activation': 'relu'}, "
#                                "{'filters': 4, 'kernel_size': 2, 'activation': "
#                                "'relu'}]",
#  'convolution_part': "['conv1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 8, 'activation': 'relu'}]",
#  'dense_part': "['dense']",
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0755412466824054,
#  'train_accuracy': 0.9793602526187896,
#  'train_loss': 0.0639686677604913}
# ----------
# Best Model # 3
# ----------
# {'accuracy': 0.9789277613162994,
#  'convolution_hyperparameter': "[{'filters': 2, 'kernel_size': 2, "
#                                "'activation': 'relu'}, {'filters': 2, "
#                                "'kernel_size': 2, 'activation': 'relu'}, "
#                                "{'filters': 4, 'kernel_size': 2, 'activation': "
#                                "'relu'}]",
#  'convolution_part': "['conv1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 8, 'activation': 'relu'}]",
#  'dense_part': "['dense']",
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0751415584236383,
#  'train_accuracy': 0.9793962687253952,
#  'train_loss': 0.0638044960796833}
# ----------
# Best Model # 4
# ----------
# {'accuracy': 0.9788196831941604,
#  'convolution_hyperparameter': "[{'pool_size': 2}, {'filters': 4, "
#                                "'kernel_size': 3, 'activation': 'relu'}, "
#                                "{'filters': 12, 'kernel_size': 2, "
#                                "'activation': 'relu'}]",
#  'convolution_part': "['maxpooling1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 2, 'activation': 'relu'}, {'units': 8, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0957868974655866,
#  'train_accuracy': 0.9787118583917618,
#  'train_loss': 0.0890884920954704}
# ----------
# Best Model # 5
# ----------
# {'accuracy': 0.9788196831941604,
#  'convolution_hyperparameter': "[{'pool_size': 2}, {'filters': 4, "
#                                "'kernel_size': 3, 'activation': 'relu'}, "
#                                "{'filters': 12, 'kernel_size': 2, "
#                                "'activation': 'relu'}]",
#  'convolution_part': "['maxpooling1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 2, 'activation': 'relu'}, {'units': 8, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0958161987364292,
#  'train_accuracy': 0.9786758422851562,
#  'train_loss': 0.0891061797738075}
# ----------

# %%
# Bottom 5 Model

for i in range(5):
  print("Worst Model #", i+1)
  print("-"*10)
  pprint.pprint(hp_log_sorted.iloc[i].to_dict())
  print("-"*10)
# Out:
# Worst Model # 1
# ----------
# {'accuracy': 0.7771123945713043,
#  'convolution_hyperparameter': "[{'filters': 16, 'kernel_size': 2, "
#                                "'activation': 'relu'}, {'filters': 4, "
#                                "'kernel_size': 2, 'activation': 'relu'}, "
#                                "{'filters': 16, 'kernel_size': 2, "
#                                "'activation': 'relu'}]",
#  'convolution_part': "['conv1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 8, 'activation': 'relu'}, {'units': 2, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.3952596634626388,
#  'train_accuracy': 0.7802968323230743,
#  'train_loss': 0.3861284665763378}
# ----------
# Worst Model # 2
# ----------
# {'accuracy': 0.7771123945713043,
#  'convolution_hyperparameter': "[{'filters': 8, 'kernel_size': 2, "
#                                "'activation': 'relu'}, {'filters': 8, "
#                                "'kernel_size': 2, 'activation': 'relu'}, "
#                                "{'filters': 12, 'kernel_size': 3, "
#                                "'activation': 'relu'}]",
#  'convolution_part': "['conv1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 4, 'activation': 'relu'}, {'units': 2, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.3940431736409664,
#  'train_accuracy': 0.7799726724624634,
#  'train_loss': 0.3901691436767578}
# ----------
# Worst Model # 3
# ----------
# {'accuracy': 0.7779341042041779,
#  'convolution_hyperparameter': "[{'pool_size': 2}, {'filters': 4, "
#                                "'kernel_size': 3, 'activation': 'relu'}, "
#                                "{'filters': 8, 'kernel_size': 2, 'activation': "
#                                "'relu'}]",
#  'convolution_part': "['maxpooling1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 2, 'activation': 'relu'}, {'units': 2, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.3876049015671015,
#  'train_accuracy': 0.7797709405422211,
#  'train_loss': 0.383692417293787}
# ----------
# Worst Model # 4
# ----------
# {'accuracy': 0.7782583683729172,
#  'convolution_hyperparameter': "[{'filters': 12, 'kernel_size': 3, "
#                                "'activation': 'relu'}, {'filters': 2, "
#                                "'kernel_size': 3, 'activation': 'relu'}, "
#                                "{'filters': 8, 'kernel_size': 3, 'activation': "
#                                "'relu'}]",
#  'convolution_part': "['conv1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 8, 'activation': 'relu'}, {'units': 2, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.3853611517697572,
#  'train_accuracy': 0.7799870371818542,
#  'train_loss': 0.3800855623558163}
# ----------
# Worst Model # 5
# ----------
# {'accuracy': 0.77890644967556,
#  'convolution_hyperparameter': "[{'filters': 16, 'kernel_size': 2, "
#                                "'activation': 'relu'}, {'filters': 16, "
#                                "'kernel_size': 3, 'activation': 'relu'}, "
#                                "{'filters': 2, 'kernel_size': 3, 'activation': "
#                                "'relu'}]",
#  'convolution_part': "['conv1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 2, 'activation': 'relu'}, {'units': 2, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(85, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.3908730391412973,
#  'train_accuracy': 0.7789424061775208,
#  'train_loss': 0.3891074620187282}
# ----------

# %%
hp_log_sorted.set_index('convolution_part')
# Out:
#                                                              convolution_hyperparameter  \
# convolution_part
# ['conv1d', 'conv1d', 'conv1d']        [{'filters': 16, 'kernel_size': 2, 'activation...
# ['conv1d', 'conv1d', 'conv1d']        [{'filters': 8, 'kernel_size': 2, 'activation'...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'pool_size': 2}, {'filters': 4, 'kernel_size...
# ['conv1d', 'conv1d', 'conv1d']        [{'filters': 12, 'kernel_size': 3, 'activation...
# ['conv1d', 'conv1d', 'conv1d']        [{'filters': 16, 'kernel_size': 2, 'activation...
# ...                                                                                 ...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'pool_size': 2}, {'filters': 4, 'kernel_size...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'pool_size': 2}, {'filters': 4, 'kernel_size...
# ['conv1d', 'conv1d', 'conv1d']        [{'filters': 2, 'kernel_size': 2, 'activation'...
# ['conv1d', 'conv1d', 'conv1d']        [{'filters': 2, 'kernel_size': 2, 'activation'...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'pool_size': 2}, {'filters': 4, 'kernel_size...
#
#                                               dense_part  \
# convolution_part
# ['conv1d', 'conv1d', 'conv1d']        ['dense', 'dense']
# ['conv1d', 'conv1d', 'conv1d']        ['dense', 'dense']
# ['maxpooling1d', 'conv1d', 'conv1d']  ['dense', 'dense']
# ['conv1d', 'conv1d', 'conv1d']        ['dense', 'dense']
# ['conv1d', 'conv1d', 'conv1d']        ['dense', 'dense']
# ...                                                  ...
# ['maxpooling1d', 'conv1d', 'conv1d']  ['dense', 'dense']
# ['maxpooling1d', 'conv1d', 'conv1d']  ['dense', 'dense']
# ['conv1d', 'conv1d', 'conv1d']                 ['dense']
# ['conv1d', 'conv1d', 'conv1d']                 ['dense']
# ['maxpooling1d', 'conv1d', 'conv1d']           ['dense']
#
#                                                                    dense_hyperparameter  \
# convolution_part
# ['conv1d', 'conv1d', 'conv1d']        [{'units': 8, 'activation': 'relu'}, {'units':...
# ['conv1d', 'conv1d', 'conv1d']        [{'units': 4, 'activation': 'relu'}, {'units':...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'units': 2, 'activation': 'relu'}, {'units':...
# ['conv1d', 'conv1d', 'conv1d']        [{'units': 8, 'activation': 'relu'}, {'units':...
# ['conv1d', 'conv1d', 'conv1d']        [{'units': 2, 'activation': 'relu'}, {'units':...
# ...                                                                                 ...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'units': 2, 'activation': 'relu'}, {'units':...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'units': 2, 'activation': 'relu'}, {'units':...
# ['conv1d', 'conv1d', 'conv1d']                     [{'units': 8, 'activation': 'relu'}]
# ['conv1d', 'conv1d', 'conv1d']                     [{'units': 8, 'activation': 'relu'}]
# ['maxpooling1d', 'conv1d', 'conv1d']              [{'units': 16, 'activation': 'relu'}]
#
#                                      input_shape  \
# convolution_part
# ['conv1d', 'conv1d', 'conv1d']           (85, 1)
# ['conv1d', 'conv1d', 'conv1d']           (85, 1)
# ['maxpooling1d', 'conv1d', 'conv1d']     (85, 1)
# ['conv1d', 'conv1d', 'conv1d']           (85, 1)
# ['conv1d', 'conv1d', 'conv1d']           (85, 1)
# ...                                          ...
# ['maxpooling1d', 'conv1d', 'conv1d']     (85, 1)
# ['maxpooling1d', 'conv1d', 'conv1d']     (85, 1)
# ['conv1d', 'conv1d', 'conv1d']           (85, 1)
# ['conv1d', 'conv1d', 'conv1d']           (85, 1)
# ['maxpooling1d', 'conv1d', 'conv1d']     (85, 1)
#
#                                                                          layer_metadata  \
# convolution_part
# ['conv1d', 'conv1d', 'conv1d']        [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ['conv1d', 'conv1d', 'conv1d']        [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ['conv1d', 'conv1d', 'conv1d']        [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ['conv1d', 'conv1d', 'conv1d']        [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ...                                                                                 ...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ['conv1d', 'conv1d', 'conv1d']        [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ['conv1d', 'conv1d', 'conv1d']        [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ['maxpooling1d', 'conv1d', 'conv1d']  [{'layer': 'conv1d', 'hyperparameter': [{'para...
#
#                                           loss  accuracy  train_loss  \
# convolution_part
# ['conv1d', 'conv1d', 'conv1d']        0.395260  0.777112    0.386128
# ['conv1d', 'conv1d', 'conv1d']        0.394043  0.777112    0.390169
# ['maxpooling1d', 'conv1d', 'conv1d']  0.387605  0.777934    0.383692
# ['conv1d', 'conv1d', 'conv1d']        0.385361  0.778258    0.380086
# ['conv1d', 'conv1d', 'conv1d']        0.390873  0.778906    0.389107
# ...                                        ...       ...         ...
# ['maxpooling1d', 'conv1d', 'conv1d']  0.095816  0.978820    0.089106
# ['maxpooling1d', 'conv1d', 'conv1d']  0.095787  0.978820    0.089088
# ['conv1d', 'conv1d', 'conv1d']        0.075142  0.978928    0.063804
# ['conv1d', 'conv1d', 'conv1d']        0.075541  0.978928    0.063969
# ['maxpooling1d', 'conv1d', 'conv1d']  0.078248  0.979036    0.069514
#
#                                       train_accuracy
# convolution_part
# ['conv1d', 'conv1d', 'conv1d']              0.780297
# ['conv1d', 'conv1d', 'conv1d']              0.779973
# ['maxpooling1d', 'conv1d', 'conv1d']        0.779771
# ['conv1d', 'conv1d', 'conv1d']              0.779987
# ['conv1d', 'conv1d', 'conv1d']              0.778942
# ...                                              ...
# ['maxpooling1d', 'conv1d', 'conv1d']        0.978676
# ['maxpooling1d', 'conv1d', 'conv1d']        0.978712
# ['conv1d', 'conv1d', 'conv1d']              0.979396
# ['conv1d', 'conv1d', 'conv1d']              0.979360
# ['maxpooling1d', 'conv1d', 'conv1d']        0.979252
#
# [1793 rows x 9 columns]
