# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import random
import math
import itertools
import pprint

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import tensorflow_datasets as tfds
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, ClassifierMixin

drive_path = '/content/drive/MyDrive/Kuliah/Tugas Akhir/Final Project Shared Folder'
data_path = "Dataset/Data Versioning/"
model_path = "Model/ML Model/"
hyperparameter_log_path = "Notebook/Arif's Workspace/Hyperparameter Tuning/Log"
data_version = "Trained_V2-2.csv"
hyperparameter_log = "V2.csv"
base_url = "https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?CycleBeginYear=2017"
dataset_names = ['Demographics', 'Dietary', 'Examination', 'Laboratory', 'Questionnaire']

# %% [markdown]
# # Model Builder

# %%
class CNNModel(BaseEstimator, ClassifierMixin):
  def __init__(
      self,
      input_shape,
      output_shape,
      layer_metadata,
      convolution_part=['conv1d'],
      intermediate_part=['flatten'],
      dense_part=['dense'],
      convolution_hyperparameter=[{'filters':16, 'kernel_size':3, 'activation':'relu'}],
      intermediate_hyperparameter=[{}],
      dense_hyperparameter=[{'units':32, 'activation':'relu'}],
      optimizer='adam',
      loss='binary_crossentropy',
      metrics=['accuracy']
  ):
    self.input_shape = input_shape
    self.layer_metadata = layer_metadata
    self.convolution_part = convolution_part
    self.intermediate_part = intermediate_part
    self.dense_part = dense_part
    self.convolution_hyperparameter = convolution_hyperparameter
    self.intermediate_hyperparameter = intermediate_hyperparameter
    self.dense_hyperparameter = dense_hyperparameter
    self.optimizer = optimizer
    self.model = self.build_model(input_shape, output_shape, convolution_part, intermediate_part, dense_part, convolution_hyperparameter, intermediate_hyperparameter, dense_hyperparameter, optimizer, loss, metrics)



  def build_model(
      self,
      input_shape,
      output_shape,
      convolution_part,
      intermediate_part,
      dense_part,
      convolution_hyperparameter,
      intermediate_hyperparameter,
      dense_hyperparameter,
      optimizer,
      loss,
      metrics
  ):

    def fix_hyperparameter_type(layer, hyperparameter, layer_metadata, warnings=True):
      for layer_info in layer_metadata:
        if(layer == layer_info['layer']):
          for params in layer_info['hyperparameter']:
            val = hyperparameter.get(params['param'], params['default'])
            if(type(val) != params['type']):
              if(warnings): print("Hyperparameter ", params['param'], " Have Invalid Data Type! Using Default..")
              hyperparameter[params['param']] = params['default']
            else:
              hyperparameter[params['param']] = val
        else:
          pass
      return hyperparameter

    model = keras.models.Sequential()
    model.add(keras.layers.Input(input_shape))

    # Convolution Part
    for layer, hyperparameter in zip(convolution_part, convolution_hyperparameter):
      hyperparameter = fix_hyperparameter_type(layer, hyperparameter, self.layer_metadata)

      if(layer == 'conv1d'):
        model.add(keras.layers.Conv1D(filters=hyperparameter['filters'], kernel_size=hyperparameter['kernel_size'], activation=hyperparameter['activation']))
      elif(layer == 'maxpooling1d'):
        model.add(keras.layers.MaxPooling1D(pool_size=hyperparameter['pool_size']))
      elif(layer == 'conv2d'):
        model.add(keras.layers.Conv2D(filters=hyperparameter['filters'], kernel_size=hyperparameter['kernel_size'], activation=hyperparameter['activation']))
      elif(layer == 'maxpooling2d'):
        model.add(keras.layers.MaxPooling2D(pool_size=hyperparameter['pool_size']))
      else:
        print("'Convolution Part' Layer Invalid!")
        return None

    # Intermediate Part
    for layer, hyperparameter in zip(intermediate_part, intermediate_hyperparameter):
      hyperparameter = fix_hyperparameter_type(layer, hyperparameter, self.layer_metadata)

      if(layer == 'flatten'):
        model.add(keras.layers.Flatten())
      else:
        print("'Intermediate Part' Layer Invalid!")
        return None

    # Dense Part
    for layer, hyperparameter in zip(dense_part, dense_hyperparameter):
      hyperparameter = fix_hyperparameter_type(layer, hyperparameter, self.layer_metadata)

      if(layer == 'dense'):
        model.add(keras.layers.Dense(units=hyperparameter['units'], activation=hyperparameter['activation']))
      else:
        print("'Dense Part' Layer Invalid!")
        return None

    model.add(keras.layers.Dense(output_shape, activation='sigmoid'))

    # Compile the model
    model.compile(optimizer=optimizer,
                loss=loss,
                metrics=metrics)

    return model

  def fit(self, X_train, y_train, X_test, y_test, epochs, verbose=1):
    self.model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), verbose=verbose)

  def score(self, X, y):
    loss, accuracy = self.model.evaluate(X, y, verbose=0)
    loss_inverse = 1/(loss+1e-20)

    return loss_inverse

  def evaluate(self, X, y):
    # Evaluate the model on the test set
    loss, accuracy = self.model.evaluate(X, y, verbose=0)

    print(f"Loss: %.3f%%" % (loss*100) )
    print(f"Accuracy: %.3f%%" % (accuracy*100) )

    return loss, accuracy

  def summary(self):
    self.model.summary()

  def predict(self, X):
    return self.model.predict(X, verbose=0)

# %%
layer_metadata = [
  {'layer': 'conv1d', 'hyperparameter': [
      {'param':'filters', 'type':int, 'default':16},
      {'param':'kernel_size', 'type':int, 'default':3},
      {'param':'activation', 'type':str, 'default':'linear'}
    ]
  },
  {'layer': 'maxpooling1d', 'hyperparameter': [
      {'param':'pool_size', 'type':int, 'default':2}
    ]
  },
  {'layer': 'flatten', 'hyperparameter': [

    ]
  },
  {'layer': 'dense', 'hyperparameter': [
      {'param':'units', 'type':int, 'default':8},
      {'param':'activation', 'type':str, 'default':'linear'}
    ]
  }
]

# %% [markdown]
# # Check Hyperparameter Log

# %%
hp_log = pd.read_csv(os.path.join(drive_path, hyperparameter_log_path+"/"+hyperparameter_log))

hp_log['convolution_hyperparameter'].replace(r"<class '(.*?)'>", r"\1", regex=True)
hp_log['dense_hyperparameter'].replace(r"<class '(.*?)'>", r"\1", regex=True)

hp_log
# Out:
#                    convolution_part  \
# 0                        ['conv1d']
# 1                        ['conv1d']
# 2                        ['conv1d']
# 3                        ['conv1d']
# 4                        ['conv1d']
# ..                              ...
# 698  ['conv1d', 'conv1d', 'conv1d']
# 699  ['conv1d', 'conv1d', 'conv1d']
# 700  ['conv1d', 'conv1d', 'conv1d']
# 701  ['conv1d', 'conv1d', 'conv1d']
# 702  ['conv1d', 'conv1d', 'conv1d']
#
#                             convolution_hyperparameter          dense_part  \
# 0    [{'filters': 2, 'kernel_size': 1, 'activation'...                  []
# 1    [{'filters': 2, 'kernel_size': 1, 'activation'...           ['dense']
# 2    [{'filters': 2, 'kernel_size': 1, 'activation'...           ['dense']
# 3    [{'filters': 2, 'kernel_size': 1, 'activation'...           ['dense']
# 4    [{'filters': 2, 'kernel_size': 1, 'activation'...           ['dense']
# ..                                                 ...                 ...
# 698  [{'filters': 2, 'kernel_size': 1, 'activation'...  ['dense', 'dense']
# 699  [{'filters': 2, 'kernel_size': 1, 'activation'...  ['dense', 'dense']
# 700  [{'filters': 2, 'kernel_size': 1, 'activation'...  ['dense', 'dense']
# 701  [{'filters': 2, 'kernel_size': 1, 'activation'...  ['dense', 'dense']
# 702  [{'filters': 2, 'kernel_size': 1, 'activation'...  ['dense', 'dense']
#
#                                   dense_hyperparameter input_shape  \
# 0                                                   []     (79, 1)
# 1               [{'units': 2, 'activation': 'linear'}]     (79, 1)
# 2                 [{'units': 2, 'activation': 'relu'}]     (79, 1)
# 3              [{'units': 16, 'activation': 'linear'}]     (79, 1)
# 4                [{'units': 16, 'activation': 'relu'}]     (79, 1)
# ..                                                 ...         ...
# 698  [{'units': 2, 'activation': 'linear'}, {'units...     (79, 1)
# 699  [{'units': 2, 'activation': 'linear'}, {'units...     (79, 1)
# 700  [{'units': 2, 'activation': 'linear'}, {'units...     (79, 1)
# 701  [{'units': 2, 'activation': 'relu'}, {'units':...     (79, 1)
# 702  [{'units': 2, 'activation': 'relu'}, {'units':...     (79, 1)
#
#      output_shape                                     layer_metadata  \
# 0               1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 1               1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 2               1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 3               1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 4               1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ..            ...                                                ...
# 698             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 699             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 700             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 701             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 702             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
#
#          loss       metrics  accuracy  train_loss  train_accuracy
# 0    0.066495  ['accuracy']  0.979834    0.079093        0.975297
# 1    0.065173  ['accuracy']  0.979114    0.075125        0.975760
# 2    0.064310  ['accuracy']  0.980194    0.072760        0.976996
# 3    0.065463  ['accuracy']  0.978394    0.074957        0.975297
# 4    0.065772  ['accuracy']  0.981275    0.060922        0.978539
# ..        ...           ...       ...         ...             ...
# 698  0.061000  ['accuracy']  0.981995    0.072596        0.977150
# 699  0.062791  ['accuracy']  0.979834    0.070558        0.975915
# 700  0.061729  ['accuracy']  0.980555    0.069003        0.977459
# 701  0.064235  ['accuracy']  0.981635    0.071765        0.977459
# 702  0.680466  ['accuracy']  0.579402    0.680176        0.580361
#
# [703 rows x 12 columns]

# %%
hp_log_sorted = hp_log.copy()
hp_log_sorted = hp_log_sorted.sort_values(by=['accuracy', 'loss', 'train_accuracy', 'train_loss'], ascending=[True, False, True, False])

hp_log_sorted
# Out:
#                    convolution_part  \
# 490                      ['conv1d']
# 100                      ['conv1d']
# 419                      ['conv1d']
# 702  ['conv1d', 'conv1d', 'conv1d']
# 639  ['conv1d', 'conv1d', 'conv1d']
# ..                              ...
# 268                      ['conv1d']
# 593  ['conv1d', 'conv1d', 'conv1d']
# 691  ['conv1d', 'conv1d', 'conv1d']
# 140                      ['conv1d']
# 319                      ['conv1d']
#
#                             convolution_hyperparameter          dense_part  \
# 490  [{'filters': 64, 'kernel_size': 3, 'activation...  ['dense', 'dense']
# 100  [{'filters': 2, 'kernel_size': 3, 'activation'...  ['dense', 'dense']
# 419  [{'filters': 64, 'kernel_size': 1, 'activation...  ['dense', 'dense']
# 702  [{'filters': 2, 'kernel_size': 1, 'activation'...  ['dense', 'dense']
# 639  [{'filters': 2, 'kernel_size': 1, 'activation'...  ['dense', 'dense']
# ..                                                 ...                 ...
# 268  [{'filters': 16, 'kernel_size': 3, 'activation...  ['dense', 'dense']
# 593  [{'filters': 2, 'kernel_size': 1, 'activation'...  ['dense', 'dense']
# 691  [{'filters': 2, 'kernel_size': 1, 'activation'...           ['dense']
# 140  [{'filters': 2, 'kernel_size': 3, 'activation'...  ['dense', 'dense']
# 319  [{'filters': 16, 'kernel_size': 3, 'activation...  ['dense', 'dense']
#
#                                   dense_hyperparameter input_shape  \
# 490  [{'units': 2, 'activation': 'relu'}, {'units':...     (79, 1)
# 100  [{'units': 2, 'activation': 'relu'}, {'units':...     (79, 1)
# 419  [{'units': 64, 'activation': 'linear'}, {'unit...     (79, 1)
# 702  [{'units': 2, 'activation': 'relu'}, {'units':...     (79, 1)
# 639  [{'units': 64, 'activation': 'relu'}, {'units'...     (79, 1)
# ..                                                 ...         ...
# 268  [{'units': 2, 'activation': 'linear'}, {'units...     (79, 1)
# 593  [{'units': 64, 'activation': 'linear'}, {'unit...     (79, 1)
# 691            [{'units': 16, 'activation': 'linear'}]     (79, 1)
# 140  [{'units': 2, 'activation': 'linear'}, {'units...     (79, 1)
# 319  [{'units': 2, 'activation': 'relu'}, {'units':...     (79, 1)
#
#      output_shape                                     layer_metadata  \
# 490             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 100             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 419             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 702             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 639             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# ..            ...                                                ...
# 268             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 593             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 691             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 140             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
# 319             1  [{'layer': 'conv1d', 'hyperparameter': [{'para...
#
#          loss       metrics  accuracy  train_loss  train_accuracy
# 490  0.680632  ['accuracy']  0.579402    0.680358        0.580361
# 100  0.680484  ['accuracy']  0.579402    0.680176        0.580361
# 419  0.680484  ['accuracy']  0.579402    0.680175        0.580361
# 702  0.680466  ['accuracy']  0.579402    0.680176        0.580361
# 639  0.092228  ['accuracy']  0.963990    0.076870        0.968658
# ..        ...           ...       ...         ...             ...
# 268  0.063788  ['accuracy']  0.982355    0.066408        0.978848
# 593  0.063735  ['accuracy']  0.982355    0.062456        0.977304
# 691  0.061289  ['accuracy']  0.982355    0.068228        0.977150
# 140  0.061549  ['accuracy']  0.983075    0.070197        0.977922
# 319  0.059493  ['accuracy']  0.983075    0.065112        0.978076
#
# [703 rows x 12 columns]

# %%
# Top 5 Model

for i in range(5):
  print("Best Model #", i+1)
  print("-"*10)
  pprint.pprint(hp_log_sorted.iloc[-i-1].to_dict())
  print("-"*10)
# Out:
# Best Model # 1
# ----------
# {'accuracy': 0.9830752611160278,
#  'convolution_hyperparameter': "[{'filters': 16, 'kernel_size': 3, "
#                                "'activation': 'relu'}]",
#  'convolution_part': "['conv1d']",
#  'dense_hyperparameter': "[{'units': 2, 'activation': 'relu'}, {'units': 64, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(79, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0594929531216621,
#  'metrics': "['accuracy']",
#  'output_shape': 1,
#  'train_accuracy': 0.9780762791633606,
#  'train_loss': 0.065112292766571}
# ----------
# Best Model # 2
# ----------
# {'accuracy': 0.9830752611160278,
#  'convolution_hyperparameter': "[{'filters': 2, 'kernel_size': 3, "
#                                "'activation': 'relu'}]",
#  'convolution_part': "['conv1d']",
#  'dense_hyperparameter': "[{'units': 2, 'activation': 'linear'}, {'units': 64, "
#                          "'activation': 'linear'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(79, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0615487359464168,
#  'metrics': "['accuracy']",
#  'output_shape': 1,
#  'train_accuracy': 0.9779219031333924,
#  'train_loss': 0.0701971873641014}
# ----------
# Best Model # 3
# ----------
# {'accuracy': 0.9823550581932068,
#  'convolution_hyperparameter': "[{'filters': 2, 'kernel_size': 1, "
#                                "'activation': 'linear'}, {'filters': 2, "
#                                "'kernel_size': 1, 'activation': 'linear'}, "
#                                "{'filters': 2, 'kernel_size': 3, 'activation': "
#                                "'relu'}]",
#  'convolution_part': "['conv1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 16, 'activation': 'linear'}]",
#  'dense_part': "['dense']",
#  'input_shape': '(79, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0612894855439662,
#  'metrics': "['accuracy']",
#  'output_shape': 1,
#  'train_accuracy': 0.9771499037742616,
#  'train_loss': 0.0682284384965896}
# ----------
# Best Model # 4
# ----------
# {'accuracy': 0.9823550581932068,
#  'convolution_hyperparameter': "[{'filters': 2, 'kernel_size': 1, "
#                                "'activation': 'linear'}, {'filters': 2, "
#                                "'kernel_size': 1, 'activation': 'linear'}, "
#                                "{'filters': 2, 'kernel_size': 1, 'activation': "
#                                "'linear'}]",
#  'convolution_part': "['conv1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 64, 'activation': 'linear'}, {'units': "
#                          "16, 'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(79, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0637345090508461,
#  'metrics': "['accuracy']",
#  'output_shape': 1,
#  'train_accuracy': 0.9773042798042296,
#  'train_loss': 0.0624562017619609}
# ----------
# Best Model # 5
# ----------
# {'accuracy': 0.9823550581932068,
#  'convolution_hyperparameter': "[{'filters': 16, 'kernel_size': 3, "
#                                "'activation': 'linear'}]",
#  'convolution_part': "['conv1d']",
#  'dense_hyperparameter': "[{'units': 2, 'activation': 'linear'}, {'units': 16, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(79, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0637878999114036,
#  'metrics': "['accuracy']",
#  'output_shape': 1,
#  'train_accuracy': 0.9788482189178468,
#  'train_loss': 0.0664081946015358}
# ----------

# %%
# Bottom 5 Model

for i in range(5):
  print("Worst Model #", i+1)
  print("-"*10)
  pprint.pprint(hp_log_sorted.iloc[i].to_dict())
  print("-"*10)
# Out:
# Worst Model # 1
# ----------
# {'accuracy': 0.5794022083282471,
#  'convolution_hyperparameter': "[{'filters': 64, 'kernel_size': 3, "
#                                "'activation': 'relu'}]",
#  'convolution_part': "['conv1d']",
#  'dense_hyperparameter': "[{'units': 2, 'activation': 'relu'}, {'units': 64, "
#                          "'activation': 'linear'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(79, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.6806321144104004,
#  'metrics': "['accuracy']",
#  'output_shape': 1,
#  'train_accuracy': 0.5803613066673279,
#  'train_loss': 0.6803580522537231}
# ----------
# Worst Model # 2
# ----------
# {'accuracy': 0.5794022083282471,
#  'convolution_hyperparameter': "[{'filters': 2, 'kernel_size': 3, "
#                                "'activation': 'linear'}]",
#  'convolution_part': "['conv1d']",
#  'dense_hyperparameter': "[{'units': 2, 'activation': 'relu'}, {'units': 2, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(79, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.6804844737052917,
#  'metrics': "['accuracy']",
#  'output_shape': 1,
#  'train_accuracy': 0.5803613066673279,
#  'train_loss': 0.6801756024360657}
# ----------
# Worst Model # 3
# ----------
# {'accuracy': 0.5794022083282471,
#  'convolution_hyperparameter': "[{'filters': 64, 'kernel_size': 1, "
#                                "'activation': 'relu'}]",
#  'convolution_part': "['conv1d']",
#  'dense_hyperparameter': "[{'units': 64, 'activation': 'linear'}, {'units': 2, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(79, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.6804844737052917,
#  'metrics': "['accuracy']",
#  'output_shape': 1,
#  'train_accuracy': 0.5803613066673279,
#  'train_loss': 0.6801754832267761}
# ----------
# Worst Model # 4
# ----------
# {'accuracy': 0.5794022083282471,
#  'convolution_hyperparameter': "[{'filters': 2, 'kernel_size': 1, "
#                                "'activation': 'linear'}, {'filters': 2, "
#                                "'kernel_size': 1, 'activation': 'linear'}, "
#                                "{'filters': 2, 'kernel_size': 3, 'activation': "
#                                "'relu'}]",
#  'convolution_part': "['conv1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 2, 'activation': 'relu'}, {'units': 2, "
#                          "'activation': 'relu'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(79, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.6804656982421875,
#  'metrics': "['accuracy']",
#  'output_shape': 1,
#  'train_accuracy': 0.5803613066673279,
#  'train_loss': 0.6801760196685791}
# ----------
# Worst Model # 5
# ----------
# {'accuracy': 0.9639899134635924,
#  'convolution_hyperparameter': "[{'filters': 2, 'kernel_size': 1, "
#                                "'activation': 'linear'}, {'filters': 2, "
#                                "'kernel_size': 1, 'activation': 'linear'}, "
#                                "{'filters': 2, 'kernel_size': 1, 'activation': "
#                                "'relu'}]",
#  'convolution_part': "['conv1d', 'conv1d', 'conv1d']",
#  'dense_hyperparameter': "[{'units': 64, 'activation': 'relu'}, {'units': 2, "
#                          "'activation': 'linear'}]",
#  'dense_part': "['dense', 'dense']",
#  'input_shape': '(79, 1)',
#  'layer_metadata': "[{'layer': 'conv1d', 'hyperparameter': [{'param': "
#                    "'filters', 'type': <class 'int'>, 'default': 16}, "
#                    "{'param': 'kernel_size', 'type': <class 'int'>, 'default': "
#                    "3}, {'param': 'activation', 'type': <class 'str'>, "
#                    "'default': 'linear'}]}, {'layer': 'maxpooling1d', "
#                    "'hyperparameter': [{'param': 'pool_size', 'type': <class "
#                    "'int'>, 'default': 2}]}, {'layer': 'flatten', "
#                    "'hyperparameter': []}, {'layer': 'dense', "
#                    "'hyperparameter': [{'param': 'units', 'type': <class "
#                    "'int'>, 'default': 8}, {'param': 'activation', 'type': "
#                    "<class 'str'>, 'default': 'linear'}]}]",
#  'loss': 0.0922278985381126,
#  'metrics': "['accuracy']",
#  'output_shape': 1,
#  'train_accuracy': 0.9686583280563354,
#  'train_loss': 0.0768704563379287}
# ----------
